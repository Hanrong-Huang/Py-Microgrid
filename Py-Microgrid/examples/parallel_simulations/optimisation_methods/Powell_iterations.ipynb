# %%
import requests
import os
import yaml
import pandas as pd
import numpy as np
import time
from scipy.optimize import minimize, differential_evolution, shgo
import csv
from hopp.simulation import HoppInterface
from hopp.tools.dispatch.plot_tools import (
    plot_battery_output, plot_battery_dispatch_error, plot_generation_profile, plot_battery_generation
)
from hopp.utilities import load_yaml
from hopp.simulation.technologies.grid import Grid
from hopp.simulation.technologies.grid import GridConfig
from hopp.utilities.keys import set_nrel_key_dot_env
from hopp.utilities.keys import set_developer_nrel_gov_key

# Set API for solar and wind resources
set_developer_nrel_gov_key('3F5fBErsd9gKIPEdQpkWHNIhNj7gZG3j0y3lkzew')

# Global variables
yaml_file_path = "../input_yaml/input_file_chunk_3.yaml"
project_lifetime = 25  # years
discount_rate = 0.0588  # real discount rate = 5.88%, discount rate 8%, inflation rate 2%


# Functions for Present Value and LCOE calculations
def present_value(future_value, discount_rate, project_lifetime):
    return future_value / ((1 + discount_rate) ** project_lifetime)

def calculate_lcoe(total_system_cost, total_system_generation_over_lifetime, discount_rate, project_lifetime):
    present_value_total_system_costs = present_value(total_system_cost, discount_rate, project_lifetime)
    present_value_total_system_generation = present_value(total_system_generation_over_lifetime, discount_rate, project_lifetime)
    return present_value_total_system_costs / present_value_total_system_generation

# Battery and load adjustment
def apply_flexible_load_and_adjust_battery(row):
    pv, wind, genset = row['PV Generation (kW)'], row['Wind Generation (kW)'], row['Genset Generation (kW)']
    battery, original_load = row['Original Battery Generation (kW)'], row['Original Load (kW)']
    
    total_generation_without_battery = pv + wind + genset
    
    if battery < 0 and total_generation_without_battery + battery < original_load:
        battery = 0
    
    adjusted_generation = total_generation_without_battery + battery
    
    if adjusted_generation < original_load:
        max_reduction = 0.20 * original_load
        load_reduction = min(original_load - adjusted_generation, max_reduction)
        adjusted_load = original_load - load_reduction
    else:
        adjusted_load = original_load
    
    new_deficit = adjusted_generation - adjusted_load
    
    return pd.Series({
        'Adjusted Battery Generation (kW)': battery,
        'Adjusted Load (kW)': adjusted_load,
        'Adjusted Deficit (kW)': new_deficit
    })

# Penalty calculation
def calculate_penalty(demand_met_percentage):
    unmet_percentage = 100 - demand_met_percentage
    if unmet_percentage <= 1:
        return 0.1 * unmet_percentage
    else:
        return 0.2 * unmet_percentage

# Load YAML configuration file safely
def load_yaml_safely(file_path):
    with open(file_path, 'r') as file:
        config = yaml.safe_load(file)
    if config is None:
        raise ValueError(f"The YAML configuration file at {file_path} is empty or invalid.")
    return config

# Save YAML configuration file safely
def save_yaml_safely(config, file_path):
    backup_path = file_path + '.bak'
    if os.path.exists(file_path):
        os.rename(file_path, backup_path)
    
    try:
        with open(file_path, 'w') as file:
            yaml.safe_dump(config, file, default_flow_style=False, sort_keys=False)
        
        if os.path.getsize(file_path) == 0:
            raise IOError("Failed to write data to YAML file")
        
        if os.path.exists(backup_path):
            os.remove(backup_path)
    except Exception as e:
        if os.path.exists(backup_path):
            os.rename(backup_path, file_path)
        raise IOError(f"Error saving YAML file: {str(e)}")

# Update YAML configuration
def update_yaml_config(yaml_file_path, solar_path, wind_path, latitude, longitude):
    if os.path.exists(yaml_file_path):
        config = load_yaml_safely(yaml_file_path)
        if 'site' not in config or 'data' not in config['site']:
            raise KeyError("The YAML configuration is missing required 'site.data' key.")

        config['site']['data']['lat'] = latitude
        config['site']['data']['lon'] = longitude
        config['site']['solar_resource_file'] = solar_path.replace('\\', '/')
        config['site']['wind_resource_file'] = wind_path.replace('\\', '/')

        save_yaml_safely(config, yaml_file_path)
        print(f"YAML configuration updated successfully at {yaml_file_path}.")
    else:
        raise FileNotFoundError(f"The YAML file at {yaml_file_path} does not exist.")

# Download solar and wind resource data
def download_data_and_update_config(latitude, longitude, solar_year, wind_start, wind_end, api_key, email, yaml_file_path):
    # Define directories for saving files
    solar_dir = r'/home/z5142067/miniconda3/envs/microgrid/lib/python3.8/site-packages/hopp/simulation/resource_files/solar'
    wind_dir = r'/home/z5142067/miniconda3/envs/microgrid/lib/python3.8/site-packages/hopp/simulation/resource_files/wind'
    os.makedirs(solar_dir, exist_ok=True)
    os.makedirs(wind_dir, exist_ok=True)

    # Download Solar Data
    solar_base_url = "https://developer.nrel.gov/api/nsrdb/v2/solar/himawari-download.csv"
    solar_params = {
        "wkt": f"POINT({longitude} {latitude})",
        "names": solar_year,
        "leap_day": "false",
        "interval": "60",
        "utc": "false",
        "full_name": "Hanrong Huang",
        "email": email,
        "affiliation": "UNSW",
        "mailing_list": "true",
        "reason": "research",
        "api_key": api_key,
        "attributes": "dni,dhi,ghi,dew_point,air_temperature,surface_pressure,wind_direction,wind_speed,surface_albedo"
    }
    solar_response = requests.get(solar_base_url, params=solar_params)
    solar_filename = f"{latitude}_{longitude}_psmv3_60_{solar_year}.csv"
    solar_path = os.path.join(solar_dir, solar_filename)

    if solar_response.status_code == 200:
        with open(solar_path, 'wb') as file:
            file.write(solar_response.content)
        print(f"Solar data downloaded and saved to {solar_path}.")
    else:
        print(f"Failed to download solar data: {solar_response.status_code}")
        print(solar_response.text)

    # Download Wind Data
    wind_url = "https://power.larc.nasa.gov/api/temporal/hourly/point"
    wind_params = {
        "start": wind_start,
        "end": wind_end,
        "latitude": latitude,
        "longitude": longitude,
        "community": "ag",
        "parameters": "WS50M,WD50M",
        "format": "srw",
        "user": "Hanrong",
        "header": "true",
        "time-standard": "lst"
    }
    wind_response = requests.get(wind_url, params=wind_params)
    wind_filename = f"{latitude}_{longitude}_NASA_{wind_start[:4]}_60min_50m.srw"
    wind_path = os.path.join(wind_dir, wind_filename)

    if wind_response.status_code == 200:
        with open(wind_path, 'wb') as file:
            file.write(wind_response.content)
        print(f"Wind data downloaded successfully and saved to {wind_path}.")
    else:
        print(f"Failed to download wind data: {wind_response.status_code}")
        print(wind_response.text)

    # Update YAML configuration file
    try:
        update_yaml_config(yaml_file_path, solar_path, wind_path, latitude, longitude)
    except Exception as e:
        raise RuntimeError(f"Error updating YAML configuration: {e}")
        
# Objective function for optimization
def objective_function(x):
    # Ensure integer values for specific variables
    pv_size = float(np.clip(round(x[0]), bounds[0][0], bounds[0][1]))
    num_turbines = int(np.clip(round(x[1]), bounds[1][0], bounds[1][1]))
    battery_capacity_kwh = float(np.clip(round(x[2]), bounds[2][0], bounds[2][1]))
    battery_capacity_kw = float(np.clip(round(x[3]), bounds[3][0], bounds[3][1]))
    grid_interconnect_kw = float(np.clip(round(x[4]), bounds[4][0], bounds[4][1]))

    # Update the YAML configuration with rounded integer variable
    config = load_yaml_safely(yaml_file_path)
    config['technologies']['pv']['system_capacity_kw'] = pv_size
    config['technologies']['wind']['num_turbines'] = num_turbines
    config['technologies']['battery']['system_capacity_kwh'] = battery_capacity_kwh
    config['technologies']['battery']['system_capacity_kw'] = battery_capacity_kw
    config['technologies']['grid']['interconnect_kw'] = grid_interconnect_kw
    save_yaml_safely(config, yaml_file_path)

    # Create a new HoppInterface instance and run the simulation
    try:
        hopp = HoppInterface(yaml_file_path)
        hopp.simulate(project_life=25)
    except Exception as e:
        print(f"Simulation failed: {e}")
        return 1e6, {}  # Return a high LCOE and empty result for infeasible solutions

    # Calculate system components generation over project lifetime
    hybrid_plant = hopp.system

    pv_total_generation = np.sum(hybrid_plant.generation_profile.pv)
    wind_total_generation = np.sum(hybrid_plant.generation_profile.wind)
    battery_total_generation = np.sum(hybrid_plant.generation_profile.battery)
    genset_total_generation = np.sum(hybrid_plant.generation_profile.grid)

    # Total system generation = PV + wind + genset, excluding battery
    total_system_generation_over_lifetime = pv_total_generation + wind_total_generation + genset_total_generation 

    # Genset Specific Calculations
    genset_capacity_kw = hybrid_plant.grid.interconnect_kw
    genset_install_cost_per_kw = 500
    replacement_cost_genset_per_kw = 500
    om_cost_per_kw_per_op_hour = 0.03  # Genset O&M cost per kW per operating hour
    fuel_cost_per_l = 1.20
    specific_fuel_consumption_l_per_kwh = 0.250
    genset_operational_hours_per_year = np.sum(np.array(hybrid_plant.grid.generation_profile) > 0) / project_lifetime
    generator_operational_life_hours = 15000
    generator_operational_life_years = generator_operational_life_hours / genset_operational_hours_per_year
    num_genset_replacements = float(project_lifetime / generator_operational_life_years) - 1

    genset_installed_cost = genset_capacity_kw * genset_install_cost_per_kw
    replacement_cost_genset = num_genset_replacements * genset_capacity_kw * replacement_cost_genset_per_kw
    total_om_cost_genset = om_cost_per_kw_per_op_hour * genset_capacity_kw * genset_operational_hours_per_year * project_lifetime
    total_fuel_consumption = genset_total_generation * specific_fuel_consumption_l_per_kwh
    total_fuel_cost = total_fuel_consumption * fuel_cost_per_l
    total_genset_cost = genset_installed_cost + replacement_cost_genset + total_om_cost_genset + total_fuel_cost

    # Battery Costs
    battery_capacity_kwh = config['technologies']['battery']['system_capacity_kwh']
    battery_installed_cost = hybrid_plant.battery.total_installed_cost  # can be modified in hopp/tools/analysis/bos/cost_calculator.py
    om_cost_battery_per_kwh_per_year = 10  # Battery O&M cost per kW per year
    operational_life_battery = 15
    num_battery_replacements = float(project_lifetime / operational_life_battery) - 1
    replacement_cost_battery_per_kWh = battery_installed_cost / battery_capacity_kwh  # Battery replacement cost per kWh, 700 $/kWh
    replacement_cost_battery = num_battery_replacements * battery_capacity_kwh * replacement_cost_battery_per_kWh
    total_om_cost_battery = om_cost_battery_per_kwh_per_year * battery_capacity_kwh * project_lifetime
    total_battery_cost = battery_installed_cost + replacement_cost_battery + total_om_cost_battery

    # PV Costs
    pv_capacity_kw = hybrid_plant.system_capacity_kw.pv
    pv_installed_cost = hybrid_plant.pv.total_installed_cost  # can be modified in hopp/tools/analysis/bos/cost_calculator.py
    om_cost_pv_per_kw_per_year = 10  # PV O&M cost per kW per year
    total_om_cost_pv = om_cost_pv_per_kw_per_year * pv_capacity_kw * project_lifetime
    total_pv_cost = pv_installed_cost + total_om_cost_pv

    # Wind Costs
    wind_capacity_kw = hybrid_plant.system_capacity_kw.wind
    wind_installed_cost = hybrid_plant.wind.total_installed_cost  # can be modified in hopp/tools/analysis/bos/cost_calculator.py
    om_cost_wind_per_kw_per_year = 40  # Wind O&M cost per kW per year
    total_om_cost_wind = om_cost_wind_per_kw_per_year * wind_capacity_kw * project_lifetime
    total_wind_cost = wind_installed_cost + total_om_cost_wind

    # Total System Costs over project lifetime
    total_system_cost = total_pv_cost + total_wind_cost + total_battery_cost + total_genset_cost

    # Calculate NPC 
    npc = present_value(total_system_cost, discount_rate, project_lifetime)
    
    # Create a DataFrame for flexible load and battery adjustment calculation
    df = pd.DataFrame({
        'PV Generation (kW)': np.array(hybrid_plant.generation_profile.pv[:8760]), 
        'Wind Generation (kW)': np.array(hybrid_plant.generation_profile.wind[:8760]),  
        'Genset Generation (kW)': np.array(hybrid_plant.generation_profile.grid[:8760]), 
        'Original Battery Generation (kW)': np.array(hybrid_plant.generation_profile.battery[:8760]), 
        'Original Load (kW)': np.array(hybrid_plant.site.desired_schedule[:8760]) * 1000   # Convert MW to kW
    })

    # Apply flexible load and battery charging adjustment
    adjusted_results = df.apply(apply_flexible_load_and_adjust_battery, axis=1)
    df['Adjusted Deficit (kW)'] = adjusted_results['Adjusted Deficit (kW)']
    df['Adjusted Load (kW)'] = adjusted_results['Adjusted Load (kW)']
    df['Adjusted Battery Generation (kW)'] = adjusted_results['Adjusted Battery Generation (kW)']

    # Calculate the number of deficit hours that have been fixed by the adjustments (for one year)
    original_deficits = df[df['Original Load (kW)'] > (df['PV Generation (kW)'] + df['Wind Generation (kW)'] + df['Genset Generation (kW)'] + df['Original Battery Generation (kW)'])]
    remaining_deficits = df[df['Adjusted Deficit (kW)'] < 0]
    deficit_hours_fixed_one_year = len(original_deficits) - len(remaining_deficits)

    # Calculate metrics for one year
    total_load_served_one_year = np.sum(df['Adjusted Load (kW)'])
    total_load_reduction_one_year = np.sum(df['Original Load (kW)'] - df['Adjusted Load (kW)'])
    total_charging_prevented_one_year = np.sum(np.maximum(0, -df['Original Battery Generation (kW)'] + df['Adjusted Battery Generation (kW)']))
    total_load_not_served_one_year = np.sum(np.maximum(0, -df['Adjusted Deficit (kW)']))

    # Calculate values for the entire project lifetime
    deficit_hours_fixed = deficit_hours_fixed_one_year * project_lifetime
    total_load_served = total_load_served_one_year * project_lifetime
    total_load_reduction = total_load_reduction_one_year * project_lifetime
    total_charging_prevented = total_charging_prevented_one_year * project_lifetime
    total_load_not_served = total_load_not_served_one_year * project_lifetime

    # Calculate percentages
    total_load_reduction_percentage = (total_load_reduction / (np.sum(df['Original Load (kW)']) * project_lifetime)) * 100
    demand_met_percentage = ((total_load_served - total_load_not_served) / total_load_served) * 100

    # Calculate LCOE
    lcoe = calculate_lcoe(total_system_cost, total_load_served, discount_rate, project_lifetime)

    # Check if the system meets the demand for all hours
    all_hours_sufficient = np.all(df['Adjusted Deficit (kW)'] >= 0)

    # Prepare result dictionary with lifetime values
    result = {
        "PV Capacity (kW)": pv_size,
        "Wind Turbine Capacity (kW)": num_turbines * 1000,  # 1000 kW per turbine
        "Genset Capacity (kW)": grid_interconnect_kw,
        "Battery Energy Capacity (kWh)": battery_capacity_kwh,
        "Battery Power Capacity (kW)": battery_capacity_kw,
        "Total System Generation (kWh)": total_system_generation_over_lifetime,
        "Total PV Generation (kWh)": pv_total_generation,
        "Total Wind Generation (kWh)": wind_total_generation,
        "Total Genset Generation (kWh)": genset_total_generation,
        "Total Battery Generation (kWh)": battery_total_generation,
        "System NPC ($)": npc,
        "System LCOE ($/kWh)": lcoe,
        "Deficit Hours Fixed": deficit_hours_fixed,
        "Total Load Reduction (kWh)": total_load_reduction,
        "Total Load Served (kWh)": total_load_served,
        "Load Reduction Percentage": total_load_reduction_percentage,
        "Total Charging Prevented (kWh)": total_charging_prevented,
        "Demand Not Served (kWh)": total_load_not_served,
        "Demand Met Percentage": demand_met_percentage,
        "Project Lifetime (years)": project_lifetime
    }

    # Check if all hours were sufficient and apply the penalty if there are deficit hours
    if all_hours_sufficient:
        return lcoe, result
    else:
        penalty = calculate_penalty(demand_met_percentage)
        penalized_lcoe = lcoe + penalty
        result["Penalized LCOE ($/kWh)"] = penalized_lcoe
        return penalized_lcoe, result

# OptimizationTracker class
class OptimizationTracker:
    def __init__(self, csv_file):
        self.csv_file = csv_file
        self.iteration_count = 0
        self.fieldnames = ['Iteration', 'Objective Value', 'Parameters', 'Time (seconds)']
        self.data = []
        self.start_time = time.time()

    def track(self, x, f=None):
        self.iteration_count += 1
        current_time = time.time()
        elapsed_time = current_time - self.start_time
        
        x_int = [int(round(xi)) for xi in x]
        lcoe = f if f is not None else objective_function(x_int)[0]
        self.data.append({
            'Iteration': self.iteration_count,
            'Objective Value': lcoe,
            'Parameters': x_int,
            'Time (seconds)': elapsed_time
        })
        print(f"Iteration {self.iteration_count}: Objective Value (LCOE) = {lcoe}, Parameters = {x_int}, Time = {elapsed_time:.2f} seconds")

    def save_to_csv(self):
        with open(self.csv_file, 'w', newline='') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=self.fieldnames)
            writer.writeheader()
            for row in self.data:
                row_copy = row.copy()
                row_copy['Parameters'] = str(row['Parameters'])
                writer.writerow(row_copy)

# Class to hold optimization result
class OptimizationResult:
    def __init__(self, x, success):
        self.x = x
        self.success = success
        
# Global variable for the tracker
global_tracker = None

# Base objective function
def base_objective_function(x):
    x_int = [int(round(xi)) for xi in x]
    return objective_function(x_int)[0]

# Tracking wrapper
def track_evaluation(func):
    def wrapper(x):
        result = func(x)
        if global_tracker is not None:
            global_tracker.track(x, result)
        return result
    return wrapper

# Integer constraint objective (used for Nelder-Mead, Powell and COBYlA)
integer_constraint_objective = base_objective_function

# Tracked integer constraint objective (used for differential evo and shgo)
tracked_integer_constraint_objective = track_evaluation(base_objective_function)

# Custom callback for Nelder-Mead
def custom_callback(xk):
    global best_score, iterations, global_tracker
    iterations += 1
    score = base_objective_function(xk)
    if global_tracker is not None:
        global_tracker.track(xk, score)
    if best_score is None or score < best_score:
        best_score = score
    else:
        if iterations > 50 and abs(score - best_score) < 1e-3:
            return True
    return False

# Run optimization function
def run_optimization(method, bounds, deposit_uid, iteration_output_dir, latitude, longitude):
    global global_tracker, best_score, iterations
    
    start_time = time.time()
    
    tracker = OptimizationTracker(os.path.join(iteration_output_dir, f'{method}_iterations_{deposit_uid}.csv'))
    global_tracker = tracker
    
    best_score = None
    iterations = 0

    # Choose the appropriate objective function based on the method
    obj_func = integer_constraint_objective if method == 'Nelder-Mead' else tracked_integer_constraint_objective

    try:
        if method == 'Nelder-Mead':
            x0 = [int(bound[0] + 0.5 * (bound[1] - bound[0])) for bound in bounds]
            result = minimize(
                obj_func,
                x0,
                method=method,
                options={
                    'maxiter': 200,
                    'xatol': 1,
                    'fatol': 1e-3,
                    'disp': True
                },
                callback=custom_callback
            )
        elif method == 'COBYLA':
            x0 = [int(bound[0] + 0.5 * (bound[1] - bound[0])) for bound in bounds]
            result = minimize(
                obj_func,
                x0,
                method=method,
                bounds=bounds,
                options={
                    'maxiter': 200,
                    'rhobeg': 1.0,
                    'tol': 1e-5,
                    'disp': True
                }
            )
        elif method == 'Powell':
            x0 = [int(bound[0] + 0.5 * (bound[1] - bound[0])) for bound in bounds]
            result = minimize(
                obj_func,
                x0,
                method=method,
                bounds=bounds,
                options={
                    'maxiter': 200,
                    'xtol': 1e-5,
                    'ftol': 1e-5,
                    'disp': True
                }
            )
        elif method == 'Differential Evolution':
            result = differential_evolution(
                obj_func,
                bounds,
                strategy='best1bin',
                maxiter=200,
                popsize=15,
                tol=1e-6,
                mutation=(0.5, 1),
                recombination=0.7,
                updating='immediate',
                workers=1,
                disp=True
            )
        elif method == 'SHGO':
            result = shgo(
                obj_func,
                bounds,
                n=100,
                iters=4,
                sampling_method='sobol',
                options={'disp': True}
            )
        else:
            raise ValueError(f"Unknown method: {method}")
        
        success = result.success
    except Exception as e:
        print(f"Optimization failed for method {method}: {e}")
        result = OptimizationResult(None, False)
        
    end_time = time.time()
    total_time = end_time - start_time

    tracker.save_to_csv()
    global_tracker = None

    if result and getattr(result, 'x', None) is not None:
        optimal_x = [int(round(x)) for x in result.x]
        lcoe, optimal_results = objective_function(optimal_x)

        optimization_results.append({
            'Method': method,
            'Deposit UID': deposit_uid,
            'Latitude': latitude,
            'Longitude': longitude,
            'Iterations': iterations,
            'Duration (seconds)': total_time,
            'LCOE': lcoe,
            **optimal_results
        })
        print(f"{method} optimization successful. LCOE: {lcoe:.6f}, Iterations: {iterations}, Total Time: {total_time:.2f} seconds")
    else:
        print(f"{method} optimization failed or was stopped early. Total Time: {total_time:.2f} seconds")

    return result, iterations, total_time

# Main execution logic
if __name__ == "__main__":
    csv_path = "../deposit_data/auCopper_chunk_0_test_optimisation_methods.csv"
    location_data = pd.read_csv(csv_path)
    api_key = "3F5fBErsd9gKIPEdQpkWHNIhNj7gZG3j0y3lkzew"
    email = "z5142067@ad.unsw.edu.au"
    optimization_results = []
    iteration_output_dir = "./optimisation_results"
    os.makedirs(iteration_output_dir, exist_ok=True)

    methods_to_test = ['Powell']

    # Bounds for the variables: PV, wind, battery_capacity_kwh, battery_capacity_kw, genset
    bounds = [(10000, 45000), (10, 45), (15000, 30000), (5000, 10000), (17000, 30000)]

    for index, row in location_data.iterrows():
        latitude = row['DEPOSIT_LATITUDE']
        longitude = row['DEPOSIT_LONGITUDE']
        deposit_uid = row['DEPOSIT_UID']
        print(f"\nHybrid microgrid simulation and optimization at ore deposit (Lat: {latitude}, Lon: {longitude}) starts:")

        try:
            # Assume you have a function to download data and update config
            download_data_and_update_config(latitude, longitude, "2020", "20200101", "20201231", api_key, email, yaml_file_path)
        except Exception as e:
            print(f"Failed to download data or update configuration: {e}")
            continue
            
        for method in methods_to_test:
            print(f"\nTesting optimization method: {method}")
            result, iterations, duration = run_optimization(method, bounds, deposit_uid, iteration_output_dir, latitude, longitude)

            if result and getattr(result, 'x', None) is not None:
                optimal_x = result.x

                # Round integer variables if needed
                if method != 'Nelder-Mead':  # Nelder-Mead already handled internally
                    optimal_x[1] = int(round(optimal_x[1]))  # Number of turbines

                # Get LCOE and results
                lcoe, optimal_results = objective_function(optimal_x)

                optimization_results.append({
                    'Method': method,
                    'Deposit UID': deposit_uid,
                    'Latitude': latitude,
                    'Longitude': longitude,
                    'Iterations': iterations,
                    'Duration (seconds)': duration,
                    'LCOE ($/kWh)': lcoe,
                    **optimal_results
                })
                print(f"{method} optimization successful. LCOE: {lcoe:.6f}, Iterations: {iterations}, Time: {duration:.2f} seconds")
            else:
                print(f"{method} optimization failed to converge or was stopped early.")

    # Saving and summarizing results
    if optimization_results:
        optimization_df = pd.DataFrame(optimization_results)
        output_dir = "./optimisation_results"
        os.makedirs(output_dir, exist_ok=True)
        optimization_df.to_csv(os.path.join(output_dir, "optimisation_results_Powell.csv"), index=False)
        print("\nOptimization comparison results are saved in the 'optimisation_results' directory.")

        # Best results per deposit
        best_results = optimization_df.loc[optimization_df.groupby('Deposit UID')['LCOE'].idxmin()]
        print("\nBest results for each deposit:")
        print(best_results[['Method', 'Iterations', 'Duration (seconds)', 'LCOE']])

        # Method performance summary
        method_performance = optimization_df.groupby('Method').agg({
            'Iterations': ['median', 'min', 'max'],
            'Duration (seconds)': ['median', 'min', 'max'],
            'LCOE': ['median', 'min', 'max', 'std']
        }).sort_values(('LCOE', 'median'))
        print("\nMethod performance summary:")
        print(method_performance)

        # Number of times each method found the best solution
        best_method_counts = optimization_df.loc[optimization_df.groupby('Deposit UID')['LCOE'].idxmin()]['Method'].value_counts()
        print("\nNumber of times each method found the best solution:")
        print(best_method_counts)

        # Success rate of each method (%)
        unique_deposits = optimization_df['Deposit UID'].nunique()
        success_rate = (optimization_df.groupby('Method')['LCOE'].count() / unique_deposits) * 100
        print("\nSuccess rate of each method (%):")
        print(success_rate)
    else:
        print("No successful optimization results to save.")
# Out:
# /home/z5142067/miniconda3/envs/microgrid/lib/python3.8/site-packages/hopp/examples/parallel_simulations/optimisation_methods/log/hybrid_systems_2024-10-02T20.03.19.165757.log
#
# Hybrid microgrid simulation and optimization at ore deposit (Lat: -31.1629, Lon: 145.6538) starts:
# Solar data downloaded and saved to /home/z5142067/miniconda3/envs/microgrid/lib/python3.8/site-packages/hopp/simulation/resource_files/solar/-31.1629_145.6538_psmv3_60_2020.csv.
# Wind data downloaded successfully and saved to /home/z5142067/miniconda3/envs/microgrid/lib/python3.8/site-packages/hopp/simulation/resource_files/wind/-31.1629_145.6538_NASA_2020_60min_50m.srw.
# YAML configuration updated successfully at ../input_yaml/input_file_chunk_3.yaml.
#
# Testing optimization method: Powell
# Iteration 1: Objective Value (LCOE) = 0.2635514661672161, Parameters = [27500, 27, 22500, 7500, 23500], Time = 10.53 seconds
# Iteration 2: Objective Value (LCOE) = 0.26104112520346945, Parameters = [23369, 27, 22500, 7500, 23500], Time = 21.22 seconds
# Iteration 3: Objective Value (LCOE) = 0.26670171543085575, Parameters = [31631, 27, 22500, 7500, 23500], Time = 31.79 seconds
# Iteration 4: Objective Value (LCOE) = 0.26024403105837374, Parameters = [18262, 27, 22500, 7500, 23500], Time = 42.31 seconds
# Iteration 5: Objective Value (LCOE) = 0.2601795936845499, Parameters = [18843, 27, 22500, 7500, 23500], Time = 52.90 seconds
# Iteration 6: Objective Value (LCOE) = 0.2600393214491231, Parameters = [19493, 27, 22500, 7500, 23500], Time = 63.45 seconds
# Iteration 7: Objective Value (LCOE) = 0.2600132097234715, Parameters = [20973, 27, 22500, 7500, 23500], Time = 74.21 seconds
# Iteration 8: Objective Value (LCOE) = 0.25988227580714857, Parameters = [20328, 27, 22500, 7500, 23500], Time = 84.84 seconds
# Iteration 9: Objective Value (LCOE) = 0.25989195579641367, Parameters = [20267, 27, 22500, 7500, 23500], Time = 95.62 seconds
# Iteration 10: Objective Value (LCOE) = 0.2599594122803563, Parameters = [20452, 27, 22500, 7500, 23500], Time = 106.35 seconds
# Iteration 11: Objective Value (LCOE) = 0.2598729886148554, Parameters = [20316, 27, 22500, 7500, 23500], Time = 117.07 seconds
# Iteration 12: Objective Value (LCOE) = 0.25989921078142986, Parameters = [20301, 27, 22500, 7500, 23500], Time = 127.74 seconds
# Iteration 13: Objective Value (LCOE) = 0.25990614474061624, Parameters = [20310, 27, 22500, 7500, 23500], Time = 138.52 seconds
# Iteration 14: Objective Value (LCOE) = 0.2598760843456198, Parameters = [20320, 27, 22500, 7500, 23500], Time = 149.25 seconds
# Iteration 15: Objective Value (LCOE) = 0.25989033586495935, Parameters = [20314, 27, 22500, 7500, 23500], Time = 160.01 seconds
# Iteration 16: Objective Value (LCOE) = 0.2598745364802376, Parameters = [20318, 27, 22500, 7500, 23500], Time = 170.68 seconds
# Iteration 17: Objective Value (LCOE) = 0.2598911076479567, Parameters = [20315, 27, 22500, 7500, 23500], Time = 181.46 seconds
# Iteration 18: Objective Value (LCOE) = 0.25987376254754657, Parameters = [20317, 27, 22500, 7500, 23500], Time = 192.28 seconds
# Iteration 19: Objective Value (LCOE) = 0.2598729886148554, Parameters = [20316, 27, 22500, 7500, 23500], Time = 203.00 seconds
# Iteration 20: Objective Value (LCOE) = 0.2598729886148554, Parameters = [20316, 27, 22500, 7500, 23500], Time = 213.79 seconds
# Iteration 21: Objective Value (LCOE) = 0.2598729886148554, Parameters = [20316, 27, 22500, 7500, 23500], Time = 224.52 seconds
# Iteration 22: Objective Value (LCOE) = 0.2598729886148554, Parameters = [20316, 27, 22500, 7500, 23500], Time = 235.26 seconds
# Iteration 23: Objective Value (LCOE) = 0.2598729886148554, Parameters = [20316, 27, 22500, 7500, 23500], Time = 246.02 seconds
# Iteration 24: Objective Value (LCOE) = 0.2598729886148554, Parameters = [20316, 27, 22500, 7500, 23500], Time = 256.80 seconds
# Iteration 25: Objective Value (LCOE) = 0.2598729886148554, Parameters = [20316, 27, 22500, 7500, 23500], Time = 267.60 seconds
# Iteration 26: Objective Value (LCOE) = 0.2598729886148554, Parameters = [20316, 27, 22500, 7500, 23500], Time = 278.27 seconds
# Iteration 27: Objective Value (LCOE) = 0.2598729886148554, Parameters = [20316, 27, 22500, 7500, 23500], Time = 289.02 seconds
# Iteration 28: Objective Value (LCOE) = 0.2598729886148554, Parameters = [20316, 27, 22500, 7500, 23500], Time = 299.80 seconds
# Iteration 29: Objective Value (LCOE) = 0.2598729886148554, Parameters = [20316, 27, 22500, 7500, 23500], Time = 310.63 seconds
# Iteration 30: Objective Value (LCOE) = 0.2598729886148554, Parameters = [20316, 27, 22500, 7500, 23500], Time = 321.37 seconds
# Iteration 31: Objective Value (LCOE) = 0.2598729886148554, Parameters = [20316, 27, 22500, 7500, 23500], Time = 332.21 seconds
# Iteration 32: Objective Value (LCOE) = 0.2598729886148554, Parameters = [20316, 27, 22500, 7500, 23500], Time = 343.00 seconds
# Iteration 33: Objective Value (LCOE) = 0.2598729886148554, Parameters = [20316, 27, 22500, 7500, 23500], Time = 353.75 seconds
# Iteration 34: Objective Value (LCOE) = 0.2598729886148554, Parameters = [20316, 27, 22500, 7500, 23500], Time = 364.44 seconds
# Iteration 35: Objective Value (LCOE) = 0.2640524495540045, Parameters = [20316, 23, 22500, 7500, 23500], Time = 375.18 seconds
# Iteration 36: Objective Value (LCOE) = 0.2571935328269134, Parameters = [20316, 32, 22500, 7500, 23500], Time = 386.07 seconds
# Iteration 37: Objective Value (LCOE) = 0.25686048132586997, Parameters = [20316, 37, 22500, 7500, 23500], Time = 396.94 seconds
# Iteration 38: Objective Value (LCOE) = 0.25645343297646783, Parameters = [20316, 35, 22500, 7500, 23500], Time = 407.84 seconds
# Iteration 39: Objective Value (LCOE) = 0.25645343297646783, Parameters = [20316, 35, 22500, 7500, 23500], Time = 418.60 seconds
# Iteration 40: Objective Value (LCOE) = 0.25645343297646783, Parameters = [20316, 35, 22500, 7500, 23500], Time = 429.42 seconds
# Iteration 41: Objective Value (LCOE) = 0.25645343297646783, Parameters = [20316, 35, 22500, 7500, 23500], Time = 440.30 seconds
# Iteration 42: Objective Value (LCOE) = 0.25645343297646783, Parameters = [20316, 35, 22500, 7500, 23500], Time = 451.11 seconds
# Iteration 43: Objective Value (LCOE) = 0.25645343297646783, Parameters = [20316, 35, 22500, 7500, 23500], Time = 461.97 seconds
# Iteration 44: Objective Value (LCOE) = 0.25645343297646783, Parameters = [20316, 35, 22500, 7500, 23500], Time = 472.71 seconds
# Iteration 45: Objective Value (LCOE) = 0.25645343297646783, Parameters = [20316, 35, 22500, 7500, 23500], Time = 483.36 seconds
# Iteration 46: Objective Value (LCOE) = 0.25645343297646783, Parameters = [20316, 35, 22500, 7500, 23500], Time = 494.04 seconds
# Iteration 47: Objective Value (LCOE) = 0.25645343297646783, Parameters = [20316, 35, 22500, 7500, 23500], Time = 504.71 seconds
# Iteration 48: Objective Value (LCOE) = 0.25645343297646783, Parameters = [20316, 35, 22500, 7500, 23500], Time = 515.42 seconds
# Iteration 49: Objective Value (LCOE) = 0.25645343297646783, Parameters = [20316, 35, 22500, 7500, 23500], Time = 526.17 seconds
# Iteration 50: Objective Value (LCOE) = 0.25645343297646783, Parameters = [20316, 35, 22500, 7500, 23500], Time = 536.88 seconds
# Iteration 51: Objective Value (LCOE) = 0.25645343297646783, Parameters = [20316, 35, 22500, 7500, 23500], Time = 547.59 seconds
# Iteration 52: Objective Value (LCOE) = 0.25645343297646783, Parameters = [20316, 35, 22500, 7500, 23500], Time = 558.36 seconds
# Iteration 53: Objective Value (LCOE) = 0.25645343297646783, Parameters = [20316, 35, 22500, 7500, 23500], Time = 569.17 seconds
# Iteration 54: Objective Value (LCOE) = 0.25645343297646783, Parameters = [20316, 35, 22500, 7500, 23500], Time = 579.93 seconds
# Iteration 55: Objective Value (LCOE) = 0.25645343297646783, Parameters = [20316, 35, 22500, 7500, 23500], Time = 590.79 seconds
# Iteration 56: Objective Value (LCOE) = 0.25645343297646783, Parameters = [20316, 35, 22500, 7500, 23500], Time = 601.47 seconds
# Iteration 57: Objective Value (LCOE) = 0.25645343297646783, Parameters = [20316, 35, 22500, 7500, 23500], Time = 612.07 seconds
# Iteration 58: Objective Value (LCOE) = 0.25645343297646783, Parameters = [20316, 35, 22500, 7500, 23500], Time = 622.73 seconds
# Iteration 59: Objective Value (LCOE) = 0.25645343297646783, Parameters = [20316, 35, 22500, 7500, 23500], Time = 633.45 seconds
# Iteration 60: Objective Value (LCOE) = 0.25645343297646783, Parameters = [20316, 35, 22500, 7500, 23500], Time = 644.10 seconds
# Iteration 61: Objective Value (LCOE) = 0.255179585569487, Parameters = [20316, 35, 20729, 7500, 23500], Time = 654.82 seconds
# Iteration 62: Objective Value (LCOE) = 0.25772728038344866, Parameters = [20316, 35, 24271, 7500, 23500], Time = 665.38 seconds
# Iteration 63: Objective Value (LCOE) = 0.25360579780750275, Parameters = [20316, 35, 18541, 7500, 23500], Time = 676.05 seconds
# Iteration 64: Objective Value (LCOE) = 0.25263261003695214, Parameters = [20316, 35, 17188, 7500, 23500], Time = 686.78 seconds
# Iteration 65: Objective Value (LCOE) = 0.25203201004551856, Parameters = [20316, 35, 16353, 7500, 23500], Time = 697.47 seconds
# Iteration 66: Objective Value (LCOE) = 0.2516601415478285, Parameters = [20316, 35, 15836, 7500, 23500], Time = 708.18 seconds
# Iteration 67: Objective Value (LCOE) = 0.251430690772658, Parameters = [20316, 35, 15517, 7500, 23500], Time = 718.93 seconds
# Iteration 68: Objective Value (LCOE) = 0.2512882730501384, Parameters = [20316, 35, 15319, 7500, 23500], Time = 729.65 seconds
# Iteration 69: Objective Value (LCOE) = 0.2512005207160607, Parameters = [20316, 35, 15197, 7500, 23500], Time = 740.31 seconds
# Iteration 70: Objective Value (LCOE) = 0.2511465746090457, Parameters = [20316, 35, 15122, 7500, 23500], Time = 750.97 seconds
# Iteration 71: Objective Value (LCOE) = 0.25111276838198293, Parameters = [20316, 35, 15075, 7500, 23500], Time = 761.68 seconds
# Iteration 72: Objective Value (LCOE) = 0.2510926285020307, Parameters = [20316, 35, 15047, 7500, 23500], Time = 772.43 seconds
# Iteration 73: Objective Value (LCOE) = 0.2510796814363471, Parameters = [20316, 35, 15029, 7500, 23500], Time = 783.13 seconds
# Iteration 74: Objective Value (LCOE) = 0.25107176934065156, Parameters = [20316, 35, 15018, 7500, 23500], Time = 793.87 seconds
# Iteration 75: Objective Value (LCOE) = 0.2510667343706635, Parameters = [20316, 35, 15011, 7500, 23500], Time = 804.43 seconds
# Iteration 76: Objective Value (LCOE) = 0.251063857244956, Parameters = [20316, 35, 15007, 7500, 23500], Time = 815.06 seconds
# Iteration 77: Objective Value (LCOE) = 0.2510616994006754, Parameters = [20316, 35, 15004, 7500, 23500], Time = 825.76 seconds
# Iteration 78: Objective Value (LCOE) = 0.25106098011924854, Parameters = [20316, 35, 15003, 7500, 23500], Time = 836.37 seconds
# Iteration 79: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 7500, 23500], Time = 847.08 seconds
# Iteration 80: Objective Value (LCOE) = 0.2510602608378217, Parameters = [20316, 35, 15002, 7500, 23500], Time = 857.62 seconds
# Iteration 81: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 7500, 23500], Time = 868.28 seconds
# Iteration 82: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 7500, 23500], Time = 879.02 seconds
# Iteration 83: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 7500, 23500], Time = 889.79 seconds
# Iteration 84: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 7500, 23500], Time = 900.46 seconds
# Iteration 85: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 7500, 23500], Time = 911.20 seconds
# Iteration 86: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 7500, 23500], Time = 921.88 seconds
# Iteration 87: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 7500, 23500], Time = 932.61 seconds
# Iteration 88: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 7500, 23500], Time = 943.22 seconds
# Iteration 89: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 7500, 23500], Time = 953.89 seconds
# Iteration 90: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 7500, 23500], Time = 964.64 seconds
# Iteration 91: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 7500, 23500], Time = 975.39 seconds
# Iteration 92: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 7500, 23500], Time = 986.08 seconds
# Iteration 93: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 7500, 23500], Time = 996.69 seconds
# Iteration 94: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 7500, 23500], Time = 1007.37 seconds
# Iteration 95: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 7500, 23500], Time = 1018.09 seconds
# Iteration 96: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 7500, 23500], Time = 1028.73 seconds
# Iteration 97: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 6910, 23500], Time = 1039.43 seconds
# Iteration 98: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 8090, 23500], Time = 1050.05 seconds
# Iteration 99: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 8820, 23500], Time = 1060.67 seconds
# Iteration 100: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 9271, 23500], Time = 1071.44 seconds
# Iteration 101: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 9549, 23500], Time = 1082.14 seconds
# Iteration 102: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 9721, 23500], Time = 1092.83 seconds
# Iteration 103: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 9828, 23500], Time = 1103.54 seconds
# Iteration 104: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 9894, 23500], Time = 1114.23 seconds
# Iteration 105: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 9934, 23500], Time = 1124.93 seconds
# Iteration 106: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 9959, 23500], Time = 1135.49 seconds
# Iteration 107: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 9975, 23500], Time = 1146.17 seconds
# Iteration 108: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 9984, 23500], Time = 1156.93 seconds
# Iteration 109: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 9990, 23500], Time = 1167.66 seconds
# Iteration 110: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 9994, 23500], Time = 1178.71 seconds
# Iteration 111: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 9996, 23500], Time = 1189.42 seconds
# Iteration 112: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 9998, 23500], Time = 1200.15 seconds
# Iteration 113: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 9999, 23500], Time = 1210.86 seconds
# Iteration 114: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 9999, 23500], Time = 1221.63 seconds
# Iteration 115: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 9999, 23500], Time = 1232.50 seconds
# Iteration 116: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 10000, 23500], Time = 1243.37 seconds
# Iteration 117: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 10000, 23500], Time = 1254.22 seconds
# Iteration 118: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 10000, 23500], Time = 1265.01 seconds
# Iteration 119: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 10000, 23500], Time = 1275.87 seconds
# Iteration 120: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 10000, 23500], Time = 1286.73 seconds
# Iteration 121: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 10000, 23500], Time = 1297.66 seconds
# Iteration 122: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 10000, 23500], Time = 1308.50 seconds
# Iteration 123: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 10000, 23500], Time = 1319.21 seconds
# Iteration 124: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 10000, 23500], Time = 1330.06 seconds
# Iteration 125: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 10000, 23500], Time = 1340.81 seconds
# Iteration 126: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 10000, 23500], Time = 1351.63 seconds
# Iteration 127: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 10000, 23500], Time = 1362.45 seconds
# Iteration 128: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 10000, 23500], Time = 1373.41 seconds
# Iteration 129: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 10000, 23500], Time = 1384.33 seconds
# Iteration 130: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 10000, 23500], Time = 1395.06 seconds
# Iteration 131: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 10000, 23500], Time = 1406.09 seconds
# Iteration 132: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 10000, 23500], Time = 1416.98 seconds
# Iteration 133: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 10000, 23500], Time = 1427.72 seconds
# Iteration 134: Objective Value (LCOE) = 0.2510595415563948, Parameters = [20316, 35, 15001, 10000, 23500], Time = 1438.53 seconds
# Iteration 135: Objective Value (LCOE) = 0.2464116603148749, Parameters = [20316, 35, 15001, 10000, 21966], Time = 1449.23 seconds
# Iteration 136: Objective Value (LCOE) = 0.25570742279791475, Parameters = [20316, 35, 15001, 10000, 25034], Time = 1460.07 seconds
# Iteration 137: Objective Value (LCOE) = 0.2406639219086406, Parameters = [20316, 35, 15001, 10000, 20069], Time = 1470.89 seconds
# Iteration 138: Objective Value (LCOE) = 0.23711286792229033, Parameters = [20316, 35, 15001, 10000, 18897], Time = 1481.84 seconds
# Iteration 139: Objective Value (LCOE) = 0.23491618350240634, Parameters = [20316, 35, 15001, 10000, 18172], Time = 1492.76 seconds
# Iteration 140: Objective Value (LCOE) = 0.23355878402639535, Parameters = [20316, 35, 15001, 10000, 17724], Time = 1503.55 seconds
# Iteration 141: Objective Value (LCOE) = 0.23272252899206713, Parameters = [20316, 35, 15001, 10000, 17448], Time = 1514.40 seconds
# Iteration 142: Objective Value (LCOE) = 0.23220441445992898, Parameters = [20316, 35, 15001, 10000, 17277], Time = 1525.25 seconds
# Iteration 143: Objective Value (LCOE) = 0.2318832440481942, Parameters = [20316, 35, 15001, 10000, 17171], Time = 1535.97 seconds
# Iteration 144: Objective Value (LCOE) = 0.23168629992779083, Parameters = [20316, 35, 15001, 10000, 17106], Time = 1546.80 seconds
# Iteration 145: Objective Value (LCOE) = 0.23156207363645945, Parameters = [20316, 35, 15001, 10000, 17065], Time = 1557.51 seconds
# Iteration 146: Objective Value (LCOE) = 0.2314863258978428, Parameters = [20316, 35, 15001, 10000, 17040], Time = 1568.33 seconds
# Iteration 147: Objective Value (LCOE) = 0.23144087725467277, Parameters = [20316, 35, 15001, 10000, 17025], Time = 1579.08 seconds
# Iteration 148: Objective Value (LCOE) = 0.23141057815922608, Parameters = [20316, 35, 15001, 10000, 17015], Time = 1589.88 seconds
# Iteration 149: Objective Value (LCOE) = 0.23139542861150278, Parameters = [20316, 35, 15001, 10000, 17010], Time = 1600.74 seconds
# Iteration 150: Objective Value (LCOE) = 0.23138330897332407, Parameters = [20316, 35, 15001, 10000, 17006], Time = 1611.65 seconds
# Iteration 151: Objective Value (LCOE) = 0.23137724915423474, Parameters = [20316, 35, 15001, 10000, 17004], Time = 1622.52 seconds
# Iteration 152: Objective Value (LCOE) = 0.23137118933514542, Parameters = [20316, 35, 15001, 10000, 17002], Time = 1633.29 seconds
# Iteration 153: Objective Value (LCOE) = 0.23136815942560077, Parameters = [20316, 35, 15001, 10000, 17001], Time = 1644.09 seconds
# Iteration 154: Objective Value (LCOE) = 0.23136815942560077, Parameters = [20316, 35, 15001, 10000, 17001], Time = 1654.80 seconds
# Iteration 155: Objective Value (LCOE) = 0.23136815942560077, Parameters = [20316, 35, 15001, 10000, 17001], Time = 1665.62 seconds
# Iteration 156: Objective Value (LCOE) = 0.23136815942560077, Parameters = [20316, 35, 15001, 10000, 17001], Time = 1676.40 seconds
# Iteration 157: Objective Value (LCOE) = 0.23136815942560077, Parameters = [20316, 35, 15001, 10000, 17001], Time = 1687.20 seconds
# Iteration 158: Objective Value (LCOE) = 0.23136815942560077, Parameters = [20316, 35, 15001, 10000, 17001], Time = 1697.91 seconds
# Iteration 159: Objective Value (LCOE) = 0.23136815942560077, Parameters = [20316, 35, 15001, 10000, 17001], Time = 1708.71 seconds
# Iteration 160: Objective Value (LCOE) = 0.23136815942560077, Parameters = [20316, 35, 15001, 10000, 17001], Time = 1719.55 seconds
# Iteration 161: Objective Value (LCOE) = 0.23136815942560077, Parameters = [20316, 35, 15001, 10000, 17001], Time = 1730.54 seconds
# Iteration 162: Objective Value (LCOE) = 0.23136815942560077, Parameters = [20316, 35, 15001, 10000, 17001], Time = 1741.42 seconds
# Iteration 163: Objective Value (LCOE) = 0.23136815942560077, Parameters = [20316, 35, 15001, 10000, 17001], Time = 1752.22 seconds
# Iteration 164: Objective Value (LCOE) = 0.23136815942560077, Parameters = [20316, 35, 15001, 10000, 17001], Time = 1763.02 seconds
# Iteration 165: Objective Value (LCOE) = 0.23136815942560077, Parameters = [20316, 35, 15001, 10000, 17001], Time = 1773.76 seconds
# Iteration 166: Objective Value (LCOE) = 0.23136815942560077, Parameters = [20316, 35, 15001, 10000, 17001], Time = 1784.57 seconds
# Iteration 167: Objective Value (LCOE) = 0.23136815942560077, Parameters = [20316, 35, 15001, 10000, 17001], Time = 1795.27 seconds
# Iteration 168: Objective Value (LCOE) = 0.23136815942560077, Parameters = [20316, 35, 15001, 10000, 17001], Time = 1806.09 seconds
# Iteration 169: Objective Value (LCOE) = 0.23136815942560077, Parameters = [20316, 35, 15001, 10000, 17001], Time = 1816.82 seconds
# Iteration 170: Objective Value (LCOE) = 0.23136815942560077, Parameters = [20316, 35, 15001, 10000, 17001], Time = 1827.60 seconds
# Iteration 171: Objective Value (LCOE) = 0.23136815942560077, Parameters = [20316, 35, 15001, 10000, 17001], Time = 1838.45 seconds
# Iteration 172: Objective Value (LCOE) = 0.2732742136433076, Parameters = [29196, 25, 24270, 6910, 25034], Time = 1849.30 seconds
# Iteration 173: Objective Value (LCOE) = 0.25509748583260006, Parameters = [25804, 29, 20730, 8090, 21966], Time = 1860.09 seconds
# Iteration 174: Objective Value (LCOE) = 0.24534243908689696, Parameters = [23708, 31, 18541, 8820, 20069], Time = 1870.82 seconds
# Iteration 175: Objective Value (LCOE) = 0.2399873846943091, Parameters = [22412, 32, 17189, 9271, 18897], Time = 1881.56 seconds
# Iteration 176: Objective Value (LCOE) = 0.2363090863693835, Parameters = [21611, 33, 16353, 9549, 18173], Time = 1892.26 seconds
# Iteration 177: Objective Value (LCOE) = 0.2344058966380114, Parameters = [21116, 34, 15836, 9721, 17725], Time = 1903.02 seconds
# Iteration 178: Objective Value (LCOE) = 0.23314528648567254, Parameters = [20811, 34, 15517, 9828, 17449], Time = 1913.75 seconds
# Iteration 179: Objective Value (LCOE) = 0.23237657479844645, Parameters = [20621, 34, 15320, 9894, 17278], Time = 1924.55 seconds
# Iteration 180: Objective Value (LCOE) = 0.23188088718835334, Parameters = [20505, 34, 15198, 9934, 17172], Time = 1935.29 seconds
# Iteration 181: Objective Value (LCOE) = 0.23160839600891714, Parameters = [20432, 34, 15123, 9959, 17107], Time = 1946.04 seconds
# Iteration 182: Objective Value (LCOE) = 0.2314260930054882, Parameters = [20388, 34, 15076, 9975, 17066], Time = 1956.88 seconds
# Iteration 183: Objective Value (LCOE) = 0.23155883973332156, Parameters = [20360, 35, 15047, 9984, 17041], Time = 1967.86 seconds
# Iteration 184: Objective Value (LCOE) = 0.23145071453081686, Parameters = [20394, 34, 15082, 9973, 17071], Time = 1978.72 seconds
# Iteration 185: Objective Value (LCOE) = 0.23140608661784431, Parameters = [20383, 34, 15071, 9977, 17062], Time = 1989.45 seconds
# Iteration 186: Objective Value (LCOE) = 0.2313676196794611, Parameters = [20374, 34, 15062, 9980, 17054], Time = 2000.25 seconds
# Iteration 187: Objective Value (LCOE) = 0.2315832937379172, Parameters = [20369, 35, 15056, 9981, 17049], Time = 2010.99 seconds
# Iteration 188: Objective Value (LCOE) = 0.23138229164799318, Parameters = [20378, 34, 15065, 9978, 17057], Time = 2021.74 seconds
# Iteration 189: Objective Value (LCOE) = 0.23159774130501917, Parameters = [20372, 35, 15060, 9980, 17052], Time = 2032.49 seconds
# Iteration 190: Objective Value (LCOE) = 0.23137223481714594, Parameters = [20375, 34, 15063, 9979, 17055], Time = 2043.32 seconds
# Iteration 191: Objective Value (LCOE) = 0.2316023174002442, Parameters = [20373, 35, 15061, 9980, 17053], Time = 2054.08 seconds
# Iteration 192: Objective Value (LCOE) = 0.2313684462349386, Parameters = [20375, 34, 15062, 9979, 17054], Time = 2064.84 seconds
# Iteration 193: Objective Value (LCOE) = 0.2313676196794611, Parameters = [20374, 34, 15062, 9980, 17054], Time = 2075.68 seconds
# Iteration 194: Objective Value (LCOE) = 0.2313676196794611, Parameters = [20374, 34, 15062, 9980, 17054], Time = 2086.60 seconds
# Iteration 195: Objective Value (LCOE) = 0.2313676196794611, Parameters = [20374, 34, 15062, 9980, 17054], Time = 2097.51 seconds
# Iteration 196: Objective Value (LCOE) = 0.23325791334384505, Parameters = [23369, 34, 15062, 9980, 17054], Time = 2108.31 seconds
# Iteration 197: Objective Value (LCOE) = 0.23974703478602705, Parameters = [31631, 34, 15062, 9980, 17054], Time = 2119.12 seconds
# Iteration 198: Objective Value (LCOE) = 0.23100948066467716, Parameters = [18262, 34, 15062, 9980, 17054], Time = 2129.85 seconds
# Iteration 199: Objective Value (LCOE) = 0.23302530902234236, Parameters = [12286, 34, 15062, 9980, 17054], Time = 2140.65 seconds
# Iteration 200: Objective Value (LCOE) = 0.23095343492466117, Parameters = [17678, 34, 15062, 9980, 17054], Time = 2151.37 seconds
# Iteration 201: Objective Value (LCOE) = 0.2309121665900107, Parameters = [17373, 34, 15062, 9980, 17054], Time = 2162.20 seconds
# Iteration 202: Objective Value (LCOE) = 0.2312217936698071, Parameters = [15430, 34, 15062, 9980, 17054], Time = 2172.96 seconds
# Iteration 203: Objective Value (LCOE) = 0.23094169203135248, Parameters = [16631, 34, 15062, 9980, 17054], Time = 2183.73 seconds
# Iteration 204: Objective Value (LCOE) = 0.2309231427896729, Parameters = [17121, 34, 15062, 9980, 17054], Time = 2194.60 seconds
# Iteration 205: Objective Value (LCOE) = 0.23093009215612798, Parameters = [17490, 34, 15062, 9980, 17054], Time = 2205.53 seconds
# Iteration 206: Objective Value (LCOE) = 0.2309284834606946, Parameters = [17288, 34, 15062, 9980, 17054], Time = 2216.47 seconds
# Iteration 207: Objective Value (LCOE) = 0.23092636759020546, Parameters = [17418, 34, 15062, 9980, 17054], Time = 2227.29 seconds
# Iteration 208: Objective Value (LCOE) = 0.23091979292365955, Parameters = [17341, 34, 15062, 9980, 17054], Time = 2238.11 seconds
# Iteration 209: Objective Value (LCOE) = 0.2309227096812654, Parameters = [17390, 34, 15062, 9980, 17054], Time = 2248.85 seconds
# Iteration 210: Objective Value (LCOE) = 0.23092029832291144, Parameters = [17364, 34, 15062, 9980, 17054], Time = 2259.66 seconds
# Iteration 211: Objective Value (LCOE) = 0.2309165078628803, Parameters = [17380, 34, 15062, 9980, 17054], Time = 2270.41 seconds
# Iteration 212: Objective Value (LCOE) = 0.2309103060444952, Parameters = [17370, 34, 15062, 9980, 17054], Time = 2281.26 seconds
# Iteration 213: Objective Value (LCOE) = 0.23090844549897965, Parameters = [17367, 34, 15062, 9980, 17054], Time = 2291.98 seconds
# Iteration 214: Objective Value (LCOE) = 0.23090782531714116, Parameters = [17366, 34, 15062, 9980, 17054], Time = 2302.75 seconds
# Iteration 215: Objective Value (LCOE) = 0.23092091657447758, Parameters = [17365, 34, 15062, 9980, 17054], Time = 2313.62 seconds
# Iteration 216: Objective Value (LCOE) = 0.23090782531714116, Parameters = [17366, 34, 15062, 9980, 17054], Time = 2324.53 seconds
# Iteration 217: Objective Value (LCOE) = 0.23090782531714116, Parameters = [17366, 34, 15062, 9980, 17054], Time = 2335.45 seconds
# Iteration 218: Objective Value (LCOE) = 0.23090782531714116, Parameters = [17366, 34, 15062, 9980, 17054], Time = 2346.26 seconds
# Iteration 219: Objective Value (LCOE) = 0.23090782531714116, Parameters = [17366, 34, 15062, 9980, 17054], Time = 2357.09 seconds
# Iteration 220: Objective Value (LCOE) = 0.23090782531714116, Parameters = [17366, 34, 15062, 9980, 17054], Time = 2367.84 seconds
# Iteration 221: Objective Value (LCOE) = 0.23090782531714116, Parameters = [17366, 34, 15062, 9980, 17054], Time = 2378.64 seconds
# Iteration 222: Objective Value (LCOE) = 0.23090782531714116, Parameters = [17366, 34, 15062, 9980, 17054], Time = 2389.36 seconds
# Iteration 223: Objective Value (LCOE) = 0.23090782531714116, Parameters = [17366, 34, 15062, 9980, 17054], Time = 2400.22 seconds
# Iteration 224: Objective Value (LCOE) = 0.23090782531714116, Parameters = [17366, 34, 15062, 9980, 17054], Time = 2410.98 seconds
# Iteration 225: Objective Value (LCOE) = 0.23090782531714116, Parameters = [17366, 34, 15062, 9980, 17054], Time = 2421.83 seconds
# Iteration 226: Objective Value (LCOE) = 0.23090782531714116, Parameters = [17366, 34, 15062, 9980, 17054], Time = 2432.75 seconds
# Iteration 227: Objective Value (LCOE) = 0.23090782531714116, Parameters = [17366, 34, 15062, 9980, 17054], Time = 2443.77 seconds
# Iteration 228: Objective Value (LCOE) = 0.23090782531714116, Parameters = [17366, 34, 15062, 9980, 17054], Time = 2454.68 seconds
# Iteration 229: Objective Value (LCOE) = 0.23090782531714116, Parameters = [17366, 34, 15062, 9980, 17054], Time = 2465.46 seconds
# Iteration 230: Objective Value (LCOE) = 0.23090782531714116, Parameters = [17366, 34, 15062, 9980, 17054], Time = 2476.26 seconds
# Iteration 231: Objective Value (LCOE) = 0.23090782531714116, Parameters = [17366, 34, 15062, 9980, 17054], Time = 2487.03 seconds
# Iteration 232: Objective Value (LCOE) = 0.23090782531714116, Parameters = [17366, 34, 15062, 9980, 17054], Time = 2497.89 seconds
# Iteration 233: Objective Value (LCOE) = 0.23090782531714116, Parameters = [17366, 34, 15062, 9980, 17054], Time = 2508.59 seconds
# Iteration 234: Objective Value (LCOE) = 0.23090782531714116, Parameters = [17366, 34, 15062, 9980, 17054], Time = 2519.41 seconds
# Iteration 235: Objective Value (LCOE) = 0.23605079345626423, Parameters = [17366, 23, 15062, 9980, 17054], Time = 2530.02 seconds
# Iteration 236: Objective Value (LCOE) = 0.2312249568400775, Parameters = [17366, 32, 15062, 9980, 17054], Time = 2540.77 seconds
# Iteration 237: Objective Value (LCOE) = 0.2318497271621586, Parameters = [17366, 37, 15062, 9980, 17054], Time = 2551.66 seconds
# Iteration 238: Objective Value (LCOE) = 0.2308762524266059, Parameters = [17366, 33, 15062, 9980, 17054], Time = 2562.63 seconds
# Iteration 239: Objective Value (LCOE) = 0.23090782531714116, Parameters = [17366, 34, 15062, 9980, 17054], Time = 2573.53 seconds
# Iteration 240: Objective Value (LCOE) = 0.2308762524266059, Parameters = [17366, 33, 15062, 9980, 17054], Time = 2584.34 seconds
# Iteration 241: Objective Value (LCOE) = 0.2308762524266059, Parameters = [17366, 33, 15062, 9980, 17054], Time = 2595.16 seconds
# Iteration 242: Objective Value (LCOE) = 0.2308762524266059, Parameters = [17366, 33, 15062, 9980, 17054], Time = 2605.84 seconds
# Iteration 243: Objective Value (LCOE) = 0.2308762524266059, Parameters = [17366, 33, 15062, 9980, 17054], Time = 2616.62 seconds
# Iteration 244: Objective Value (LCOE) = 0.2308762524266059, Parameters = [17366, 33, 15062, 9980, 17054], Time = 2627.35 seconds
# Iteration 245: Objective Value (LCOE) = 0.2308762524266059, Parameters = [17366, 33, 15062, 9980, 17054], Time = 2638.23 seconds
# Iteration 246: Objective Value (LCOE) = 0.2308762524266059, Parameters = [17366, 33, 15062, 9980, 17054], Time = 2648.97 seconds
# Iteration 247: Objective Value (LCOE) = 0.2308762524266059, Parameters = [17366, 33, 15062, 9980, 17054], Time = 2659.75 seconds
# Iteration 248: Objective Value (LCOE) = 0.2308762524266059, Parameters = [17366, 33, 15062, 9980, 17054], Time = 2670.60 seconds
# Iteration 249: Objective Value (LCOE) = 0.2308762524266059, Parameters = [17366, 33, 15062, 9980, 17054], Time = 2681.50 seconds
# Iteration 250: Objective Value (LCOE) = 0.2308762524266059, Parameters = [17366, 33, 15062, 9980, 17054], Time = 2692.45 seconds
# Iteration 251: Objective Value (LCOE) = 0.2308762524266059, Parameters = [17366, 33, 15062, 9980, 17054], Time = 2703.18 seconds
# Iteration 252: Objective Value (LCOE) = 0.2308762524266059, Parameters = [17366, 33, 15062, 9980, 17054], Time = 2713.99 seconds
# Iteration 253: Objective Value (LCOE) = 0.2308762524266059, Parameters = [17366, 33, 15062, 9980, 17054], Time = 2724.71 seconds
# Iteration 254: Objective Value (LCOE) = 0.2308762524266059, Parameters = [17366, 33, 15062, 9980, 17054], Time = 2735.48 seconds
# Iteration 255: Objective Value (LCOE) = 0.2308762524266059, Parameters = [17366, 33, 15062, 9980, 17054], Time = 2746.18 seconds
# Iteration 256: Objective Value (LCOE) = 0.2308762524266059, Parameters = [17366, 33, 15062, 9980, 17054], Time = 2757.03 seconds
# Iteration 257: Objective Value (LCOE) = 0.2308762524266059, Parameters = [17366, 33, 15062, 9980, 17054], Time = 2767.73 seconds
# Iteration 258: Objective Value (LCOE) = 0.2308762524266059, Parameters = [17366, 33, 15062, 9980, 17054], Time = 2778.49 seconds
# Iteration 259: Objective Value (LCOE) = 0.2308762524266059, Parameters = [17366, 33, 15062, 9980, 17054], Time = 2789.40 seconds
# Iteration 260: Objective Value (LCOE) = 0.2308762524266059, Parameters = [17366, 33, 15062, 9980, 17054], Time = 2800.34 seconds
# Iteration 261: Objective Value (LCOE) = 0.2349524202726592, Parameters = [17366, 33, 20729, 9980, 17054], Time = 2811.18 seconds
# Iteration 262: Objective Value (LCOE) = 0.23750011508662083, Parameters = [17366, 33, 24271, 9980, 17054], Time = 2821.99 seconds
# Iteration 263: Objective Value (LCOE) = 0.23337863251067492, Parameters = [17366, 33, 18541, 9980, 17054], Time = 2832.79 seconds
# Iteration 264: Objective Value (LCOE) = 0.23240544474012437, Parameters = [17366, 33, 17188, 9980, 17054], Time = 2843.49 seconds
# Iteration 265: Objective Value (LCOE) = 0.23180484474869073, Parameters = [17366, 33, 16353, 9980, 17054], Time = 2854.31 seconds
# Iteration 266: Objective Value (LCOE) = 0.2314329762510007, Parameters = [17366, 33, 15836, 9980, 17054], Time = 2865.02 seconds
# Iteration 267: Objective Value (LCOE) = 0.2312035254758302, Parameters = [17366, 33, 15517, 9980, 17054], Time = 2875.89 seconds
# Iteration 268: Objective Value (LCOE) = 0.2310611077533106, Parameters = [17366, 33, 15319, 9980, 17054], Time = 2886.59 seconds
# Iteration 269: Objective Value (LCOE) = 0.23097335541923292, Parameters = [17366, 33, 15197, 9980, 17054], Time = 2897.38 seconds
# Iteration 270: Objective Value (LCOE) = 0.2309194093122179, Parameters = [17366, 33, 15122, 9980, 17054], Time = 2908.29 seconds
# Iteration 271: Objective Value (LCOE) = 0.23088560308515513, Parameters = [17366, 33, 15075, 9980, 17054], Time = 2919.19 seconds
# Iteration 272: Objective Value (LCOE) = 0.2308654632052029, Parameters = [17366, 33, 15047, 9980, 17054], Time = 2930.05 seconds
# Iteration 273: Objective Value (LCOE) = 0.2308525161395193, Parameters = [17366, 33, 15029, 9980, 17054], Time = 2940.91 seconds
# Iteration 274: Objective Value (LCOE) = 0.23084460404382376, Parameters = [17366, 33, 15018, 9980, 17054], Time = 2951.69 seconds
# Iteration 275: Objective Value (LCOE) = 0.23083956907383568, Parameters = [17366, 33, 15011, 9980, 17054], Time = 2962.38 seconds
# Iteration 276: Objective Value (LCOE) = 0.2308366919481282, Parameters = [17366, 33, 15007, 9980, 17054], Time = 2973.17 seconds
# Iteration 277: Objective Value (LCOE) = 0.2308345341038476, Parameters = [17366, 33, 15004, 9980, 17054], Time = 2983.83 seconds
# Iteration 278: Objective Value (LCOE) = 0.23083381482242077, Parameters = [17366, 33, 15003, 9980, 17054], Time = 2994.65 seconds
# Iteration 279: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9980, 17054], Time = 3005.28 seconds
# Iteration 280: Objective Value (LCOE) = 0.23083309554099393, Parameters = [17366, 33, 15002, 9980, 17054], Time = 3015.98 seconds
# Iteration 281: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9980, 17054], Time = 3026.79 seconds
# Iteration 282: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9980, 17054], Time = 3037.64 seconds
# Iteration 283: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9980, 17054], Time = 3048.43 seconds
# Iteration 284: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9980, 17054], Time = 3059.19 seconds
# Iteration 285: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9980, 17054], Time = 3069.91 seconds
# Iteration 286: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9980, 17054], Time = 3080.53 seconds
# Iteration 287: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9980, 17054], Time = 3091.28 seconds
# Iteration 288: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9980, 17054], Time = 3101.94 seconds
# Iteration 289: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9980, 17054], Time = 3112.68 seconds
# Iteration 290: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9980, 17054], Time = 3123.34 seconds
# Iteration 291: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9980, 17054], Time = 3134.05 seconds
# Iteration 292: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9980, 17054], Time = 3144.80 seconds
# Iteration 293: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9980, 17054], Time = 3155.62 seconds
# Iteration 294: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9980, 17054], Time = 3166.40 seconds
# Iteration 295: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9980, 17054], Time = 3177.18 seconds
# Iteration 296: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9980, 17054], Time = 3187.90 seconds
# Iteration 297: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9980, 17054], Time = 3198.55 seconds
# Iteration 298: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9980, 17054], Time = 3209.25 seconds
# Iteration 299: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9980, 17054], Time = 3219.86 seconds
# Iteration 300: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9980, 17054], Time = 3230.55 seconds
# Iteration 301: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9980, 17054], Time = 3241.19 seconds
# Iteration 302: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9980, 17054], Time = 3251.85 seconds
# Iteration 303: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9980, 17054], Time = 3262.52 seconds
# Iteration 304: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 6910, 17054], Time = 3273.25 seconds
# Iteration 305: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 8090, 17054], Time = 3283.99 seconds
# Iteration 306: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 8820, 17054], Time = 3294.63 seconds
# Iteration 307: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9271, 17054], Time = 3305.30 seconds
# Iteration 308: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9549, 17054], Time = 3315.90 seconds
# Iteration 309: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9721, 17054], Time = 3326.53 seconds
# Iteration 310: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9828, 17054], Time = 3337.04 seconds
# Iteration 311: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9894, 17054], Time = 3347.70 seconds
# Iteration 312: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9934, 17054], Time = 3358.27 seconds
# Iteration 313: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9959, 17054], Time = 3368.88 seconds
# Iteration 314: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9975, 17054], Time = 3379.54 seconds
# Iteration 315: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9984, 17054], Time = 3390.25 seconds
# Iteration 316: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9990, 17054], Time = 3401.09 seconds
# Iteration 317: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9994, 17054], Time = 3411.71 seconds
# Iteration 318: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9996, 17054], Time = 3422.34 seconds
# Iteration 319: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9998, 17054], Time = 3432.93 seconds
# Iteration 320: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9999, 17054], Time = 3443.58 seconds
# Iteration 321: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9999, 17054], Time = 3454.11 seconds
# Iteration 322: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 9999, 17054], Time = 3464.74 seconds
# Iteration 323: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 10000, 17054], Time = 3475.28 seconds
# Iteration 324: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 10000, 17054], Time = 3485.89 seconds
# Iteration 325: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 10000, 17054], Time = 3496.59 seconds
# Iteration 326: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 10000, 17054], Time = 3507.32 seconds
# Iteration 327: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 10000, 17054], Time = 3518.04 seconds
# Iteration 328: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 10000, 17054], Time = 3528.60 seconds
# Iteration 329: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 10000, 17054], Time = 3539.26 seconds
# Iteration 330: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 10000, 17054], Time = 3549.79 seconds
# Iteration 331: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 10000, 17054], Time = 3560.44 seconds
# Iteration 332: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 10000, 17054], Time = 3570.99 seconds
# Iteration 333: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 10000, 17054], Time = 3581.64 seconds
# Iteration 334: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 10000, 17054], Time = 3592.20 seconds
# Iteration 335: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 10000, 17054], Time = 3602.85 seconds
# Iteration 336: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 10000, 17054], Time = 3613.56 seconds
# Iteration 337: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 10000, 17054], Time = 3624.26 seconds
# Iteration 338: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 10000, 17054], Time = 3634.97 seconds
# Iteration 339: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 10000, 17054], Time = 3645.63 seconds
# Iteration 340: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 10000, 17054], Time = 3656.31 seconds
# Iteration 341: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 10000, 17054], Time = 3666.86 seconds
# Iteration 342: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 10000, 17054], Time = 3677.51 seconds
# Iteration 343: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 10000, 17054], Time = 3688.09 seconds
# Iteration 344: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 10000, 17054], Time = 3698.78 seconds
# Iteration 345: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 10000, 17054], Time = 3709.35 seconds
# Iteration 346: Objective Value (LCOE) = 0.230832376259567, Parameters = [17366, 33, 15001, 10000, 17054], Time = 3719.99 seconds
# Iteration 347: Objective Value (LCOE) = 0.2544400716417253, Parameters = [22832, 27, 20707, 8098, 21999], Time = 3730.60 seconds
# Iteration 348: Objective Value (LCOE) = 0.27166467647066855, Parameters = [26210, 24, 24233, 6922, 25055], Time = 3741.23 seconds
# Iteration 349: Objective Value (LCOE) = 0.24462696928892785, Parameters = [20744, 29, 18527, 8824, 20110], Time = 3751.93 seconds
# Iteration 350: Objective Value (LCOE) = 0.23884175907359226, Parameters = [19453, 31, 17180, 9273, 18943], Time = 3762.36 seconds
# Iteration 351: Objective Value (LCOE) = 0.23597970113158334, Parameters = [18656, 32, 16348, 9551, 18221], Time = 3772.82 seconds
# Iteration 352: Objective Value (LCOE) = 0.23415831784701344, Parameters = [18163, 32, 15833, 9722, 17775], Time = 3783.23 seconds
# Iteration 353: Objective Value (LCOE) = 0.2326457937552036, Parameters = [17858, 33, 15515, 9828, 17500], Time = 3793.75 seconds
# Iteration 354: Objective Value (LCOE) = 0.23193699925395683, Parameters = [17670, 33, 15319, 9894, 17329], Time = 3804.17 seconds
# Iteration 355: Objective Value (LCOE) = 0.23148227516148215, Parameters = [17554, 33, 15197, 9934, 17224], Time = 3814.66 seconds
# Iteration 356: Objective Value (LCOE) = 0.2312446408888371, Parameters = [17482, 33, 15122, 9960, 17159], Time = 3825.07 seconds
# Iteration 357: Objective Value (LCOE) = 0.2310832798106257, Parameters = [17437, 33, 15076, 9975, 17119], Time = 3835.52 seconds
# Iteration 358: Objective Value (LCOE) = 0.23096570882126216, Parameters = [17410, 33, 15047, 9985, 17094], Time = 3846.05 seconds
# Iteration 359: Objective Value (LCOE) = 0.23092170883278332, Parameters = [17393, 33, 15029, 9990, 17079], Time = 3856.85 seconds
# Iteration 360: Objective Value (LCOE) = 0.23087562362490519, Parameters = [17383, 33, 15018, 9994, 17069], Time = 3867.42 seconds
# Iteration 361: Objective Value (LCOE) = 0.23086152032382365, Parameters = [17376, 33, 15012, 9996, 17063], Time = 3877.91 seconds
# Iteration 362: Objective Value (LCOE) = 0.2308550481275325, Parameters = [17371, 33, 15006, 9998, 17059], Time = 3888.40 seconds
# Iteration 363: Objective Value (LCOE) = 0.23084597938034632, Parameters = [17369, 33, 15004, 9999, 17057], Time = 3898.84 seconds
# Iteration 364: Objective Value (LCOE) = 0.23084144500675322, Parameters = [17368, 33, 15003, 9999, 17056], Time = 3909.35 seconds
# Iteration 365: Objective Value (LCOE) = 0.23083691063316014, Parameters = [17367, 33, 15002, 10000, 17055], Time = 3919.79 seconds
# Iteration 366: Objective Value (LCOE) = 0.2308355854394296, Parameters = [17366, 33, 15001, 10000, 17055], Time = 3930.32 seconds
# ...
# Iteration 653: Objective Value (LCOE) = 0.23087823911306088, Parameters = [17041, 33, 15197, 10000, 17055], Time = 6941.40 seconds
# Iteration 654: Objective Value (LCOE) = 0.2308242930060459, Parameters = [17041, 33, 15122, 10000, 17055], Time = 6951.84 seconds
# Iteration 655: Objective Value (LCOE) = 0.23079048677898314, Parameters = [17041, 33, 15075, 10000, 17055], Time = 6962.28 seconds
# Iteration 656: Objective Value (LCOE) = 0.2307703468990309, Parameters = [17041, 33, 15047, 10000, 17055], Time = 6972.78 seconds
# Iteration 657: Objective Value (LCOE) = 0.23075739983334728, Parameters = [17041, 33, 15029, 10000, 17055], Time = 6983.10 seconds
# Iteration 658: Objective Value (LCOE) = 0.23074948773765172, Parameters = [17041, 33, 15018, 10000, 17055], Time = 6993.57 seconds
# Iteration 659: Objective Value (LCOE) = 0.2307444527676637, Parameters = [17041, 33, 15011, 10000, 17055], Time = 7004.01 seconds
# Iteration 660: Objective Value (LCOE) = 0.2307415756419562, Parameters = [17041, 33, 15007, 10000, 17055], Time = 7014.44 seconds
# Iteration 661: Objective Value (LCOE) = 0.2307394177976756, Parameters = [17041, 33, 15004, 10000, 17055], Time = 7024.80 seconds
# Iteration 662: Objective Value (LCOE) = 0.23073869851624873, Parameters = [17041, 33, 15003, 10000, 17055], Time = 7035.23 seconds
# Iteration 663: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7045.51 seconds
# Iteration 664: Objective Value (LCOE) = 0.2307379792348219, Parameters = [17041, 33, 15002, 10000, 17055], Time = 7055.77 seconds
# Iteration 665: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7066.19 seconds
# Iteration 666: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7076.71 seconds
# Iteration 667: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7087.15 seconds
# Iteration 668: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7097.63 seconds
# Iteration 669: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7108.06 seconds
# Iteration 670: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7118.48 seconds
# Iteration 671: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7128.99 seconds
# Iteration 672: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7139.43 seconds
# Iteration 673: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7149.79 seconds
# Iteration 674: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7160.20 seconds
# Iteration 675: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7170.55 seconds
# Iteration 676: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7180.95 seconds
# Iteration 677: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7191.28 seconds
# Iteration 678: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7201.65 seconds
# Iteration 679: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7212.18 seconds
# Iteration 680: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7222.65 seconds
# Iteration 681: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7233.04 seconds
# Iteration 682: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7243.41 seconds
# Iteration 683: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7253.85 seconds
# Iteration 684: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7264.03 seconds
# Iteration 685: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7274.61 seconds
# Iteration 686: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7285.00 seconds
# Iteration 687: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7295.45 seconds
# Iteration 688: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7305.88 seconds
# Iteration 689: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 6910, 17055], Time = 7316.37 seconds
# Iteration 690: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 8090, 17055], Time = 7326.87 seconds
# Iteration 691: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 8820, 17055], Time = 7337.29 seconds
# Iteration 692: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 9271, 17055], Time = 7347.75 seconds
# Iteration 693: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 9549, 17055], Time = 7358.24 seconds
# Iteration 694: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 9721, 17055], Time = 7368.61 seconds
# Iteration 695: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 9828, 17055], Time = 7379.08 seconds
# Iteration 696: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 9894, 17055], Time = 7389.40 seconds
# Iteration 697: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 9934, 17055], Time = 7399.86 seconds
# Iteration 698: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 9959, 17055], Time = 7410.17 seconds
# Iteration 699: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 9975, 17055], Time = 7420.54 seconds
# Iteration 700: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 9984, 17055], Time = 7431.14 seconds
# Iteration 701: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 9990, 17055], Time = 7441.60 seconds
# Iteration 702: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 9994, 17055], Time = 7452.01 seconds
# Iteration 703: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 9996, 17055], Time = 7462.41 seconds
# Iteration 704: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 9998, 17055], Time = 7473.11 seconds
# Iteration 705: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 9999, 17055], Time = 7483.35 seconds
# Iteration 706: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 9999, 17055], Time = 7493.93 seconds
# Iteration 707: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 9999, 17055], Time = 7504.32 seconds
# Iteration 708: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7514.81 seconds
# Iteration 709: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7525.14 seconds
# Iteration 710: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7535.50 seconds
# Iteration 711: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7545.70 seconds
# Iteration 712: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7556.24 seconds
# Iteration 713: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7566.86 seconds
# Iteration 714: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7577.36 seconds
# Iteration 715: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7587.84 seconds
# Iteration 716: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7598.36 seconds
# Iteration 717: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7608.82 seconds
# Iteration 718: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7619.40 seconds
# Iteration 719: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7629.88 seconds
# Iteration 720: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7640.35 seconds
# Iteration 721: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7650.83 seconds
# Iteration 722: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7661.19 seconds
# Iteration 723: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7671.66 seconds
# Iteration 724: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7681.94 seconds
# Iteration 725: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7692.33 seconds
# Iteration 726: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7703.08 seconds
# Iteration 727: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7713.59 seconds
# Iteration 728: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7724.09 seconds
# Iteration 729: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7734.45 seconds
# Iteration 730: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7744.93 seconds
# Iteration 731: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7755.14 seconds
# Iteration 732: Objective Value (LCOE) = 0.2542684393809527, Parameters = [22507, 27, 20706, 8098, 21999], Time = 7765.69 seconds
# Iteration 733: Objective Value (LCOE) = 0.27143193304002533, Parameters = [25885, 24, 24233, 6922, 25055], Time = 7776.04 seconds
# Iteration 734: Objective Value (LCOE) = 0.24461106845134875, Parameters = [20419, 29, 18527, 8824, 20111], Time = 7786.41 seconds
# Iteration 735: Objective Value (LCOE) = 0.23889292541590637, Parameters = [19129, 31, 17180, 9273, 18943], Time = 7796.87 seconds
# Iteration 736: Objective Value (LCOE) = 0.23596760734986022, Parameters = [18331, 32, 16348, 9551, 18222], Time = 7807.28 seconds
# Iteration 737: Objective Value (LCOE) = 0.23410970493221078, Parameters = [17838, 32, 15833, 9722, 17776], Time = 7817.77 seconds
# Iteration 738: Objective Value (LCOE) = 0.2329370317812693, Parameters = [17534, 32, 15515, 9828, 17500], Time = 7828.01 seconds
# Iteration 739: Objective Value (LCOE) = 0.23193411723702562, Parameters = [17345, 33, 15319, 9894, 17330], Time = 7838.64 seconds
# Iteration 740: Objective Value (LCOE) = 0.23152253066005557, Parameters = [17229, 33, 15197, 9934, 17225], Time = 7849.07 seconds
# Iteration 741: Objective Value (LCOE) = 0.23123069654948086, Parameters = [17157, 33, 15122, 9960, 17160], Time = 7859.55 seconds
# Iteration 742: Objective Value (LCOE) = 0.23104290189668086, Parameters = [17113, 33, 15076, 9975, 17120], Time = 7870.00 seconds
# Iteration 743: Objective Value (LCOE) = 0.23092505402319147, Parameters = [17085, 33, 15047, 9985, 17095], Time = 7880.39 seconds
# Iteration 744: Objective Value (LCOE) = 0.23085058021925564, Parameters = [17068, 33, 15029, 9990, 17079], Time = 7890.90 seconds
# Iteration 745: Objective Value (LCOE) = 0.23080779966872195, Parameters = [17058, 33, 15018, 9994, 17070], Time = 7901.05 seconds
# Iteration 746: Objective Value (LCOE) = 0.23078004050392867, Parameters = [17051, 33, 15012, 9996, 17064], Time = 7911.67 seconds
# Iteration 747: Objective Value (LCOE) = 0.23076121079198625, Parameters = [17047, 33, 15007, 9998, 17060], Time = 7922.09 seconds
# Iteration 748: Objective Value (LCOE) = 0.23075215557672854, Parameters = [17045, 33, 15005, 9999, 17058], Time = 7932.50 seconds
# Iteration 749: Objective Value (LCOE) = 0.2307463151686528, Parameters = [17043, 33, 15003, 9999, 17057], Time = 7943.02 seconds
# Iteration 750: Objective Value (LCOE) = 0.23074178756102387, Parameters = [17042, 33, 15002, 9999, 17056], Time = 7953.47 seconds
# Iteration 751: Objective Value (LCOE) = 0.23073857275384185, Parameters = [17042, 33, 15002, 10000, 17055], Time = 7963.97 seconds
# Iteration 752: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7974.17 seconds
# Iteration 753: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7984.76 seconds
# Iteration 754: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 7995.20 seconds
# Iteration 755: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 8005.62 seconds
# Iteration 756: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 8016.12 seconds
# Iteration 757: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 8026.50 seconds
# Iteration 758: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 8037.03 seconds
# Iteration 759: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 8047.25 seconds
# Iteration 760: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 8057.99 seconds
# Iteration 761: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 8068.57 seconds
# Iteration 762: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 8079.13 seconds
# Iteration 763: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 8089.74 seconds
# Iteration 764: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 8100.25 seconds
# Iteration 765: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 8110.85 seconds
# Iteration 766: Objective Value (LCOE) = 0.230737259953395, Parameters = [17041, 33, 15001, 10000, 17055], Time = 8121.15 seconds
# Optimization terminated successfully.
#          Current function value: 0.230737
#          Iterations: 4
#          Function evaluations: 766
# Powell optimization successful. LCOE: 0.230737, Iterations: 0, Total Time: 8121.15 seconds
# Powell optimization successful. LCOE: 0.230737, Iterations: 0, Time: 8121.15 seconds
#
# Optimization comparison results are saved in the 'optimization_iterations' directory.
#
# Best results for each deposit:
#    Method  Iterations  Duration (seconds)      LCOE
# 0  Powell           0         8121.152675  0.230737
#
# Method performance summary:
#        Iterations         Duration (seconds)                            \
#            median min max             median          min          max
# Method
# Powell        0.0   0   0        8121.152675  8121.152675  8121.152675
#
#             LCOE
#           median       min       max  std
# Method
# Powell  0.230737  0.230737  0.230737  0.0
#
# Number of times each method found the best solution:
# Method
# Powell    1
# Name: count, dtype: int64
#
# Success rate of each method (%):
# Method
# Powell    200.0
# Name: LCOE, dtype: float64
