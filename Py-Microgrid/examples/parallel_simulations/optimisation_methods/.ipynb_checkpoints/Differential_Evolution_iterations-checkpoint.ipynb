# %%
import requests
import os
import yaml
import pandas as pd
import numpy as np
import time
from scipy.optimize import minimize, differential_evolution, shgo
import csv
from hopp.simulation import HoppInterface
from hopp.tools.dispatch.plot_tools import (
    plot_battery_output, plot_battery_dispatch_error, plot_generation_profile, plot_battery_generation
)
from hopp.utilities import load_yaml
from hopp.simulation.technologies.grid import Grid
from hopp.simulation.technologies.grid import GridConfig
from hopp.utilities.keys import set_nrel_key_dot_env
from hopp.utilities.keys import set_developer_nrel_gov_key

# Set API for solar and wind resources
set_developer_nrel_gov_key('3F5fBErsd9gKIPEdQpkWHNIhNj7gZG3j0y3lkzew')

# Global variables
yaml_file_path = "../input_yaml/input_file_chunk_6.yaml"
project_lifetime = 25  # years
discount_rate = 0.0588  # real discount rate = 5.88%, discount rate 8%, inflation rate 2%


# Functions for Present Value and LCOE calculations
def present_value(future_value, discount_rate, project_lifetime):
    return future_value / ((1 + discount_rate) ** project_lifetime)

def calculate_lcoe(total_system_cost, total_system_generation_over_lifetime, discount_rate, project_lifetime):
    present_value_total_system_costs = present_value(total_system_cost, discount_rate, project_lifetime)
    present_value_total_system_generation = present_value(total_system_generation_over_lifetime, discount_rate, project_lifetime)
    return present_value_total_system_costs / present_value_total_system_generation

# Battery and load adjustment
def apply_flexible_load_and_adjust_battery(row):
    pv, wind, genset = row['PV Generation (kW)'], row['Wind Generation (kW)'], row['Genset Generation (kW)']
    battery, original_load = row['Original Battery Generation (kW)'], row['Original Load (kW)']
    
    total_generation_without_battery = pv + wind + genset
    
    if battery < 0 and total_generation_without_battery + battery < original_load:
        battery = 0
    
    adjusted_generation = total_generation_without_battery + battery
    
    if adjusted_generation < original_load:
        max_reduction = 0.20 * original_load
        load_reduction = min(original_load - adjusted_generation, max_reduction)
        adjusted_load = original_load - load_reduction
    else:
        adjusted_load = original_load
    
    new_deficit = adjusted_generation - adjusted_load
    
    return pd.Series({
        'Adjusted Battery Generation (kW)': battery,
        'Adjusted Load (kW)': adjusted_load,
        'Adjusted Deficit (kW)': new_deficit
    })

# Penalty calculation
def calculate_penalty(demand_met_percentage):
    unmet_percentage = 100 - demand_met_percentage
    if unmet_percentage <= 1:
        return 0.1 * unmet_percentage
    else:
        return 0.2 * unmet_percentage

# Load YAML configuration file safely
def load_yaml_safely(file_path):
    with open(file_path, 'r') as file:
        config = yaml.safe_load(file)
    if config is None:
        raise ValueError(f"The YAML configuration file at {file_path} is empty or invalid.")
    return config

# Save YAML configuration file safely
def save_yaml_safely(config, file_path):
    backup_path = file_path + '.bak'
    if os.path.exists(file_path):
        os.rename(file_path, backup_path)
    
    try:
        with open(file_path, 'w') as file:
            yaml.safe_dump(config, file, default_flow_style=False, sort_keys=False)
        
        if os.path.getsize(file_path) == 0:
            raise IOError("Failed to write data to YAML file")
        
        if os.path.exists(backup_path):
            os.remove(backup_path)
    except Exception as e:
        if os.path.exists(backup_path):
            os.rename(backup_path, file_path)
        raise IOError(f"Error saving YAML file: {str(e)}")

# Update YAML configuration
def update_yaml_config(yaml_file_path, solar_path, wind_path, latitude, longitude):
    if os.path.exists(yaml_file_path):
        config = load_yaml_safely(yaml_file_path)
        if 'site' not in config or 'data' not in config['site']:
            raise KeyError("The YAML configuration is missing required 'site.data' key.")

        config['site']['data']['lat'] = latitude
        config['site']['data']['lon'] = longitude
        config['site']['solar_resource_file'] = solar_path.replace('\\', '/')
        config['site']['wind_resource_file'] = wind_path.replace('\\', '/')

        save_yaml_safely(config, yaml_file_path)
        print(f"YAML configuration updated successfully at {yaml_file_path}.")
    else:
        raise FileNotFoundError(f"The YAML file at {yaml_file_path} does not exist.")

# Download solar and wind resource data
def download_data_and_update_config(latitude, longitude, solar_year, wind_start, wind_end, api_key, email, yaml_file_path):
    # Define directories for saving files
    solar_dir = r'/home/z5142067/miniconda3/envs/microgrid/lib/python3.8/site-packages/hopp/simulation/resource_files/solar'
    wind_dir = r'/home/z5142067/miniconda3/envs/microgrid/lib/python3.8/site-packages/hopp/simulation/resource_files/wind'
    os.makedirs(solar_dir, exist_ok=True)
    os.makedirs(wind_dir, exist_ok=True)

    # Download Solar Data
    solar_base_url = "https://developer.nrel.gov/api/nsrdb/v2/solar/himawari-download.csv"
    solar_params = {
        "wkt": f"POINT({longitude} {latitude})",
        "names": solar_year,
        "leap_day": "false",
        "interval": "60",
        "utc": "false",
        "full_name": "Hanrong Huang",
        "email": email,
        "affiliation": "UNSW",
        "mailing_list": "true",
        "reason": "research",
        "api_key": api_key,
        "attributes": "dni,dhi,ghi,dew_point,air_temperature,surface_pressure,wind_direction,wind_speed,surface_albedo"
    }
    solar_response = requests.get(solar_base_url, params=solar_params)
    solar_filename = f"{latitude}_{longitude}_psmv3_60_{solar_year}.csv"
    solar_path = os.path.join(solar_dir, solar_filename)

    if solar_response.status_code == 200:
        with open(solar_path, 'wb') as file:
            file.write(solar_response.content)
        print(f"Solar data downloaded and saved to {solar_path}.")
    else:
        print(f"Failed to download solar data: {solar_response.status_code}")
        print(solar_response.text)

    # Download Wind Data
    wind_url = "https://power.larc.nasa.gov/api/temporal/hourly/point"
    wind_params = {
        "start": wind_start,
        "end": wind_end,
        "latitude": latitude,
        "longitude": longitude,
        "community": "ag",
        "parameters": "WS50M,WD50M",
        "format": "srw",
        "user": "Hanrong",
        "header": "true",
        "time-standard": "lst"
    }
    wind_response = requests.get(wind_url, params=wind_params)
    wind_filename = f"{latitude}_{longitude}_NASA_{wind_start[:4]}_60min_50m.srw"
    wind_path = os.path.join(wind_dir, wind_filename)

    if wind_response.status_code == 200:
        with open(wind_path, 'wb') as file:
            file.write(wind_response.content)
        print(f"Wind data downloaded successfully and saved to {wind_path}.")
    else:
        print(f"Failed to download wind data: {wind_response.status_code}")
        print(wind_response.text)

    # Update YAML configuration file
    try:
        update_yaml_config(yaml_file_path, solar_path, wind_path, latitude, longitude)
    except Exception as e:
        raise RuntimeError(f"Error updating YAML configuration: {e}")
        
# Objective function for optimization
def objective_function(x):
    # Ensure integer values for specific variables
    pv_size = float(np.clip(round(x[0]), bounds[0][0], bounds[0][1]))
    num_turbines = int(np.clip(round(x[1]), bounds[1][0], bounds[1][1]))
    battery_capacity_kwh = float(np.clip(round(x[2]), bounds[2][0], bounds[2][1]))
    battery_capacity_kw = float(np.clip(round(x[3]), bounds[3][0], bounds[3][1]))
    grid_interconnect_kw = float(np.clip(round(x[4]), bounds[4][0], bounds[4][1]))

    # Update the YAML configuration with rounded integer variable
    config = load_yaml_safely(yaml_file_path)
    config['technologies']['pv']['system_capacity_kw'] = pv_size
    config['technologies']['wind']['num_turbines'] = num_turbines
    config['technologies']['battery']['system_capacity_kwh'] = battery_capacity_kwh
    config['technologies']['battery']['system_capacity_kw'] = battery_capacity_kw
    config['technologies']['grid']['interconnect_kw'] = grid_interconnect_kw
    save_yaml_safely(config, yaml_file_path)

    # Create a new HoppInterface instance and run the simulation
    try:
        hopp = HoppInterface(yaml_file_path)
        hopp.simulate(project_life=25)
    except Exception as e:
        print(f"Simulation failed: {e}")
        return 1e6, {}  # Return a high LCOE and empty result for infeasible solutions

    # Calculate system components generation over project lifetime
    hybrid_plant = hopp.system

    pv_total_generation = np.sum(hybrid_plant.generation_profile.pv)
    wind_total_generation = np.sum(hybrid_plant.generation_profile.wind)
    battery_total_generation = np.sum(hybrid_plant.generation_profile.battery)
    genset_total_generation = np.sum(hybrid_plant.generation_profile.grid)

    # Total system generation = PV + wind + genset, excluding battery
    total_system_generation_over_lifetime = pv_total_generation + wind_total_generation + genset_total_generation 

    # Genset Specific Calculations
    genset_capacity_kw = hybrid_plant.grid.interconnect_kw
    genset_install_cost_per_kw = 500
    replacement_cost_genset_per_kw = 500
    om_cost_per_kw_per_op_hour = 0.03  # Genset O&M cost per kW per operating hour
    fuel_cost_per_l = 1.20
    specific_fuel_consumption_l_per_kwh = 0.250
    genset_operational_hours_per_year = np.sum(np.array(hybrid_plant.grid.generation_profile) > 0) / project_lifetime
    generator_operational_life_hours = 15000
    generator_operational_life_years = generator_operational_life_hours / genset_operational_hours_per_year
    num_genset_replacements = float(project_lifetime / generator_operational_life_years) - 1

    genset_installed_cost = genset_capacity_kw * genset_install_cost_per_kw
    replacement_cost_genset = num_genset_replacements * genset_capacity_kw * replacement_cost_genset_per_kw
    total_om_cost_genset = om_cost_per_kw_per_op_hour * genset_capacity_kw * genset_operational_hours_per_year * project_lifetime
    total_fuel_consumption = genset_total_generation * specific_fuel_consumption_l_per_kwh
    total_fuel_cost = total_fuel_consumption * fuel_cost_per_l
    total_genset_cost = genset_installed_cost + replacement_cost_genset + total_om_cost_genset + total_fuel_cost

    # Battery Costs
    battery_capacity_kwh = config['technologies']['battery']['system_capacity_kwh']
    battery_installed_cost = hybrid_plant.battery.total_installed_cost  # can be modified in hopp/tools/analysis/bos/cost_calculator.py
    om_cost_battery_per_kwh_per_year = 10  # Battery O&M cost per kWh per year
    operational_life_battery = 15
    num_battery_replacements = float(project_lifetime / operational_life_battery) - 1
    replacement_cost_battery_per_kWh = battery_installed_cost / battery_capacity_kwh  # Battery replacement cost per kWh, 700 $/kWh
    replacement_cost_battery = num_battery_replacements * battery_capacity_kwh * replacement_cost_battery_per_kWh
    total_om_cost_battery = om_cost_battery_per_kwh_per_year * battery_capacity_kwh * project_lifetime
    total_battery_cost = battery_installed_cost + replacement_cost_battery + total_om_cost_battery

    # PV Costs
    pv_capacity_kw = hybrid_plant.system_capacity_kw.pv
    pv_installed_cost = hybrid_plant.pv.total_installed_cost  # can be modified in hopp/tools/analysis/bos/cost_calculator.py
    om_cost_pv_per_kw_per_year = 10  # PV O&M cost per kW per year
    total_om_cost_pv = om_cost_pv_per_kw_per_year * pv_capacity_kw * project_lifetime
    total_pv_cost = pv_installed_cost + total_om_cost_pv

    # Wind Costs
    wind_capacity_kw = hybrid_plant.system_capacity_kw.wind
    wind_installed_cost = hybrid_plant.wind.total_installed_cost  # can be modified in hopp/tools/analysis/bos/cost_calculator.py
    om_cost_wind_per_kw_per_year = 40  # Wind O&M cost per kW per year
    total_om_cost_wind = om_cost_wind_per_kw_per_year * wind_capacity_kw * project_lifetime
    total_wind_cost = wind_installed_cost + total_om_cost_wind

    # Total System Costs over project lifetime
    total_system_cost = total_pv_cost + total_wind_cost + total_battery_cost + total_genset_cost

    # Calculate NPC 
    npc = present_value(total_system_cost, discount_rate, project_lifetime)
    
    # Create a DataFrame for flexible load and battery adjustment calculation
    df = pd.DataFrame({
        'PV Generation (kW)': np.array(hybrid_plant.generation_profile.pv[:8760]), 
        'Wind Generation (kW)': np.array(hybrid_plant.generation_profile.wind[:8760]),  
        'Genset Generation (kW)': np.array(hybrid_plant.generation_profile.grid[:8760]), 
        'Original Battery Generation (kW)': np.array(hybrid_plant.generation_profile.battery[:8760]), 
        'Original Load (kW)': np.array(hybrid_plant.site.desired_schedule[:8760]) * 1000   # Convert MW to kW
    })

    # Apply flexible load and battery charging adjustment
    adjusted_results = df.apply(apply_flexible_load_and_adjust_battery, axis=1)
    df['Adjusted Deficit (kW)'] = adjusted_results['Adjusted Deficit (kW)']
    df['Adjusted Load (kW)'] = adjusted_results['Adjusted Load (kW)']
    df['Adjusted Battery Generation (kW)'] = adjusted_results['Adjusted Battery Generation (kW)']

    # Calculate the number of deficit hours that have been fixed by the adjustments (for one year)
    original_deficits = df[df['Original Load (kW)'] > (df['PV Generation (kW)'] + df['Wind Generation (kW)'] + df['Genset Generation (kW)'] + df['Original Battery Generation (kW)'])]
    remaining_deficits = df[df['Adjusted Deficit (kW)'] < 0]
    deficit_hours_fixed_one_year = len(original_deficits) - len(remaining_deficits)

    # Calculate metrics for one year
    total_load_served_one_year = np.sum(df['Adjusted Load (kW)'])
    total_load_reduction_one_year = np.sum(df['Original Load (kW)'] - df['Adjusted Load (kW)'])
    total_charging_prevented_one_year = np.sum(np.maximum(0, -df['Original Battery Generation (kW)'] + df['Adjusted Battery Generation (kW)']))
    total_load_not_served_one_year = np.sum(np.maximum(0, -df['Adjusted Deficit (kW)']))

    # Calculate values for the entire project lifetime
    deficit_hours_fixed = deficit_hours_fixed_one_year * project_lifetime
    total_load_served = total_load_served_one_year * project_lifetime
    total_load_reduction = total_load_reduction_one_year * project_lifetime
    total_charging_prevented = total_charging_prevented_one_year * project_lifetime
    total_load_not_served = total_load_not_served_one_year * project_lifetime

    # Calculate percentages
    total_load_reduction_percentage = (total_load_reduction / (np.sum(df['Original Load (kW)']) * project_lifetime)) * 100
    demand_met_percentage = ((total_load_served - total_load_not_served) / total_load_served) * 100

    # Calculate LCOE
    lcoe = calculate_lcoe(total_system_cost, total_load_served, discount_rate, project_lifetime)

    # Check if the system meets the demand for all hours
    all_hours_sufficient = np.all(df['Adjusted Deficit (kW)'] >= 0)

    # Prepare result dictionary with lifetime values
    result = {
        "PV Capacity (kW)": pv_size,
        "Wind Turbine Capacity (kW)": num_turbines * 1000,  # 1000 kW per turbine
        "Genset Capacity (kW)": grid_interconnect_kw,
        "Battery Energy Capacity (kWh)": battery_capacity_kwh,
        "Battery Power Capacity (kW)": battery_capacity_kw,
        "Total System Generation (kWh)": total_system_generation_over_lifetime,
        "Total PV Generation (kWh)": pv_total_generation,
        "Total Wind Generation (kWh)": wind_total_generation,
        "Total Genset Generation (kWh)": genset_total_generation,
        "Total Battery Generation (kWh)": battery_total_generation,
        "System NPC ($)": npc,
        "System LCOE ($/kWh)": lcoe,
        "Deficit Hours Fixed": deficit_hours_fixed,
        "Total Load Reduction (kWh)": total_load_reduction,
        "Total Load Served (kWh)": total_load_served,
        "Load Reduction Percentage": total_load_reduction_percentage,
        "Total Charging Prevented (kWh)": total_charging_prevented,
        "Demand Not Served (kWh)": total_load_not_served,
        "Demand Met Percentage": demand_met_percentage,
        "Project Lifetime (years)": project_lifetime
    }

    # Check if all hours were sufficient and apply the penalty if there are deficit hours
    if all_hours_sufficient:
        return lcoe, result
    else:
        penalty = calculate_penalty(demand_met_percentage)
        penalized_lcoe = lcoe + penalty
        result["Penalized LCOE ($/kWh)"] = penalized_lcoe
        return penalized_lcoe, result

# OptimizationTracker class
class OptimizationTracker:
    def __init__(self, csv_file):
        self.csv_file = csv_file
        self.iteration_count = 0
        self.fieldnames = ['Iteration', 'Objective Value', 'Parameters', 'Time (seconds)']
        self.data = []
        self.start_time = time.time()

    def track(self, x, f=None):
        self.iteration_count += 1
        current_time = time.time()
        elapsed_time = current_time - self.start_time
        
        x_int = [int(round(xi)) for xi in x]
        lcoe = f if f is not None else objective_function(x_int)[0]
        self.data.append({
            'Iteration': self.iteration_count,
            'Objective Value': lcoe,
            'Parameters': x_int,
            'Time (seconds)': elapsed_time
        })
        print(f"Iteration {self.iteration_count}: Objective Value (LCOE) = {lcoe}, Parameters = {x_int}, Time = {elapsed_time:.2f} seconds")

    def save_to_csv(self):
        with open(self.csv_file, 'w', newline='') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=self.fieldnames)
            writer.writeheader()
            for row in self.data:
                row_copy = row.copy()
                row_copy['Parameters'] = str(row['Parameters'])
                writer.writerow(row_copy)

# Class to hold optimization result
class OptimizationResult:
    def __init__(self, x, success):
        self.x = x
        self.success = success
        
# Global variable for the tracker
global_tracker = None

# Base objective function
def base_objective_function(x):
    x_int = [int(round(xi)) for xi in x]
    return objective_function(x_int)[0]

# Tracking wrapper
def track_evaluation(func):
    def wrapper(x):
        result = func(x)
        if global_tracker is not None:
            global_tracker.track(x, result)
        return result
    return wrapper

# Integer constraint objective (used for Nelder-Mead, Powell and COBYlA)
integer_constraint_objective = base_objective_function

# Tracked integer constraint objective (used for differential evo and shgo)
tracked_integer_constraint_objective = track_evaluation(base_objective_function)

# Custom callback for Nelder-Mead
def custom_callback(xk):
    global best_score, iterations, global_tracker
    iterations += 1
    score = base_objective_function(xk)
    if global_tracker is not None:
        global_tracker.track(xk, score)
    if best_score is None or score < best_score:
        best_score = score
    else:
        if iterations > 50 and abs(score - best_score) < 1e-3:
            return True
    return False

# Run optimization function
def run_optimization(method, bounds, deposit_uid, iteration_output_dir, latitude, longitude):
    global global_tracker, best_score, iterations
    
    start_time = time.time()
    
    tracker = OptimizationTracker(os.path.join(iteration_output_dir, f'{method}_iterations_{deposit_uid}.csv'))
    global_tracker = tracker
    
    best_score = None
    iterations = 0

    # Choose the appropriate objective function based on the method
    obj_func = integer_constraint_objective if method == 'Nelder-Mead' else tracked_integer_constraint_objective

    try:
        if method == 'Nelder-Mead':
            x0 = [int(bound[0] + 0.5 * (bound[1] - bound[0])) for bound in bounds]
            result = minimize(
                obj_func,
                x0,
                method=method,
                options={
                    'maxiter': 200,
                    'xatol': 1,
                    'fatol': 1e-3,
                    'disp': True
                },
                callback=custom_callback
            )
        elif method == 'COBYLA':
            x0 = [int(bound[0] + 0.5 * (bound[1] - bound[0])) for bound in bounds]
            result = minimize(
                obj_func,
                x0,
                method=method,
                bounds=bounds,
                options={
                    'maxiter': 200,
                    'rhobeg': 1.0,
                    'tol': 1e-5,
                    'disp': True
                }
            )
        elif method == 'Powell':
            x0 = [int(bound[0] + 0.5 * (bound[1] - bound[0])) for bound in bounds]
            result = minimize(
                obj_func,
                x0,
                method=method,
                bounds=bounds,
                options={
                    'maxiter': 200,
                    'xtol': 1e-5,
                    'ftol': 1e-5,
                    'disp': True
                }
            )
        elif method == 'Differential Evolution':
            result = differential_evolution(
                obj_func,
                bounds,
                strategy='best1bin',
                maxiter=200,
                popsize=10,
                tol=1e-4,
                mutation=(0.3, 0.6),
                recombination=0.9,
                updating='immediate',
                workers=1,
                disp=True
            )
        elif method == 'SHGO':
            result = shgo(
                obj_func,
                bounds,
                n=100,
                iters=4,
                sampling_method='sobol',
                options={'disp': True}
            )
        else:
            raise ValueError(f"Unknown method: {method}")
        
        success = result.success
    except Exception as e:
        print(f"Optimization failed for method {method}: {e}")
        result = OptimizationResult(None, False)
        
    end_time = time.time()
    total_time = end_time - start_time

    tracker.save_to_csv()
    global_tracker = None

    if result and getattr(result, 'x', None) is not None:
        optimal_x = [int(round(x)) for x in result.x]
        lcoe, optimal_results = objective_function(optimal_x)

        optimization_results.append({
            'Method': method,
            'Deposit UID': deposit_uid,
            'Latitude': latitude,
            'Longitude': longitude,
            'Iterations': iterations,
            'Duration (seconds)': total_time,
            'LCOE': lcoe,
            **optimal_results
        })
        print(f"{method} optimization successful. LCOE: {lcoe:.6f}, Iterations: {iterations}, Total Time: {total_time:.2f} seconds")
    else:
        print(f"{method} optimization failed or was stopped early. Total Time: {total_time:.2f} seconds")

    return result, iterations, total_time

# Main execution logic
if __name__ == "__main__":
    csv_path = "../deposit_data/auCopper_chunk_0_test_optimisation_methods.csv"
    location_data = pd.read_csv(csv_path)
    api_key = "3F5fBErsd9gKIPEdQpkWHNIhNj7gZG3j0y3lkzew"
    email = "z5142067@ad.unsw.edu.au"
    optimization_results = []
    iteration_output_dir = "./optimisation_results"
    os.makedirs(iteration_output_dir, exist_ok=True)

    methods_to_test = ['Differential Evolution']

    # Bounds for the variables: PV, wind, battery_capacity_kwh, battery_capacity_kw, genset
    bounds = [(10000, 45000), (10, 45), (15000, 30000), (5000, 10000), (17000, 30000)]

    for index, row in location_data.iterrows():
        latitude = row['DEPOSIT_LATITUDE']
        longitude = row['DEPOSIT_LONGITUDE']
        deposit_uid = row['DEPOSIT_UID']
        print(f"\nHybrid microgrid simulation and optimization at ore deposit (Lat: {latitude}, Lon: {longitude}) starts:")

        try:
            # Assume you have a function to download data and update config
            download_data_and_update_config(latitude, longitude, "2020", "20200101", "20201231", api_key, email, yaml_file_path)
        except Exception as e:
            print(f"Failed to download data or update configuration: {e}")
            continue
            
        for method in methods_to_test:
            print(f"\nTesting optimization method: {method}")
            result, iterations, duration = run_optimization(method, bounds, deposit_uid, iteration_output_dir, latitude, longitude)

            if result and getattr(result, 'x', None) is not None:
                optimal_x = result.x

                # Round integer variables if needed
                if method != 'Nelder-Mead':  # Nelder-Mead already handled internally
                    optimal_x[1] = int(round(optimal_x[1]))  # Number of turbines

                # Get LCOE and results
                lcoe, optimal_results = objective_function(optimal_x)

                optimization_results.append({
                    'Method': method,
                    'Deposit UID': deposit_uid,
                    'Latitude': latitude,
                    'Longitude': longitude,
                    'Iterations': iterations,
                    'Duration (seconds)': duration,
                    'LCOE': lcoe,
                    **optimal_results
                })
                print(f"{method} optimization successful. LCOE: {lcoe:.6f}, Iterations: {iterations}, Time: {duration:.2f} seconds")
            else:
                print(f"{method} optimization failed to converge or was stopped early.")

    # Saving and summarizing results
    if optimization_results:
        optimization_df = pd.DataFrame(optimization_results)
        output_dir = "./optimisation_results"
        os.makedirs(output_dir, exist_ok=True)
        optimization_df.to_csv(os.path.join(output_dir, "optimisation_results_Differential_Evolution.csv"), index=False)
        print("\nOptimization comparison results are saved in the 'optimisation_results' directory.")

        # Best results per deposit
        best_results = optimization_df.loc[optimization_df.groupby('Deposit UID')['LCOE'].idxmin()]
        print("\nBest results for each deposit:")
        print(best_results[['Method', 'Iterations', 'Duration (seconds)', 'LCOE']])

        # Method performance summary
        method_performance = optimization_df.groupby('Method').agg({
            'Iterations': ['median', 'min', 'max'],
            'Duration (seconds)': ['median', 'min', 'max'],
            'LCOE': ['median', 'min', 'max', 'std']
        }).sort_values(('LCOE', 'median'))
        print("\nMethod performance summary:")
        print(method_performance)

        # Number of times each method found the best solution
        best_method_counts = optimization_df.loc[optimization_df.groupby('Deposit UID')['LCOE'].idxmin()]['Method'].value_counts()
        print("\nNumber of times each method found the best solution:")
        print(best_method_counts)

        # Success rate of each method (%)
        unique_deposits = optimization_df['Deposit UID'].nunique()
        success_rate = (optimization_df.groupby('Method')['LCOE'].count() / unique_deposits) * 100
        print("\nSuccess rate of each method (%):")
        print(success_rate)
    else:
        print("No successful optimization results to save.")
# Out:
# /home/z5142067/miniconda3/envs/microgrid/lib/python3.8/site-packages/hopp/examples/parallel_simulations/optimisation_methods/log/hybrid_systems_2024-10-03T10.40.45.723647.log
#
# Hybrid microgrid simulation and optimization at ore deposit (Lat: -31.1629, Lon: 145.6538) starts:
# Solar data downloaded and saved to /home/z5142067/miniconda3/envs/microgrid/lib/python3.8/site-packages/hopp/simulation/resource_files/solar/-31.1629_145.6538_psmv3_60_2020.csv.
# Wind data downloaded successfully and saved to /home/z5142067/miniconda3/envs/microgrid/lib/python3.8/site-packages/hopp/simulation/resource_files/wind/-31.1629_145.6538_NASA_2020_60min_50m.srw.
# YAML configuration updated successfully at ../input_yaml/input_file_chunk_6.yaml.
#
# Testing optimization method: Differential Evolution
# Iteration 1: Objective Value (LCOE) = 0.25523269737176535, Parameters = [32765, 32, 28319, 5985, 18700], Time = 11.28 seconds
# Iteration 2: Objective Value (LCOE) = 0.24494338565759713, Parameters = [30541, 23, 17081, 6743, 17457], Time = 22.47 seconds
# Iteration 3: Objective Value (LCOE) = 0.2958608543873975, Parameters = [38029, 20, 29658, 6457, 26984], Time = 33.42 seconds
# Iteration 4: Objective Value (LCOE) = 0.2645042175591449, Parameters = [20048, 42, 27350, 7155, 24619], Time = 44.60 seconds
# Iteration 5: Objective Value (LCOE) = 0.2745339541165418, Parameters = [17917, 32, 17752, 9491, 29818], Time = 55.45 seconds
# Iteration 6: Objective Value (LCOE) = 0.2814462059286094, Parameters = [43268, 45, 15832, 9832, 26735], Time = 66.70 seconds
# Iteration 7: Objective Value (LCOE) = 0.29011473883824707, Parameters = [40712, 44, 21943, 8884, 29441], Time = 77.78 seconds
# Iteration 8: Objective Value (LCOE) = 0.2581062612169299, Parameters = [28163, 19, 24384, 7337, 19057], Time = 88.60 seconds
# Iteration 9: Objective Value (LCOE) = 0.2506922481911144, Parameters = [31263, 22, 18447, 9608, 18386], Time = 99.32 seconds
# Iteration 10: Objective Value (LCOE) = 0.2622287564520819, Parameters = [16944, 35, 25847, 9920, 24479], Time = 110.25 seconds
# Iteration 11: Objective Value (LCOE) = 0.25271873514137627, Parameters = [11694, 38, 28682, 6932, 19652], Time = 121.23 seconds
# Iteration 12: Objective Value (LCOE) = 0.2552149280979599, Parameters = [40833, 27, 20486, 8775, 17874], Time = 132.10 seconds
# Iteration 13: Objective Value (LCOE) = 0.29726848160901354, Parameters = [19190, 15, 23321, 9585, 27674], Time = 142.90 seconds
# Iteration 14: Objective Value (LCOE) = 0.2878785904372814, Parameters = [42679, 33, 26481, 8347, 27428], Time = 153.86 seconds
# Iteration 15: Objective Value (LCOE) = 0.2577499322800515, Parameters = [41700, 38, 16630, 6681, 19183], Time = 164.92 seconds
# Iteration 16: Objective Value (LCOE) = 0.27060616227509143, Parameters = [23597, 18, 28832, 9046, 21809], Time = 175.98 seconds
# Iteration 17: Objective Value (LCOE) = 0.2669792023786767, Parameters = [20679, 40, 23908, 8060, 26460], Time = 187.47 seconds
# Iteration 18: Objective Value (LCOE) = 0.2763985904991941, Parameters = [39457, 16, 19832, 7421, 21428], Time = 198.63 seconds
# Iteration 19: Objective Value (LCOE) = 0.3106001790053621, Parameters = [10873, 17, 26130, 8174, 27169], Time = 209.74 seconds
# Iteration 20: Objective Value (LCOE) = 0.2539851723346417, Parameters = [13381, 33, 17335, 5680, 23065], Time = 221.21 seconds
# Iteration 21: Objective Value (LCOE) = 0.2495469503851122, Parameters = [32190, 30, 27650, 9307, 17164], Time = 232.38 seconds
# Iteration 22: Objective Value (LCOE) = 0.24497607619572065, Parameters = [18735, 23, 24800, 7559, 17630], Time = 243.55 seconds
# Iteration 23: Objective Value (LCOE) = 0.2547860978497339, Parameters = [25988, 37, 18668, 9185, 22556], Time = 254.94 seconds
# Iteration 24: Objective Value (LCOE) = 0.2617758448525675, Parameters = [35798, 21, 18017, 9277, 20528], Time = 265.72 seconds
# Iteration 25: Objective Value (LCOE) = 0.287223439930859, Parameters = [26478, 14, 19666, 7816, 25245], Time = 276.36 seconds
# Iteration 26: Objective Value (LCOE) = 0.2783055961928295, Parameters = [12139, 39, 20316, 7078, 29670], Time = 287.46 seconds
# Iteration 27: Objective Value (LCOE) = 0.31728620452579465, Parameters = [38856, 13, 27969, 6177, 28751], Time = 298.23 seconds
# Iteration 28: Objective Value (LCOE) = 0.29844916969179164, Parameters = [30268, 11, 15449, 5032, 25901], Time = 308.95 seconds
# Iteration 29: Objective Value (LCOE) = 0.27727424227092606, Parameters = [44957, 23, 26733, 8230, 21313], Time = 319.66 seconds
# Iteration 30: Objective Value (LCOE) = 0.2552414680771201, Parameters = [10405, 43, 17408, 8605, 22230], Time = 330.84 seconds
# Iteration 31: Objective Value (LCOE) = 0.2497455115071454, Parameters = [17285, 26, 21499, 7226, 20370], Time = 341.70 seconds
# Iteration 32: Objective Value (LCOE) = 0.26463305737283976, Parameters = [13975, 42, 22443, 8531, 25372], Time = 352.84 seconds
# Iteration 33: Objective Value (LCOE) = 0.27066219340206094, Parameters = [21873, 17, 15246, 6533, 24000], Time = 363.70 seconds
# Iteration 34: Objective Value (LCOE) = 0.28479085987978536, Parameters = [24396, 25, 25479, 7937, 29120], Time = 374.52 seconds
# Iteration 35: Objective Value (LCOE) = 0.24972479993854751, Parameters = [15136, 36, 23609, 8975, 20745], Time = 385.49 seconds
# Iteration 36: Objective Value (LCOE) = 0.27857188159701635, Parameters = [14660, 25, 16253, 5350, 28411], Time = 396.70 seconds
# Iteration 37: Objective Value (LCOE) = 0.28246766595998435, Parameters = [34200, 27, 29705, 6331, 26168], Time = 407.96 seconds
# Iteration 38: Objective Value (LCOE) = 0.2578601345772183, Parameters = [15629, 28, 15992, 6249, 24101], Time = 419.37 seconds
# Iteration 39: Objective Value (LCOE) = 0.25981801625096157, Parameters = [22904, 29, 22699, 9750, 23551], Time = 430.48 seconds
# Iteration 40: Objective Value (LCOE) = 0.2683647209606879, Parameters = [43741, 20, 20852, 6037, 19431], Time = 441.28 seconds
# Iteration 41: Objective Value (LCOE) = 0.31897362221695447, Parameters = [34522, 11, 25113, 7779, 28659], Time = 451.96 seconds
# Iteration 42: Objective Value (LCOE) = 0.2622826992164092, Parameters = [33796, 28, 25761, 7700, 21015], Time = 462.80 seconds
# Iteration 43: Objective Value (LCOE) = 0.26236040162335145, Parameters = [37936, 34, 27084, 8477, 19961], Time = 473.78 seconds
# Iteration 44: Objective Value (LCOE) = 0.2772646412985926, Parameters = [25139, 40, 29207, 5109, 27961], Time = 484.93 seconds
# Iteration 45: Objective Value (LCOE) = 0.30200785177884165, Parameters = [36991, 13, 24233, 5238, 25828], Time = 495.73 seconds
# Iteration 46: Objective Value (LCOE) = 0.2515455617189359, Parameters = [22185, 41, 18978, 5856, 21957], Time = 506.92 seconds
# Iteration 47: Objective Value (LCOE) = 0.30087108127566503, Parameters = [36524, 12, 22953, 5572, 24966], Time = 517.63 seconds
# Iteration 48: Objective Value (LCOE) = 0.24449404095710636, Parameters = [26965, 36, 21072, 5408, 18239], Time = 528.53 seconds
# Iteration 49: Objective Value (LCOE) = 0.27405259677400196, Parameters = [28428, 16, 19330, 5769, 22908], Time = 539.28 seconds
# Iteration 50: Objective Value (LCOE) = 0.2619233697589568, Parameters = [29466, 31, 21857, 6863, 23308], Time = 550.20 seconds
# Iteration 51: Objective Value (LCOE) = 0.24589220717056418, Parameters = [26965, 45, 17702, 6498, 18239], Time = 561.27 seconds
# Iteration 52: Objective Value (LCOE) = 0.2710316202272262, Parameters = [22515, 26, 20125, 6387, 26817], Time = 572.19 seconds
# Iteration 53: Objective Value (LCOE) = 0.24512526657506634, Parameters = [24686, 35, 17761, 5117, 20030], Time = 583.03 seconds
# Iteration 54: Objective Value (LCOE) = 0.28019392716155206, Parameters = [25828, 38, 24533, 5780, 29935], Time = 593.95 seconds
# Iteration 55: Objective Value (LCOE) = 0.24717527952678078, Parameters = [20397, 42, 22835, 6150, 19605], Time = 605.10 seconds
# Iteration 56: Objective Value (LCOE) = 0.24377947995941796, Parameters = [24860, 43, 18903, 5171, 18156], Time = 616.25 seconds
# Iteration 57: Objective Value (LCOE) = 0.2874246263017659, Parameters = [40712, 44, 18203, 6341, 29441], Time = 627.26 seconds
# Iteration 58: Objective Value (LCOE) = 0.2420203423677369, Parameters = [26987, 30, 16376, 8404, 18700], Time = 638.37 seconds
# Iteration 59: Objective Value (LCOE) = 0.2545201951596926, Parameters = [28528, 23, 15958, 7225, 20939], Time = 649.55 seconds
# Iteration 60: Objective Value (LCOE) = 0.2500108783369153, Parameters = [27498, 22, 19946, 9560, 18646], Time = 660.72 seconds
# Iteration 61: Objective Value (LCOE) = 0.25540589633973204, Parameters = [22845, 20, 15948, 7806, 21134], Time = 671.76 seconds
# Iteration 62: Objective Value (LCOE) = 0.25235881573196184, Parameters = [40833, 27, 16322, 7638, 17918], Time = 682.77 seconds
# Iteration 63: Objective Value (LCOE) = 0.26444104315870365, Parameters = [32120, 22, 20075, 8788, 21859], Time = 693.48 seconds
# Iteration 64: Objective Value (LCOE) = 0.2460659751436961, Parameters = [25538, 36, 15418, 7756, 20549], Time = 704.28 seconds
# Iteration 65: Objective Value (LCOE) = 0.2477239999243852, Parameters = [26753, 27, 17861, 9419, 19844], Time = 715.04 seconds
# Iteration 66: Objective Value (LCOE) = 0.24974112860908446, Parameters = [22025, 18, 22410, 8903, 17639], Time = 725.62 seconds
# Iteration 67: Objective Value (LCOE) = 0.25028917827894714, Parameters = [28854, 25, 16015, 9628, 20011], Time = 736.25 seconds
# Iteration 68: Objective Value (LCOE) = 0.24220818189469576, Parameters = [25353, 32, 16164, 8335, 19228], Time = 747.01 seconds
# Iteration 69: Objective Value (LCOE) = 0.26397269365738063, Parameters = [28557, 24, 27950, 7051, 21526], Time = 757.63 seconds
# Iteration 70: Objective Value (LCOE) = 0.24525793105108012, Parameters = [21704, 37, 19266, 8940, 20093], Time = 768.55 seconds
# Iteration 71: Objective Value (LCOE) = 0.25214894220217976, Parameters = [32190, 26, 17470, 7981, 19781], Time = 779.18 seconds
# Iteration 72: Objective Value (LCOE) = 0.2404247677277155, Parameters = [21813, 33, 16249, 9667, 19496], Time = 790.01 seconds
# Iteration 73: Objective Value (LCOE) = 0.23768869867720063, Parameters = [22707, 34, 15930, 8747, 18471], Time = 800.97 seconds
# Iteration 74: Objective Value (LCOE) = 0.2431952447529701, Parameters = [18810, 35, 18017, 8059, 20230], Time = 811.82 seconds
# Iteration 75: Objective Value (LCOE) = 0.25376004509264855, Parameters = [19214, 14, 16606, 9272, 17605], Time = 822.87 seconds
# Iteration 76: Objective Value (LCOE) = 0.23939588071760967, Parameters = [18499, 37, 18012, 8586, 18797], Time = 834.05 seconds
# Iteration 77: Objective Value (LCOE) = 0.23643928602993045, Parameters = [20483, 27, 16090, 9086, 17883], Time = 845.14 seconds
# Iteration 78: Objective Value (LCOE) = 0.24787588850442463, Parameters = [15989, 23, 17180, 5032, 19690], Time = 856.24 seconds
# Iteration 79: Objective Value (LCOE) = 0.24013580503457324, Parameters = [23766, 22, 16270, 9529, 17233], Time = 867.44 seconds
# Iteration 80: Objective Value (LCOE) = 0.2506290254782804, Parameters = [13475, 29, 17766, 9774, 21393], Time = 878.62 seconds
# Iteration 81: Objective Value (LCOE) = 0.23802521423946474, Parameters = [22832, 30, 17895, 7753, 18012], Time = 889.67 seconds
# Iteration 82: Objective Value (LCOE) = 0.2570636626241346, Parameters = [22303, 30, 16179, 8655, 24462], Time = 900.77 seconds
# Iteration 83: Objective Value (LCOE) = 0.26940189935743225, Parameters = [23928, 34, 18899, 9698, 28037], Time = 911.57 seconds
# Iteration 84: Objective Value (LCOE) = 0.255750332603498, Parameters = [20610, 27, 28123, 8722, 21065], Time = 922.24 seconds
# Iteration 85: Objective Value (LCOE) = 0.2537220861371645, Parameters = [23393, 18, 19641, 8948, 19080], Time = 932.91 seconds
# Iteration 86: Objective Value (LCOE) = 0.2608492640558382, Parameters = [19703, 27, 16733, 7449, 24971], Time = 943.80 seconds
# Iteration 87: Objective Value (LCOE) = 0.23534594339777512, Parameters = [21309, 27, 17289, 9191, 17234], Time = 954.58 seconds
# Iteration 88: Objective Value (LCOE) = 0.23787902534663902, Parameters = [22086, 24, 18660, 9635, 17023], Time = 965.25 seconds
# Iteration 89: Objective Value (LCOE) = 0.24068262773617793, Parameters = [22904, 22, 17042, 9221, 17368], Time = 975.93 seconds
# Iteration 90: Objective Value (LCOE) = 0.24123010623982963, Parameters = [21647, 31, 17291, 7551, 19431], Time = 986.75 seconds
# Iteration 91: Objective Value (LCOE) = 0.25916650395820284, Parameters = [21132, 22, 17244, 9852, 22722], Time = 997.36 seconds
# Iteration 92: Objective Value (LCOE) = 0.2477132148223756, Parameters = [27492, 25, 17041, 8093, 19325], Time = 1008.22 seconds
# Iteration 93: Objective Value (LCOE) = 0.23418321154601207, Parameters = [20290, 26, 15187, 8477, 17222], Time = 1018.86 seconds
# Iteration 94: Objective Value (LCOE) = 0.2477970232741277, Parameters = [23549, 21, 25632, 8298, 17413], Time = 1029.65 seconds
# Iteration 95: Objective Value (LCOE) = 0.2397178978678542, Parameters = [27733, 26, 15598, 8173, 17474], Time = 1040.78 seconds
# Iteration 96: Objective Value (LCOE) = 0.2444720309143059, Parameters = [16753, 24, 24320, 8689, 17824], Time = 1052.20 seconds
# Iteration 97: Objective Value (LCOE) = 0.2419762281438419, Parameters = [20227, 23, 19465, 8457, 17900], Time = 1063.35 seconds
# Iteration 98: Objective Value (LCOE) = 0.2566388415826936, Parameters = [17262, 26, 27531, 8336, 21092], Time = 1074.40 seconds
# Iteration 99: Objective Value (LCOE) = 0.2505874125131889, Parameters = [26508, 21, 27438, 9453, 17351], Time = 1085.02 seconds
# Iteration 100: Objective Value (LCOE) = 0.25404971303179974, Parameters = [17847, 29, 19393, 9425, 22747], Time = 1095.85 seconds
# differential_evolution step 1: f(x)= 0.234183
# Iteration 101: Objective Value (LCOE) = 0.24134597702526905, Parameters = [22304, 27, 17173, 8494, 18914], Time = 1106.58 seconds
# Iteration 102: Objective Value (LCOE) = 0.23727877573828915, Parameters = [21626, 32, 16609, 6658, 18314], Time = 1117.39 seconds
# Iteration 103: Objective Value (LCOE) = 0.2739697338950334, Parameters = [21261, 26, 21078, 5117, 27568], Time = 1128.04 seconds
# Iteration 104: Objective Value (LCOE) = 0.23655661536753197, Parameters = [20048, 29, 15697, 8403, 18269], Time = 1138.81 seconds
# Iteration 105: Objective Value (LCOE) = 0.25444099852550245, Parameters = [19561, 19, 29471, 8764, 18052], Time = 1149.39 seconds
# Iteration 106: Objective Value (LCOE) = 0.24708705050096064, Parameters = [26965, 36, 24677, 9685, 18239], Time = 1160.23 seconds
# Iteration 107: Objective Value (LCOE) = 0.23564517221644427, Parameters = [19355, 32, 16662, 8534, 18044], Time = 1170.90 seconds
# Iteration 108: Objective Value (LCOE) = 0.25747470953331686, Parameters = [25214, 22, 29574, 8188, 19221], Time = 1181.59 seconds
# Iteration 109: Objective Value (LCOE) = 0.27064347508171216, Parameters = [18288, 26, 17196, 9095, 27270], Time = 1192.48 seconds
# Iteration 110: Objective Value (LCOE) = 0.23996541410503552, Parameters = [22151, 25, 20046, 9384, 17395], Time = 1203.10 seconds
# Iteration 111: Objective Value (LCOE) = 0.2716463663702572, Parameters = [17651, 21, 15537, 9171, 25902], Time = 1213.79 seconds
# Iteration 112: Objective Value (LCOE) = 0.24284452258359174, Parameters = [26931, 27, 21778, 7214, 17446], Time = 1224.69 seconds
# Iteration 113: Objective Value (LCOE) = 0.23649038794373017, Parameters = [25176, 26, 15254, 7421, 17158], Time = 1235.37 seconds
# Iteration 114: Objective Value (LCOE) = 0.24369801911272004, Parameters = [20949, 25, 16018, 8888, 19461], Time = 1246.18 seconds
# Iteration 115: Objective Value (LCOE) = 0.27001413515160233, Parameters = [17735, 22, 18857, 9071, 25081], Time = 1256.86 seconds
# Iteration 116: Objective Value (LCOE) = 0.23671152195159328, Parameters = [18627, 30, 15726, 7237, 18521], Time = 1267.65 seconds
# Iteration 117: Objective Value (LCOE) = 0.24033993751241414, Parameters = [18932, 22, 19185, 8558, 17106], Time = 1278.37 seconds
# Iteration 118: Objective Value (LCOE) = 0.27178983605548407, Parameters = [27166, 32, 18210, 8335, 27940], Time = 1289.59 seconds
# Iteration 119: Objective Value (LCOE) = 0.25006561253657444, Parameters = [20644, 24, 19970, 9520, 20432], Time = 1301.01 seconds
# Iteration 120: Objective Value (LCOE) = 0.2343666097310066, Parameters = [17250, 37, 15922, 9058, 17684], Time = 1312.22 seconds
# Iteration 121: Objective Value (LCOE) = 0.23632332374844517, Parameters = [17199, 29, 15526, 9257, 18278], Time = 1323.20 seconds
# Iteration 122: Objective Value (LCOE) = 0.23587562557352126, Parameters = [18355, 25, 15775, 8067, 17327], Time = 1333.80 seconds
# Iteration 123: Objective Value (LCOE) = 0.24081814251308176, Parameters = [19385, 30, 24603, 8842, 17833], Time = 1344.52 seconds
# Iteration 124: Objective Value (LCOE) = 0.2742347305494512, Parameters = [19614, 25, 15041, 8529, 28431], Time = 1355.13 seconds
# Iteration 125: Objective Value (LCOE) = 0.24438840381623575, Parameters = [23422, 26, 24400, 9272, 17840], Time = 1365.87 seconds
# Iteration 126: Objective Value (LCOE) = 0.23874489597845988, Parameters = [18171, 37, 22870, 8407, 17457], Time = 1376.71 seconds
# Iteration 127: Objective Value (LCOE) = 0.24621196989384672, Parameters = [19824, 30, 15857, 8795, 21391], Time = 1387.46 seconds
# Iteration 128: Objective Value (LCOE) = 0.24714725828890313, Parameters = [15989, 24, 16815, 8876, 19958], Time = 1398.32 seconds
# Iteration 129: Objective Value (LCOE) = 0.2437392699987609, Parameters = [19917, 30, 29762, 8202, 17551], Time = 1409.02 seconds
# Iteration 130: Objective Value (LCOE) = 0.23983843116864753, Parameters = [16790, 29, 24128, 9126, 17459], Time = 1419.84 seconds
# Iteration 131: Objective Value (LCOE) = 0.23611184985745923, Parameters = [18901, 23, 15065, 8297, 17116], Time = 1430.88 seconds
# Iteration 132: Objective Value (LCOE) = 0.25931320913996236, Parameters = [26449, 21, 21923, 8655, 20946], Time = 1441.46 seconds
# Iteration 133: Objective Value (LCOE) = 0.2740623360964536, Parameters = [19952, 26, 18428, 8389, 28134], Time = 1452.23 seconds
# Iteration 134: Objective Value (LCOE) = 0.2571764517931852, Parameters = [21229, 22, 19255, 9842, 21754], Time = 1463.23 seconds
# Iteration 135: Objective Value (LCOE) = 0.2351149606525985, Parameters = [18219, 24, 15538, 8975, 17096], Time = 1474.33 seconds
# Iteration 136: Objective Value (LCOE) = 0.2566140218470994, Parameters = [18842, 16, 15060, 7343, 19780], Time = 1485.23 seconds
# Iteration 137: Objective Value (LCOE) = 0.24150347300842678, Parameters = [20930, 28, 26553, 7808, 17285], Time = 1496.40 seconds
# Iteration 138: Objective Value (LCOE) = 0.24429327598815115, Parameters = [20684, 24, 27596, 8392, 17207], Time = 1507.76 seconds
# Iteration 139: Objective Value (LCOE) = 0.23632332374844517, Parameters = [17199, 29, 15526, 9257, 18278], Time = 1518.81 seconds
# Iteration 140: Objective Value (LCOE) = 0.24048067198351364, Parameters = [19810, 26, 23427, 8817, 17340], Time = 1529.90 seconds
# Iteration 141: Objective Value (LCOE) = 0.2457369995342805, Parameters = [21750, 22, 16954, 8921, 18983], Time = 1540.85 seconds
# Iteration 142: Objective Value (LCOE) = 0.2428727014747898, Parameters = [15429, 30, 27366, 8374, 17705], Time = 1551.62 seconds
# Iteration 143: Objective Value (LCOE) = 0.23716406235374704, Parameters = [20245, 33, 18709, 9191, 18121], Time = 1562.42 seconds
# Iteration 144: Objective Value (LCOE) = 0.23563561595210236, Parameters = [17284, 27, 17260, 7803, 17413], Time = 1573.22 seconds
# Iteration 145: Objective Value (LCOE) = 0.24190386001646988, Parameters = [29343, 26, 15684, 7229, 17741], Time = 1584.06 seconds
# Iteration 146: Objective Value (LCOE) = 0.25098235306633077, Parameters = [23432, 31, 17826, 6659, 22072], Time = 1595.04 seconds
# Iteration 147: Objective Value (LCOE) = 0.25297766649353803, Parameters = [21566, 24, 24045, 7982, 20323], Time = 1605.79 seconds
# Iteration 148: Objective Value (LCOE) = 0.2448383260770229, Parameters = [21582, 32, 19564, 8677, 20061], Time = 1616.57 seconds
# Iteration 149: Objective Value (LCOE) = 0.23931860119631357, Parameters = [26777, 29, 16955, 9659, 17641], Time = 1627.32 seconds
# Iteration 150: Objective Value (LCOE) = 0.23332548834248748, Parameters = [21415, 30, 16739, 6610, 17057], Time = 1638.16 seconds
# differential_evolution step 2: f(x)= 0.233325
# Iteration 151: Objective Value (LCOE) = 0.26250096681222923, Parameters = [20830, 29, 16739, 6494, 25961], Time = 1648.91 seconds
# Iteration 152: Objective Value (LCOE) = 0.2602076512458548, Parameters = [19291, 30, 19432, 6505, 24900], Time = 1659.94 seconds
# Iteration 153: Objective Value (LCOE) = 0.252336884172564, Parameters = [21006, 34, 17761, 5738, 23154], Time = 1671.25 seconds
# Iteration 154: Objective Value (LCOE) = 0.25507818318631287, Parameters = [21862, 32, 16893, 6239, 23898], Time = 1682.28 seconds
# Iteration 155: Objective Value (LCOE) = 0.23335828693085836, Parameters = [20751, 30, 16539, 6290, 17232], Time = 1693.35 seconds
# Iteration 156: Objective Value (LCOE) = 0.25120138463092645, Parameters = [26965, 33, 21072, 6914, 20749], Time = 1704.28 seconds
# Iteration 157: Objective Value (LCOE) = 0.2504575472808449, Parameters = [25076, 28, 29191, 7204, 18717], Time = 1715.12 seconds
# Iteration 158: Objective Value (LCOE) = 0.25753852726197207, Parameters = [19733, 28, 19400, 7311, 23674], Time = 1725.88 seconds
# Iteration 159: Objective Value (LCOE) = 0.23458506857180234, Parameters = [21185, 30, 18447, 6499, 17118], Time = 1736.59 seconds
# Iteration 160: Objective Value (LCOE) = 0.2375174115223833, Parameters = [24149, 30, 20046, 6388, 17104], Time = 1747.34 seconds
# Iteration 161: Objective Value (LCOE) = 0.24311232788830012, Parameters = [22792, 29, 28682, 6928, 17071], Time = 1758.06 seconds
# Iteration 162: Objective Value (LCOE) = 0.26372730451490833, Parameters = [26931, 31, 17606, 6450, 25510], Time = 1768.91 seconds
# Iteration 163: Objective Value (LCOE) = 0.23524212617518486, Parameters = [21726, 29, 16850, 6777, 17469], Time = 1779.55 seconds
# Iteration 164: Objective Value (LCOE) = 0.2353740049284878, Parameters = [22428, 35, 17018, 5297, 17419], Time = 1790.45 seconds
# Iteration 165: Objective Value (LCOE) = 0.2552999064918236, Parameters = [21446, 26, 15720, 6692, 23234], Time = 1801.16 seconds
# Iteration 166: Objective Value (LCOE) = 0.2324193925435531, Parameters = [20671, 30, 15726, 6860, 17138], Time = 1811.87 seconds
# Iteration 167: Objective Value (LCOE) = 0.2334629453940433, Parameters = [19472, 30, 15657, 8558, 17531], Time = 1822.69 seconds
# Iteration 168: Objective Value (LCOE) = 0.27251231019317695, Parameters = [20425, 25, 16120, 7279, 27772], Time = 1833.51 seconds
# Iteration 169: Objective Value (LCOE) = 0.2366643243973925, Parameters = [20644, 27, 16017, 8282, 17975], Time = 1844.38 seconds
# Iteration 170: Objective Value (LCOE) = 0.2598293168334326, Parameters = [18990, 28, 15700, 7119, 25136], Time = 1855.29 seconds
# Iteration 171: Objective Value (LCOE) = 0.24391338081936323, Parameters = [18755, 28, 18535, 9257, 19790], Time = 1866.26 seconds
# Iteration 172: Objective Value (LCOE) = 0.25398236084985953, Parameters = [23069, 30, 17285, 5869, 23109], Time = 1877.31 seconds
# Iteration 173: Objective Value (LCOE) = 0.27351605815544133, Parameters = [20729, 26, 16761, 6944, 28391], Time = 1888.50 seconds
# Iteration 174: Objective Value (LCOE) = 0.23209141038174877, Parameters = [20643, 30, 15445, 8059, 17106], Time = 1899.62 seconds
# Iteration 175: Objective Value (LCOE) = 0.24278094992027238, Parameters = [21061, 31, 15000, 8190, 20546], Time = 1910.80 seconds
# Iteration 176: Objective Value (LCOE) = 0.2319046090074821, Parameters = [19660, 30, 15386, 8354, 17108], Time = 1921.47 seconds
# Iteration 177: Objective Value (LCOE) = 0.2316204352940831, Parameters = [17587, 34, 15818, 7872, 17107], Time = 1932.28 seconds
# Iteration 178: Objective Value (LCOE) = 0.23371004506445453, Parameters = [17348, 37, 15144, 7620, 17646], Time = 1943.22 seconds
# Iteration 179: Objective Value (LCOE) = 0.23683457811415784, Parameters = [18261, 32, 16270, 9529, 18504], Time = 1954.25 seconds
# Iteration 180: Objective Value (LCOE) = 0.23293137892588886, Parameters = [18365, 34, 15984, 7959, 17459], Time = 1965.17 seconds
# Iteration 181: Objective Value (LCOE) = 0.23326206607027827, Parameters = [18413, 30, 15919, 8006, 17431], Time = 1976.11 seconds
# Iteration 182: Objective Value (LCOE) = 0.23953940700758233, Parameters = [17252, 30, 22259, 8655, 17949], Time = 1986.98 seconds
# Iteration 183: Objective Value (LCOE) = 0.23361506889264813, Parameters = [17703, 32, 18500, 7961, 17041], Time = 1997.79 seconds
# Iteration 184: Objective Value (LCOE) = 0.25697529003679664, Parameters = [17742, 34, 25824, 8722, 22836], Time = 2008.78 seconds
# Iteration 185: Objective Value (LCOE) = 0.23916490182224248, Parameters = [18219, 33, 15562, 7934, 19531], Time = 2019.83 seconds
# Iteration 186: Objective Value (LCOE) = 0.2352338169723486, Parameters = [18785, 33, 15536, 7982, 18294], Time = 2030.81 seconds
# Iteration 187: Objective Value (LCOE) = 0.23310962203667498, Parameters = [16812, 36, 16090, 7609, 17295], Time = 2042.05 seconds
# Iteration 188: Objective Value (LCOE) = 0.23577146754525602, Parameters = [18202, 36, 16164, 6842, 18145], Time = 2053.39 seconds
# Iteration 189: Objective Value (LCOE) = 0.2715739882423059, Parameters = [17104, 30, 16804, 8493, 28710], Time = 2064.74 seconds
# Iteration 190: Objective Value (LCOE) = 0.2337021471847796, Parameters = [18797, 34, 17406, 7295, 17340], Time = 2076.33 seconds
# Iteration 191: Objective Value (LCOE) = 0.23994860664266787, Parameters = [16961, 36, 26168, 7380, 17171], Time = 2087.85 seconds
# Iteration 192: Objective Value (LCOE) = 0.24085066132450414, Parameters = [16264, 36, 27366, 7717, 17172], Time = 2099.49 seconds
# Iteration 193: Objective Value (LCOE) = 0.24294674632116123, Parameters = [17487, 33, 19354, 7293, 19865], Time = 2110.97 seconds
# Iteration 194: Objective Value (LCOE) = 0.25861469533100573, Parameters = [17284, 32, 15033, 8049, 25465], Time = 2122.24 seconds
# Iteration 195: Objective Value (LCOE) = 0.24996474119349904, Parameters = [16610, 34, 16093, 8092, 22770], Time = 2133.54 seconds
# Iteration 196: Objective Value (LCOE) = 0.23433833427722858, Parameters = [16128, 36, 18483, 8176, 17125], Time = 2144.77 seconds
# Iteration 197: Objective Value (LCOE) = 0.24526313227618166, Parameters = [18466, 31, 15948, 7682, 21178], Time = 2156.04 seconds
# Iteration 198: Objective Value (LCOE) = 0.23169023463598135, Parameters = [16333, 33, 15952, 8562, 17080], Time = 2167.12 seconds
# Iteration 199: Objective Value (LCOE) = 0.2676222455665566, Parameters = [17987, 34, 25443, 7648, 26316], Time = 2178.37 seconds
# Iteration 200: Objective Value (LCOE) = 0.23301720474623516, Parameters = [16727, 34, 15726, 8990, 17546], Time = 2189.72 seconds
# differential_evolution step 3: f(x)= 0.23162
# Iteration 201: Objective Value (LCOE) = 0.23731786174155628, Parameters = [17587, 34, 15752, 7773, 18924], Time = 2201.26 seconds
# Iteration 202: Objective Value (LCOE) = 0.23275969830420065, Parameters = [15840, 38, 15044, 7141, 17240], Time = 2212.71 seconds
# Iteration 203: Objective Value (LCOE) = 0.26040196702382734, Parameters = [18033, 35, 16559, 8748, 26152], Time = 2224.05 seconds
# Iteration 204: Objective Value (LCOE) = 0.23634666241883365, Parameters = [16733, 36, 21078, 7727, 17184], Time = 2235.41 seconds
# Iteration 205: Objective Value (LCOE) = 0.27303769641478104, Parameters = [15401, 30, 21841, 7336, 27692], Time = 2246.52 seconds
# Iteration 206: Objective Value (LCOE) = 0.23331339402758533, Parameters = [15247, 36, 15818, 9136, 17349], Time = 2258.03 seconds
# Iteration 207: Objective Value (LCOE) = 0.2363232364991911, Parameters = [18975, 36, 16169, 8530, 18273], Time = 2269.46 seconds
# Iteration 208: Objective Value (LCOE) = 0.24366728859290507, Parameters = [18736, 34, 29766, 7353, 17684], Time = 2280.98 seconds
# Iteration 209: Objective Value (LCOE) = 0.25931928529464104, Parameters = [15346, 31, 18447, 7642, 24561], Time = 2292.16 seconds
# Iteration 210: Objective Value (LCOE) = 0.2641591825291166, Parameters = [13469, 33, 15672, 7676, 26453], Time = 2303.44 seconds
# Iteration 211: Objective Value (LCOE) = 0.2352519418468171, Parameters = [17536, 35, 18371, 8735, 17620], Time = 2314.85 seconds
# Iteration 212: Objective Value (LCOE) = 0.2654604765344289, Parameters = [17402, 34, 15752, 7773, 27791], Time = 2326.39 seconds
# Iteration 213: Objective Value (LCOE) = 0.23278897454578718, Parameters = [16691, 34, 15759, 7588, 17469], Time = 2337.78 seconds
# Iteration 214: Objective Value (LCOE) = 0.23412602569320012, Parameters = [22577, 31, 16394, 8881, 17215], Time = 2349.09 seconds
# Iteration 215: Objective Value (LCOE) = 0.23568759929006497, Parameters = [19632, 33, 15975, 8886, 18316], Time = 2360.37 seconds
# Iteration 216: Objective Value (LCOE) = 0.24093761861930307, Parameters = [17325, 28, 27098, 8330, 17099], Time = 2371.43 seconds
# Iteration 217: Objective Value (LCOE) = 0.2327368150797894, Parameters = [20479, 33, 16360, 8418, 17210], Time = 2382.70 seconds
# Iteration 218: Objective Value (LCOE) = 0.24006961616711636, Parameters = [19323, 30, 27005, 8244, 17062], Time = 2393.77 seconds
# Iteration 219: Objective Value (LCOE) = 0.23418243781832246, Parameters = [14908, 37, 17621, 7941, 17118], Time = 2405.12 seconds
# Iteration 220: Objective Value (LCOE) = 0.23484404064777076, Parameters = [18593, 37, 17792, 8818, 17332], Time = 2416.34 seconds
# Iteration 221: Objective Value (LCOE) = 0.2382317058319189, Parameters = [17069, 39, 22581, 7917, 17192], Time = 2427.63 seconds
# Iteration 222: Objective Value (LCOE) = 0.2454435824522183, Parameters = [15798, 36, 15550, 7639, 21319], Time = 2438.88 seconds
# Iteration 223: Objective Value (LCOE) = 0.24356431505550405, Parameters = [21813, 33, 29899, 8627, 17328], Time = 2450.12 seconds
# Iteration 224: Objective Value (LCOE) = 0.2530813623036955, Parameters = [15594, 34, 17895, 7736, 23179], Time = 2461.11 seconds
# Iteration 225: Objective Value (LCOE) = 0.2373823933419527, Parameters = [11336, 31, 15776, 8190, 17583], Time = 2471.87 seconds
# Iteration 226: Objective Value (LCOE) = 0.2359251758204136, Parameters = [20643, 35, 19733, 8009, 17324], Time = 2482.79 seconds
# Iteration 227: Objective Value (LCOE) = 0.2368832432706795, Parameters = [16774, 34, 23008, 8228, 17130], Time = 2493.60 seconds
# Iteration 228: Objective Value (LCOE) = 0.24040491155053526, Parameters = [17580, 33, 25586, 8279, 17672], Time = 2504.50 seconds
# Iteration 229: Objective Value (LCOE) = 0.2372917682964146, Parameters = [12012, 38, 18982, 8774, 17209], Time = 2515.32 seconds
# Iteration 230: Objective Value (LCOE) = 0.23218815583593289, Parameters = [18365, 34, 16621, 6837, 17076], Time = 2526.20 seconds
# Iteration 231: Objective Value (LCOE) = 0.23223539132725252, Parameters = [16732, 30, 15908, 8241, 17099], Time = 2536.96 seconds
# Iteration 232: Objective Value (LCOE) = 0.24549909249774537, Parameters = [17252, 41, 16775, 7439, 20843], Time = 2547.95 seconds
# Iteration 233: Objective Value (LCOE) = 0.23669591274194982, Parameters = [17325, 37, 21891, 7251, 17041], Time = 2559.02 seconds
# Iteration 234: Objective Value (LCOE) = 0.23500013250631, Parameters = [17918, 34, 16586, 8802, 17975], Time = 2570.13 seconds
# Iteration 235: Objective Value (LCOE) = 0.2326914538993008, Parameters = [20329, 30, 16059, 6753, 17170], Time = 2581.13 seconds
# Iteration 236: Objective Value (LCOE) = 0.23755798514970677, Parameters = [19176, 31, 18274, 7431, 18294], Time = 2592.08 seconds
# Iteration 237: Objective Value (LCOE) = 0.23175526525105902, Parameters = [19974, 33, 16090, 8696, 17000], Time = 2603.07 seconds
# Iteration 238: Objective Value (LCOE) = 0.23214148950043872, Parameters = [19245, 31, 16340, 7884, 17061], Time = 2613.82 seconds
# Iteration 239: Objective Value (LCOE) = 0.2401949156906528, Parameters = [16006, 35, 15282, 7311, 19842], Time = 2624.92 seconds
# Iteration 240: Objective Value (LCOE) = 0.23677717499994924, Parameters = [15840, 36, 19944, 7484, 17573], Time = 2635.86 seconds
# Iteration 241: Objective Value (LCOE) = 0.23737225538295084, Parameters = [15820, 42, 18132, 8228, 17587], Time = 2647.04 seconds
# Iteration 242: Objective Value (LCOE) = 0.23385896894478372, Parameters = [14370, 38, 16745, 8577, 17076], Time = 2658.23 seconds
# Iteration 243: Objective Value (LCOE) = 0.23917071698319262, Parameters = [14938, 36, 15163, 6657, 19306], Time = 2669.17 seconds
# Iteration 244: Objective Value (LCOE) = 0.2426188692310245, Parameters = [14673, 38, 28895, 8377, 17111], Time = 2680.26 seconds
# Iteration 245: Objective Value (LCOE) = 0.27891866545968186, Parameters = [15315, 36, 24900, 8173, 29642], Time = 2691.47 seconds
# Iteration 246: Objective Value (LCOE) = 0.23632411585270502, Parameters = [18132, 32, 19560, 7928, 17622], Time = 2702.48 seconds
# Iteration 247: Objective Value (LCOE) = 0.2334171170164949, Parameters = [16874, 34, 18461, 8692, 17068], Time = 2713.56 seconds
# Iteration 248: Objective Value (LCOE) = 0.23960247493535045, Parameters = [11059, 36, 16002, 7912, 18252], Time = 2724.66 seconds
# Iteration 249: Objective Value (LCOE) = 0.2323535759731961, Parameters = [18705, 32, 15931, 7206, 17189], Time = 2735.50 seconds
# Iteration 250: Objective Value (LCOE) = 0.23140391405887895, Parameters = [17789, 33, 15621, 7935, 17088], Time = 2746.46 seconds
# differential_evolution step 4: f(x)= 0.231404
# Iteration 251: Objective Value (LCOE) = 0.2388213733851433, Parameters = [18666, 29, 20770, 7758, 17909], Time = 2757.22 seconds
# Iteration 252: Objective Value (LCOE) = 0.24147754649633377, Parameters = [12897, 34, 26433, 8775, 17319], Time = 2768.25 seconds
# Iteration 253: Objective Value (LCOE) = 0.26911177852026164, Parameters = [17374, 34, 16331, 7145, 28817], Time = 2779.17 seconds
# Iteration 254: Objective Value (LCOE) = 0.23612421359553704, Parameters = [20756, 31, 16219, 9190, 18208], Time = 2790.05 seconds
# Iteration 255: Objective Value (LCOE) = 0.2337858735199259, Parameters = [20582, 33, 17850, 6953, 17193], Time = 2801.24 seconds
# Iteration 256: Objective Value (LCOE) = 0.2643247088204824, Parameters = [17262, 32, 15251, 7800, 27165], Time = 2812.34 seconds
# Iteration 257: Objective Value (LCOE) = 0.23159016104055347, Parameters = [16809, 32, 15609, 8534, 17043], Time = 2823.27 seconds
# Iteration 258: Objective Value (LCOE) = 0.23628466945481977, Parameters = [18458, 33, 22158, 7248, 17126], Time = 2834.34 seconds
# Iteration 259: Objective Value (LCOE) = 0.2568836912044154, Parameters = [17078, 33, 20978, 7465, 23844], Time = 2845.68 seconds
# Iteration 260: Objective Value (LCOE) = 0.2684257588882064, Parameters = [18135, 32, 15662, 6876, 28417], Time = 2856.49 seconds
# Iteration 261: Objective Value (LCOE) = 0.23469175112663238, Parameters = [15546, 35, 16933, 8735, 17690], Time = 2867.51 seconds
# Iteration 262: Objective Value (LCOE) = 0.23177613792946042, Parameters = [17315, 34, 15891, 7365, 17128], Time = 2878.41 seconds
# Iteration 263: Objective Value (LCOE) = 0.2331711421559421, Parameters = [14297, 34, 15888, 7863, 17324], Time = 2889.43 seconds
# Iteration 264: Objective Value (LCOE) = 0.23851801447314364, Parameters = [18069, 33, 24755, 7643, 17258], Time = 2900.43 seconds
# Iteration 265: Objective Value (LCOE) = 0.23217678072392056, Parameters = [18784, 34, 15672, 7896, 17254], Time = 2911.58 seconds
# Iteration 266: Objective Value (LCOE) = 0.24827440488786087, Parameters = [21282, 31, 16739, 8007, 21848], Time = 2922.85 seconds
# Iteration 267: Objective Value (LCOE) = 0.23880402013651164, Parameters = [17602, 32, 16881, 7754, 19004], Time = 2934.35 seconds
# Iteration 268: Objective Value (LCOE) = 0.23258254356022087, Parameters = [16858, 35, 16455, 8151, 17188], Time = 2945.75 seconds
# Iteration 269: Objective Value (LCOE) = 0.27677577354608757, Parameters = [14908, 32, 17507, 6306, 29937], Time = 2957.08 seconds
# Iteration 270: Objective Value (LCOE) = 0.24029765699505465, Parameters = [18610, 31, 26229, 8194, 17380], Time = 2968.32 seconds
# Iteration 271: Objective Value (LCOE) = 0.2315921099931007, Parameters = [17199, 31, 15088, 7597, 17176], Time = 2979.47 seconds
# Iteration 272: Objective Value (LCOE) = 0.23306497033637888, Parameters = [19356, 32, 15853, 6485, 17417], Time = 2990.72 seconds
# Iteration 273: Objective Value (LCOE) = 0.2316097210544761, Parameters = [18867, 33, 15819, 7302, 17086], Time = 3001.96 seconds
# Iteration 274: Objective Value (LCOE) = 0.23364804215547047, Parameters = [16811, 38, 16868, 8081, 17138], Time = 3013.46 seconds
# Iteration 275: Objective Value (LCOE) = 0.23206042262588253, Parameters = [17159, 32, 16065, 8190, 17097], Time = 3024.51 seconds
# Iteration 276: Objective Value (LCOE) = 0.23265148780076483, Parameters = [16815, 32, 16077, 7895, 17263], Time = 3035.69 seconds
# Iteration 277: Objective Value (LCOE) = 0.23314647205968078, Parameters = [16813, 35, 15386, 8354, 17615], Time = 3047.15 seconds
# Iteration 278: Objective Value (LCOE) = 0.23309419144561816, Parameters = [17939, 36, 16046, 7970, 17305], Time = 3058.75 seconds
# Iteration 279: Objective Value (LCOE) = 0.23443190493952354, Parameters = [17977, 31, 17507, 7917, 17525], Time = 3070.04 seconds
# Iteration 280: Objective Value (LCOE) = 0.23217001731589004, Parameters = [17013, 35, 15724, 6837, 17239], Time = 3081.43 seconds
# Iteration 281: Objective Value (LCOE) = 0.261611299446817, Parameters = [17246, 33, 16164, 8241, 26387], Time = 3092.78 seconds
# Iteration 282: Objective Value (LCOE) = 0.26927440091196014, Parameters = [18812, 32, 16060, 7997, 28656], Time = 3103.92 seconds
# Iteration 283: Objective Value (LCOE) = 0.23156257382728046, Parameters = [17324, 34, 15432, 8833, 17163], Time = 3115.22 seconds
# Iteration 284: Objective Value (LCOE) = 0.23321193823118322, Parameters = [21402, 32, 16408, 6791, 17105], Time = 3126.33 seconds
# Iteration 285: Objective Value (LCOE) = 0.24024108210287962, Parameters = [20616, 32, 26911, 7508, 17077], Time = 3137.58 seconds
# Iteration 286: Objective Value (LCOE) = 0.2317609385532947, Parameters = [18785, 33, 15646, 7916, 17170], Time = 3148.73 seconds
# Iteration 287: Objective Value (LCOE) = 0.23701454107866649, Parameters = [14399, 35, 22040, 9150, 17117], Time = 3159.99 seconds
# Iteration 288: Objective Value (LCOE) = 0.2398709058087837, Parameters = [16041, 36, 26700, 7884, 17015], Time = 3171.46 seconds
# Iteration 289: Objective Value (LCOE) = 0.2317373045739603, Parameters = [19168, 34, 16118, 8481, 17000], Time = 3182.98 seconds
# Iteration 290: Objective Value (LCOE) = 0.23515594197230894, Parameters = [18152, 33, 20696, 7923, 17119], Time = 3194.39 seconds
# Iteration 291: Objective Value (LCOE) = 0.23749445614622586, Parameters = [16802, 33, 18132, 8550, 18430], Time = 3205.98 seconds
# Iteration 292: Objective Value (LCOE) = 0.23493507007412265, Parameters = [16745, 32, 18802, 9013, 17352], Time = 3217.31 seconds
# Iteration 293: Objective Value (LCOE) = 0.25140391653650634, Parameters = [12619, 38, 15538, 8263, 22534], Time = 3228.80 seconds
# Iteration 294: Objective Value (LCOE) = 0.23219667883987347, Parameters = [17706, 33, 15275, 7655, 17413], Time = 3239.92 seconds
# Iteration 295: Objective Value (LCOE) = 0.26054377317263316, Parameters = [18130, 36, 23683, 7595, 24454], Time = 3251.23 seconds
# Iteration 296: Objective Value (LCOE) = 0.2501068478820087, Parameters = [14438, 34, 19349, 8176, 21745], Time = 3262.37 seconds
# Iteration 297: Objective Value (LCOE) = 0.23150587344733217, Parameters = [15928, 32, 15396, 7847, 17033], Time = 3273.57 seconds
# Iteration 298: Objective Value (LCOE) = 0.2314647308804365, Parameters = [19112, 33, 15667, 7388, 17062], Time = 3285.21 seconds
# Iteration 299: Objective Value (LCOE) = 0.2752988762939902, Parameters = [12750, 37, 15730, 7786, 29905], Time = 3296.62 seconds
# Iteration 300: Objective Value (LCOE) = 0.2317126424321191, Parameters = [17980, 34, 15842, 8226, 17107], Time = 3308.00 seconds
# differential_evolution step 5: f(x)= 0.231404
# Iteration 301: Objective Value (LCOE) = 0.23443389554430336, Parameters = [16767, 33, 15719, 8729, 18021], Time = 3319.44 seconds
# Iteration 302: Objective Value (LCOE) = 0.23295780656725373, Parameters = [15840, 34, 17547, 7073, 17090], Time = 3330.69 seconds
# Iteration 303: Objective Value (LCOE) = 0.24115179155882618, Parameters = [17839, 33, 16129, 7112, 20030], Time = 3342.05 seconds
# Iteration 304: Objective Value (LCOE) = 0.23315501732633875, Parameters = [20756, 35, 15871, 7867, 17309], Time = 3353.48 seconds
# Iteration 305: Objective Value (LCOE) = 0.23185411868705585, Parameters = [18687, 32, 15829, 8176, 17056], Time = 3364.67 seconds
# Iteration 306: Objective Value (LCOE) = 0.23180336019807263, Parameters = [16824, 35, 15822, 7711, 17087], Time = 3376.09 seconds
# Iteration 307: Objective Value (LCOE) = 0.24123154170194905, Parameters = [18524, 32, 28203, 7693, 17222], Time = 3387.10 seconds
# Iteration 308: Objective Value (LCOE) = 0.23136853748702532, Parameters = [19381, 31, 15097, 7248, 17093], Time = 3398.31 seconds
# Iteration 309: Objective Value (LCOE) = 0.23614036120723933, Parameters = [19625, 30, 15208, 7130, 18444], Time = 3409.89 seconds
# Iteration 310: Objective Value (LCOE) = 0.24284487358611087, Parameters = [24149, 29, 15266, 6699, 19753], Time = 3421.17 seconds
# Iteration 311: Objective Value (LCOE) = 0.2501285466666635, Parameters = [20076, 28, 26669, 6846, 19870], Time = 3432.44 seconds
# Iteration 312: Objective Value (LCOE) = 0.23323623899316556, Parameters = [21616, 28, 15284, 7365, 17128], Time = 3443.77 seconds
# Iteration 313: Objective Value (LCOE) = 0.23988846255380183, Parameters = [21399, 34, 26039, 7588, 17066], Time = 3455.13 seconds
# Iteration 314: Objective Value (LCOE) = 0.23375690671223026, Parameters = [22577, 31, 16336, 7464, 17111], Time = 3466.49 seconds
# Iteration 315: Objective Value (LCOE) = 0.23621797329389047, Parameters = [18487, 33, 22029, 7689, 17141], Time = 3477.70 seconds
# Iteration 316: Objective Value (LCOE) = 0.23239955334424428, Parameters = [19398, 30, 15777, 7223, 17195], Time = 3489.03 seconds
# Iteration 317: Objective Value (LCOE) = 0.2321769553022514, Parameters = [19780, 30, 15730, 8418, 17109], Time = 3500.30 seconds
# Iteration 318: Objective Value (LCOE) = 0.2350994203314914, Parameters = [17750, 29, 18070, 7614, 17391], Time = 3511.66 seconds
# Iteration 319: Objective Value (LCOE) = 0.24182876889213126, Parameters = [17145, 35, 29462, 6820, 17156], Time = 3522.83 seconds
# Iteration 320: Objective Value (LCOE) = 0.23278272671606098, Parameters = [17823, 35, 16035, 7130, 17366], Time = 3534.20 seconds
# Iteration 321: Objective Value (LCOE) = 0.2320036703387777, Parameters = [17199, 29, 15055, 7576, 17104], Time = 3545.71 seconds
# Iteration 322: Objective Value (LCOE) = 0.231588076911298, Parameters = [18880, 32, 15190, 6684, 17130], Time = 3557.04 seconds
# Iteration 323: Objective Value (LCOE) = 0.24025586421012746, Parameters = [19829, 31, 27638, 7613, 17002], Time = 3568.40 seconds
# Iteration 324: Objective Value (LCOE) = 0.25512412515400484, Parameters = [18139, 32, 15726, 6860, 24288], Time = 3579.70 seconds
# Iteration 325: Objective Value (LCOE) = 0.236151810636171, Parameters = [17159, 32, 15588, 7397, 18455], Time = 3590.98 seconds
# Iteration 326: Objective Value (LCOE) = 0.23674755719989396, Parameters = [17058, 32, 22633, 7437, 17091], Time = 3602.12 seconds
# Iteration 327: Objective Value (LCOE) = 0.23136226361927617, Parameters = [17774, 32, 15236, 7527, 17065], Time = 3613.21 seconds
# Iteration 328: Objective Value (LCOE) = 0.23187603082598784, Parameters = [16522, 33, 15544, 7685, 17240], Time = 3624.26 seconds
# Iteration 329: Objective Value (LCOE) = 0.2423131268645044, Parameters = [20297, 28, 28747, 6974, 17089], Time = 3635.35 seconds
# Iteration 330: Objective Value (LCOE) = 0.2730969391990035, Parameters = [18992, 31, 15579, 6837, 29879], Time = 3646.11 seconds
# Iteration 331: Objective Value (LCOE) = 0.23281332886199743, Parameters = [16533, 32, 16196, 7461, 17260], Time = 3656.97 seconds
# Iteration 332: Objective Value (LCOE) = 0.23118158974004466, Parameters = [18045, 34, 15228, 7119, 17078], Time = 3667.91 seconds
# Iteration 333: Objective Value (LCOE) = 0.2398499135253141, Parameters = [15757, 35, 27134, 6781, 17046], Time = 3678.87 seconds
# Iteration 334: Objective Value (LCOE) = 0.2320482540946639, Parameters = [15990, 36, 15740, 7427, 17034], Time = 3689.93 seconds
# Iteration 335: Objective Value (LCOE) = 0.23148038688848607, Parameters = [19179, 33, 15568, 6817, 17087], Time = 3700.80 seconds
# Iteration 336: Objective Value (LCOE) = 0.23210932750640884, Parameters = [18510, 33, 15646, 6910, 17297], Time = 3711.91 seconds
# Iteration 337: Objective Value (LCOE) = 0.23909374905960426, Parameters = [14219, 34, 25360, 7799, 17045], Time = 3722.76 seconds
# Iteration 338: Objective Value (LCOE) = 0.2311720841745855, Parameters = [17045, 33, 15562, 7844, 17064], Time = 3733.72 seconds
# Iteration 339: Objective Value (LCOE) = 0.23115282434382595, Parameters = [16620, 34, 15604, 7325, 17000], Time = 3745.07 seconds
# Iteration 340: Objective Value (LCOE) = 0.23286117852017463, Parameters = [16470, 34, 17406, 7674, 17107], Time = 3756.11 seconds
# Iteration 341: Objective Value (LCOE) = 0.2319970745960625, Parameters = [15510, 36, 15579, 7145, 17021], Time = 3766.91 seconds
# Iteration 342: Objective Value (LCOE) = 0.24746338653736683, Parameters = [16917, 34, 15846, 7560, 22078], Time = 3777.86 seconds
# Iteration 343: Objective Value (LCOE) = 0.23504379791331734, Parameters = [21309, 36, 15348, 7277, 17768], Time = 3788.85 seconds
# Iteration 344: Objective Value (LCOE) = 0.2484096651603467, Parameters = [16369, 35, 15389, 6922, 22435], Time = 3800.04 seconds
# Iteration 345: Objective Value (LCOE) = 0.2447978418841778, Parameters = [17452, 34, 16846, 6988, 21025], Time = 3811.09 seconds
# Iteration 346: Objective Value (LCOE) = 0.2385250690309197, Parameters = [19072, 36, 17864, 7187, 18601], Time = 3822.02 seconds
# Iteration 347: Objective Value (LCOE) = 0.2682338169466573, Parameters = [16100, 36, 15114, 7434, 28665], Time = 3832.97 seconds
# Iteration 348: Objective Value (LCOE) = 0.24461006892466253, Parameters = [17505, 32, 16552, 7601, 20852], Time = 3843.79 seconds
# Iteration 349: Objective Value (LCOE) = 0.23153799631234578, Parameters = [16628, 34, 15920, 7313, 17048], Time = 3854.78 seconds
# Iteration 350: Objective Value (LCOE) = 0.2316540892493719, Parameters = [15255, 34, 15679, 6982, 17027], Time = 3865.67 seconds
# differential_evolution step 6: f(x)= 0.231153
# Iteration 351: Objective Value (LCOE) = 0.27099865362149106, Parameters = [17298, 33, 15179, 6833, 29543], Time = 3876.73 seconds
# Iteration 352: Objective Value (LCOE) = 0.23142674879296082, Parameters = [16163, 35, 15470, 7545, 17036], Time = 3887.54 seconds
# Iteration 353: Objective Value (LCOE) = 0.23157975143002416, Parameters = [16302, 35, 15800, 7387, 17008], Time = 3898.76 seconds
# Iteration 354: Objective Value (LCOE) = 0.23149919330694296, Parameters = [17204, 35, 15632, 7349, 17036], Time = 3910.12 seconds
# Iteration 355: Objective Value (LCOE) = 0.26922432272346586, Parameters = [17892, 33, 15835, 7173, 28894], Time = 3921.16 seconds
# Iteration 356: Objective Value (LCOE) = 0.23142741690173793, Parameters = [17165, 35, 15472, 7226, 17053], Time = 3932.17 seconds
# Iteration 357: Objective Value (LCOE) = 0.2317315626669199, Parameters = [16809, 35, 15553, 7106, 17124], Time = 3943.11 seconds
# Iteration 358: Objective Value (LCOE) = 0.25080819132925536, Parameters = [16336, 35, 16000, 7491, 23048], Time = 3954.00 seconds
# Iteration 359: Objective Value (LCOE) = 0.23114231821266454, Parameters = [17976, 33, 15538, 7173, 17030], Time = 3964.88 seconds
# Iteration 360: Objective Value (LCOE) = 0.23135695302699305, Parameters = [16886, 32, 15481, 7518, 17012], Time = 3975.75 seconds
# Iteration 361: Objective Value (LCOE) = 0.23165867533354978, Parameters = [17679, 32, 15819, 7532, 17037], Time = 3986.50 seconds
# Iteration 362: Objective Value (LCOE) = 0.231558631252985, Parameters = [18888, 32, 15444, 6884, 17062], Time = 3997.39 seconds
# Iteration 363: Objective Value (LCOE) = 0.23157015066672526, Parameters = [17403, 32, 15621, 7470, 17034], Time = 4008.12 seconds
# ...
# Iteration 947: Objective Value (LCOE) = 0.23058796282219876, Parameters = [17034, 33, 15007, 7559, 17000], Time = 10426.30 seconds
# Iteration 948: Objective Value (LCOE) = 0.23141741228722149, Parameters = [17084, 33, 16148, 7548, 17002], Time = 10437.17 seconds
# Iteration 949: Objective Value (LCOE) = 0.23059640957136038, Parameters = [17040, 33, 15006, 7560, 17006], Time = 10448.22 seconds
# Iteration 950: Objective Value (LCOE) = 0.23057999303055896, Parameters = [17040, 33, 15010, 7536, 17000], Time = 10459.01 seconds
# differential_evolution step 18: f(x)= 0.230563
# Iteration 951: Objective Value (LCOE) = 0.23064375137221343, Parameters = [16894, 33, 15041, 7492, 17001], Time = 10469.89 seconds
# Iteration 952: Objective Value (LCOE) = 0.23056888058706906, Parameters = [17054, 33, 15002, 7503, 17000], Time = 10480.50 seconds
# Iteration 953: Objective Value (LCOE) = 0.23056900203674435, Parameters = [17050, 33, 15001, 7518, 17001], Time = 10491.50 seconds
# Iteration 954: Objective Value (LCOE) = 0.2378926696877544, Parameters = [17080, 33, 15008, 7562, 19272], Time = 10502.50 seconds
# Iteration 955: Objective Value (LCOE) = 0.2656074123841008, Parameters = [16995, 33, 15011, 7554, 27880], Time = 10513.31 seconds
# Iteration 956: Objective Value (LCOE) = 0.2555539034428532, Parameters = [17054, 33, 18568, 7430, 23974], Time = 10524.15 seconds
# Iteration 957: Objective Value (LCOE) = 0.23060839071895892, Parameters = [16986, 33, 15013, 7489, 17001], Time = 10535.09 seconds
# Iteration 958: Objective Value (LCOE) = 0.23161741077804313, Parameters = [17050, 33, 15006, 7483, 17326], Time = 10546.06 seconds
# Iteration 959: Objective Value (LCOE) = 0.25852078549880714, Parameters = [17016, 33, 15004, 7544, 25682], Time = 10556.95 seconds
# Iteration 960: Objective Value (LCOE) = 0.23063537545847845, Parameters = [16880, 33, 15045, 7518, 17000], Time = 10568.08 seconds
# Iteration 961: Objective Value (LCOE) = 0.25906850446694946, Parameters = [17002, 33, 15001, 7510, 25849], Time = 10578.93 seconds
# Iteration 962: Objective Value (LCOE) = 0.24729304808718885, Parameters = [17039, 33, 15004, 7568, 22199], Time = 10589.75 seconds
# Iteration 963: Objective Value (LCOE) = 0.24735217585264102, Parameters = [17053, 33, 20731, 7502, 20939], Time = 10600.52 seconds
# Iteration 964: Objective Value (LCOE) = 0.2644114116299959, Parameters = [17055, 33, 15006, 7541, 27526], Time = 10612.01 seconds
# Iteration 965: Objective Value (LCOE) = 0.2306091895646032, Parameters = [16967, 33, 15015, 7494, 17000], Time = 10623.43 seconds
# Iteration 966: Objective Value (LCOE) = 0.2305701890747843, Parameters = [17052, 33, 15001, 7486, 17001], Time = 10634.55 seconds
# Iteration 967: Objective Value (LCOE) = 0.2349602504407798, Parameters = [17044, 33, 21111, 7512, 17001], Time = 10645.41 seconds
# Iteration 968: Objective Value (LCOE) = 0.23056997715571664, Parameters = [17051, 33, 15006, 7512, 17000], Time = 10656.32 seconds
# Iteration 969: Objective Value (LCOE) = 0.26359330863531566, Parameters = [17041, 33, 15002, 7539, 27275], Time = 10667.38 seconds
# Iteration 970: Objective Value (LCOE) = 0.24806986722210841, Parameters = [16958, 33, 15016, 7522, 22419], Time = 10678.24 seconds
# Iteration 971: Objective Value (LCOE) = 0.2699757886200138, Parameters = [17037, 33, 15004, 7564, 29246], Time = 10689.27 seconds
# Iteration 972: Objective Value (LCOE) = 0.23901314875894955, Parameters = [17042, 33, 15006, 7540, 19628], Time = 10700.03 seconds
# Iteration 973: Objective Value (LCOE) = 0.26792820033327647, Parameters = [16787, 33, 28854, 7479, 25474], Time = 10710.88 seconds
# Iteration 974: Objective Value (LCOE) = 0.23057783518627836, Parameters = [17040, 33, 15007, 7453, 17000], Time = 10721.53 seconds
# Iteration 975: Objective Value (LCOE) = 0.23057191876819794, Parameters = [17047, 33, 15012, 7512, 17000], Time = 10732.62 seconds
# Iteration 976: Objective Value (LCOE) = 0.2305785544677052, Parameters = [17040, 33, 15008, 7558, 17000], Time = 10743.57 seconds
# Iteration 977: Objective Value (LCOE) = 0.24052926509895733, Parameters = [17038, 33, 28826, 7504, 17004], Time = 10754.51 seconds
# Iteration 978: Objective Value (LCOE) = 0.23059688063770845, Parameters = [17037, 33, 15008, 7564, 17002], Time = 10765.45 seconds
# Iteration 979: Objective Value (LCOE) = 0.2306011184637715, Parameters = [17035, 33, 15020, 7603, 17001], Time = 10776.38 seconds
# Iteration 980: Objective Value (LCOE) = 0.23061568995524923, Parameters = [16884, 33, 15001, 7537, 17003], Time = 10787.51 seconds
# Iteration 981: Objective Value (LCOE) = 0.2611247374277389, Parameters = [17033, 33, 15008, 7457, 26494], Time = 10798.87 seconds
# Iteration 982: Objective Value (LCOE) = 0.24071137585574898, Parameters = [16992, 33, 15007, 7559, 20145], Time = 10810.39 seconds
# Iteration 983: Objective Value (LCOE) = 0.23419415279306502, Parameters = [17042, 33, 15006, 7599, 18129], Time = 10821.51 seconds
# Iteration 984: Objective Value (LCOE) = 0.23058078194775145, Parameters = [17065, 33, 15005, 7556, 17001], Time = 10832.80 seconds
# Iteration 985: Objective Value (LCOE) = 0.25423520536934496, Parameters = [17031, 33, 27365, 7496, 21589], Time = 10843.81 seconds
# Iteration 986: Objective Value (LCOE) = 0.23281913057178255, Parameters = [17054, 33, 18126, 7512, 17001], Time = 10855.08 seconds
# Iteration 987: Objective Value (LCOE) = 0.23720804450548413, Parameters = [17041, 33, 24243, 7513, 17000], Time = 10866.18 seconds
# Iteration 988: Objective Value (LCOE) = 0.23923240068631674, Parameters = [17038, 33, 15015, 7574, 19690], Time = 10877.02 seconds
# Iteration 989: Objective Value (LCOE) = 0.23057776348900527, Parameters = [17052, 33, 15016, 7527, 17000], Time = 10887.90 seconds
# Iteration 990: Objective Value (LCOE) = 0.23058105079736313, Parameters = [17040, 33, 15007, 7523, 17001], Time = 10898.92 seconds
# Iteration 991: Objective Value (LCOE) = 0.2389785780189166, Parameters = [17115, 33, 26639, 7580, 17001], Time = 10909.94 seconds
# Iteration 992: Objective Value (LCOE) = 0.27049330930110416, Parameters = [17016, 33, 27883, 7540, 26524], Time = 10920.84 seconds
# Iteration 993: Objective Value (LCOE) = 0.2810589672898178, Parameters = [17042, 33, 28123, 7505, 29772], Time = 10931.88 seconds
# Iteration 994: Objective Value (LCOE) = 0.23064914067281636, Parameters = [17127, 33, 15031, 7666, 17005], Time = 10942.68 seconds
# Iteration 995: Objective Value (LCOE) = 0.23208424997176805, Parameters = [17101, 33, 17070, 7540, 17000], Time = 10953.53 seconds
# Iteration 996: Objective Value (LCOE) = 0.23056891156735204, Parameters = [17045, 33, 15005, 7501, 17001], Time = 10964.31 seconds
# Iteration 997: Objective Value (LCOE) = 0.23058867143854378, Parameters = [16991, 33, 15005, 7559, 17000], Time = 10975.51 seconds
# Iteration 998: Objective Value (LCOE) = 0.24404574737356405, Parameters = [17038, 33, 15001, 7509, 21190], Time = 10986.58 seconds
# Iteration 999: Objective Value (LCOE) = 0.23060471132767074, Parameters = [17037, 33, 15001, 7559, 17006], Time = 10997.55 seconds
# Iteration 1000: Objective Value (LCOE) = 0.23761706427353815, Parameters = [17080, 33, 24775, 7466, 17001], Time = 11008.88 seconds
# differential_evolution step 19: f(x)= 0.230563
# Iteration 1001: Objective Value (LCOE) = 0.23058626283256306, Parameters = [17036, 33, 15003, 7534, 17000], Time = 11020.41 seconds
# Iteration 1002: Objective Value (LCOE) = 0.23065713489904105, Parameters = [16938, 33, 15029, 7548, 17000], Time = 11031.61 seconds
# Iteration 1003: Objective Value (LCOE) = 0.23314012486976982, Parameters = [17147, 33, 18500, 7546, 17000], Time = 11042.54 seconds
# Iteration 1004: Objective Value (LCOE) = 0.23455444602071884, Parameters = [17040, 33, 15001, 7510, 18238], Time = 11053.61 seconds
# Iteration 1005: Objective Value (LCOE) = 0.23057094364922567, Parameters = [17046, 33, 15007, 7500, 17001], Time = 11064.42 seconds
# Iteration 1006: Objective Value (LCOE) = 0.24286649328389892, Parameters = [17090, 33, 20632, 7567, 19559], Time = 11075.33 seconds
# Iteration 1007: Objective Value (LCOE) = 0.2716160417370395, Parameters = [17050, 33, 15006, 7516, 29768], Time = 11086.03 seconds
# Iteration 1008: Objective Value (LCOE) = 0.23056506794813544, Parameters = [17050, 33, 15000, 7530, 17000], Time = 11097.11 seconds
# Iteration 1009: Objective Value (LCOE) = 0.263519403481863, Parameters = [17038, 33, 26307, 7570, 24717], Time = 11108.10 seconds
# Iteration 1010: Objective Value (LCOE) = 0.2305680355432353, Parameters = [17055, 33, 15000, 7495, 17000], Time = 11118.95 seconds
# Iteration 1011: Objective Value (LCOE) = 0.2589290495608431, Parameters = [17027, 33, 15010, 7583, 25812], Time = 11129.79 seconds
# Iteration 1012: Objective Value (LCOE) = 0.23056485171633617, Parameters = [17046, 33, 15003, 7507, 17000], Time = 11140.80 seconds
# Iteration 1013: Objective Value (LCOE) = 0.23139561012533696, Parameters = [17037, 33, 15005, 7580, 17251], Time = 11151.84 seconds
# Iteration 1014: Objective Value (LCOE) = 0.25070298614349057, Parameters = [17003, 33, 15011, 7546, 23247], Time = 11162.79 seconds
# Iteration 1015: Objective Value (LCOE) = 0.24541609376961887, Parameters = [17036, 33, 15006, 7560, 21610], Time = 11173.84 seconds
# Iteration 1016: Objective Value (LCOE) = 0.23059404421486762, Parameters = [17037, 33, 15013, 7551, 17000], Time = 11184.65 seconds
# Iteration 1017: Objective Value (LCOE) = 0.23056450972213002, Parameters = [17043, 33, 15005, 7525, 17000], Time = 11195.66 seconds
# Iteration 1018: Objective Value (LCOE) = 0.23056425819731624, Parameters = [17045, 33, 15003, 7547, 17000], Time = 11206.32 seconds
# Iteration 1019: Objective Value (LCOE) = 0.2544453698738949, Parameters = [17077, 33, 15010, 7557, 24421], Time = 11217.45 seconds
# Iteration 1020: Objective Value (LCOE) = 0.23057652821975602, Parameters = [17047, 33, 15005, 7531, 17003], Time = 11229.01 seconds
# Iteration 1021: Objective Value (LCOE) = 0.2655858998818948, Parameters = [17043, 33, 15004, 7532, 27894], Time = 11240.17 seconds
# Iteration 1022: Objective Value (LCOE) = 0.23699943139787136, Parameters = [17041, 33, 23363, 7475, 17132], Time = 11251.35 seconds
# Iteration 1023: Objective Value (LCOE) = 0.24643064948711657, Parameters = [17028, 33, 15010, 7563, 21926], Time = 11262.12 seconds
# Iteration 1024: Objective Value (LCOE) = 0.2305742575512633, Parameters = [17057, 33, 15007, 7549, 17000], Time = 11273.07 seconds
# Iteration 1025: Objective Value (LCOE) = 0.2521316846129568, Parameters = [17048, 33, 15004, 7529, 23708], Time = 11284.17 seconds
# Iteration 1026: Objective Value (LCOE) = 0.23057521405389414, Parameters = [17038, 33, 15005, 7558, 17000], Time = 11295.13 seconds
# Iteration 1027: Objective Value (LCOE) = 0.25885165988883096, Parameters = [17034, 33, 15004, 7535, 25788], Time = 11306.17 seconds
# Iteration 1028: Objective Value (LCOE) = 0.23057999303055896, Parameters = [17040, 33, 15010, 7540, 17000], Time = 11317.11 seconds
# Iteration 1029: Objective Value (LCOE) = 0.23056319692168314, Parameters = [17042, 33, 15004, 7532, 17000], Time = 11328.10 seconds
# Iteration 1030: Objective Value (LCOE) = 0.2722123367655152, Parameters = [17043, 33, 15005, 7526, 29955], Time = 11339.15 seconds
# Iteration 1031: Objective Value (LCOE) = 0.2479739591593411, Parameters = [17041, 33, 16899, 7500, 21992], Time = 11350.17 seconds
# Iteration 1032: Objective Value (LCOE) = 0.23058567426452717, Parameters = [17035, 33, 15003, 7456, 17000], Time = 11361.30 seconds
# Iteration 1033: Objective Value (LCOE) = 0.2305700081359995, Parameters = [17042, 33, 15009, 7467, 17001], Time = 11372.36 seconds
# Iteration 1034: Objective Value (LCOE) = 0.2418987328079786, Parameters = [17041, 33, 15005, 7563, 20526], Time = 11383.27 seconds
# Iteration 1035: Objective Value (LCOE) = 0.23057665829489454, Parameters = [17049, 33, 15008, 7550, 17002], Time = 11394.75 seconds
# Iteration 1036: Objective Value (LCOE) = 0.2399901603554438, Parameters = [17033, 33, 28075, 7534, 17001], Time = 11405.70 seconds
# Iteration 1037: Objective Value (LCOE) = 0.23059115938008093, Parameters = [17044, 33, 15001, 7520, 17009], Time = 11417.29 seconds
# Iteration 1038: Objective Value (LCOE) = 0.24385046707441735, Parameters = [17047, 33, 15005, 7557, 21132], Time = 11428.71 seconds
# Iteration 1039: Objective Value (LCOE) = 0.25773128089232666, Parameters = [17044, 33, 15002, 7539, 25451], Time = 11440.21 seconds
# Iteration 1040: Objective Value (LCOE) = 0.23057459523273788, Parameters = [17057, 33, 15003, 7498, 17001], Time = 11451.24 seconds
# Iteration 1041: Objective Value (LCOE) = 0.23742167108926351, Parameters = [17041, 33, 24540, 7536, 17000], Time = 11462.12 seconds
# Iteration 1042: Objective Value (LCOE) = 0.2305665418040037, Parameters = [17044, 33, 15007, 7535, 17000], Time = 11472.90 seconds
# Iteration 1043: Objective Value (LCOE) = 0.23057365971951177, Parameters = [17053, 33, 15005, 7517, 17001], Time = 11483.75 seconds
# Iteration 1044: Objective Value (LCOE) = 0.23058593569130917, Parameters = [17033, 33, 15005, 7552, 17000], Time = 11494.85 seconds
# Iteration 1045: Objective Value (LCOE) = 0.23057094796195732, Parameters = [17049, 33, 15009, 7560, 17000], Time = 11505.87 seconds
# Iteration 1046: Objective Value (LCOE) = 0.23056616020405146, Parameters = [17044, 33, 15002, 7494, 17001], Time = 11516.78 seconds
# Iteration 1047: Objective Value (LCOE) = 0.25490439941763515, Parameters = [17034, 33, 15003, 7485, 24561], Time = 11527.68 seconds
# Iteration 1048: Objective Value (LCOE) = 0.2661305255711048, Parameters = [17036, 33, 15007, 7535, 28050], Time = 11538.52 seconds
# Iteration 1049: Objective Value (LCOE) = 0.23057220893152505, Parameters = [17039, 33, 15000, 7528, 17000], Time = 11549.50 seconds
# Iteration 1050: Objective Value (LCOE) = 0.23065978416001987, Parameters = [16937, 33, 15029, 7525, 17001], Time = 11560.47 seconds
# differential_evolution step 20: f(x)= 0.230563
# Polishing solution with 'L-BFGS-B'
# Iteration 1051: Objective Value (LCOE) = 0.23056319692168314, Parameters = [17042, 33, 15004, 7532, 17000], Time = 11571.49 seconds
# Iteration 1052: Objective Value (LCOE) = 0.23056319692168314, Parameters = [17042, 33, 15004, 7532, 17000], Time = 11582.24 seconds
# Iteration 1053: Objective Value (LCOE) = 0.23056319692168314, Parameters = [17042, 33, 15004, 7532, 17000], Time = 11593.45 seconds
# Iteration 1054: Objective Value (LCOE) = 0.23056319692168314, Parameters = [17042, 33, 15004, 7532, 17000], Time = 11605.00 seconds
# Iteration 1055: Objective Value (LCOE) = 0.23056319692168314, Parameters = [17042, 33, 15004, 7532, 17000], Time = 11616.61 seconds
# Iteration 1056: Objective Value (LCOE) = 0.23056319692168314, Parameters = [17042, 33, 15004, 7532, 17000], Time = 11627.59 seconds
# Differential Evolution optimization successful. LCOE: 0.230563, Iterations: 0, Total Time: 11627.60 seconds
# Differential Evolution optimization successful. LCOE: 0.230563, Iterations: 0, Time: 11627.60 seconds
#
# Optimization comparison results are saved in the 'optimization_iterations' directory.
#
# Best results for each deposit:
#                    Method  Iterations  Duration (seconds)      LCOE
# 0  Differential Evolution           0        11627.595202  0.230563
#
# Method performance summary:
#                        Iterations         Duration (seconds)                \
#                            median min max             median           min
# Method
# Differential Evolution        0.0   0   0       11627.595202  11627.595202
#
#                                           LCOE
#                                  max    median       min       max  std
# Method
# Differential Evolution  11627.595202  0.230563  0.230563  0.230563  0.0
#
# Number of times each method found the best solution:
# Method
# Differential Evolution    1
# Name: count, dtype: int64
#
# Success rate of each method (%):
# Method
# Differential Evolution    200.0
# Name: LCOE, dtype: float64
