# %%
from hopp.utilities.keys import set_nrel_key_dot_env
from hopp.simulation import HoppInterface
from hopp.tools.dispatch.plot_tools import (
    plot_battery_output, plot_battery_dispatch_error, plot_generation_profile, plot_battery_generation
)
from hopp.utilities import load_yaml
import os
from hopp.utilities.keys import set_developer_nrel_gov_key
from hopp.simulation.technologies.grid import Grid
from hopp.simulation.technologies.grid import GridConfig
import numpy as np



# set api for solar and wind resources
set_developer_nrel_gov_key('3F5fBErsd9gKIPEdQpkWHNIhNj7gZG3j0y3lkzew')
# Out:
# C:\Users\Public\miniconda\envs\microgrid\Lib\site-packages\hopp\examples\log\hybrid_systems_2024-05-15T14.59.40.562117.log

# %%
## download solar data using nerl solar api: https://developer.nrel.gov/docs/solar/nsrdb/himawari7-download/
## it covers Australia

import requests
import os

def download_solar_data(latitude, longitude, year, api_key, email):
    # Define the base URL for the Himawari-7 data endpoint
    base_url = "https://developer.nrel.gov/api/nsrdb/v2/solar/himawari7-download.csv"
    
    # Create the query parameters for the request
    params = {
        "wkt": f"POINT({longitude} {latitude})",
        "names": year,  # Ensure this is between 2011 and 2015
        "leap_day": "false",
        "interval": "60",  # Valid intervals are 30 or 60
        "utc": "false",
        "full_name": "Hanrong Huang",  # Your full name
        "email": email,  # Your email address
        "affiliation": "UNSW",
        "mailing_list": "true",
        "reason": "research",
        "api_key": api_key,
        "attributes": "dni,dhi,ghi,dew_point,air_temperature,surface_pressure,wind_direction,wind_speed,surface_albedo"
    }

    # Send the GET request
    response = requests.get(base_url, params=params)

    # Define the directory to save the file
    save_dir = r'C:\Users\Public\miniconda\envs\microgrid\Lib\site-packages\hopp\simulation\resource_files\solar'
    # Ensure the directory exists
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    # Define the filename based on the latitude, longitude, interval, and year
    file_name = f"{latitude}_{longitude}_psmv3_60_{year}.csv"
    full_path = os.path.join(save_dir, file_name)

    # Check if the request was successful
    if response.status_code == 200:
        # Save the content to a file
        with open(full_path, 'wb') as file:
            file.write(response.content)
        print(f"Data downloaded successfully and saved as '{full_path}'.")
    else:
        # Print the error if something went wrong
        print("Failed to download data:", response.text)

# Example usage
api_key = "3F5fBErsd9gKIPEdQpkWHNIhNj7gZG3j0y3lkzew"
email = "z5142067@ad.unsw.edu.au"  # Your actual email
latitude = -31.1629
longitude = 145.6538
download_solar_data(latitude, longitude, year="2012", api_key=api_key, email=email)


## download wind data using NASA weather data api: https://power.larc.nasa.gov/api/pages/?urls.primaryName=Hourly
## it covers Australia

import requests

# Define the API request URL and parameters
url = "https://power.larc.nasa.gov/api/temporal/hourly/point"
params = {
    "start": "20180101",
    "end": "20181231",
    "latitude": "-31.1629",
    "longitude": "145.6538",
    "community": "ag",
    "parameters": "WS50M,WD50M",
    "format": "srw",
    "user": "Hanrong",
    "header": "true",
    "time-standard": "lst"
}

# Send the request to the NASA POWER API
response = requests.get(url, params=params)

# Check if the response was successful
if response.status_code == 200:
    # Format the filename using specified latitude, longitude and other details
    filename = f"{params['latitude']}_{params['longitude']}_NASA_{params['start'][:4]}_60min_50m.srw"
    file_path = f"C:/Users/Public/miniconda/envs/microgrid/Lib/site-packages/hopp/simulation/resource_files/wind/{filename}"

    # Write the content to an SRW file
    with open(file_path, 'wb') as file:
        file.write(response.content)
    
    print(f"Data downloaded successfully and saved to {file_path}.")
else:
    print(f"Failed to download data: {response.status_code}")
    print(response.text)

# %%
# download solar and wind data based on input lat and lon, then rewrite the yaml file with updated data
# download solar data using nerl solar api: https://developer.nrel.gov/docs/solar/nsrdb/himawari7-download/; 
# download wind data using NASA weather data api: https://power.larc.nasa.gov/api/pages/?urls.primaryName=Hourly
import requests
import os
import yaml

def download_data_and_update_config(latitude, longitude, solar_year, wind_start, wind_end, api_key, email, yaml_file_path):
    # Define directories for saving files
    solar_dir = r'C:\Users\Public\miniconda\envs\microgrid\Lib\site-packages\hopp\simulation\resource_files\solar'
    wind_dir = r'C:\Users\Public\miniconda\envs\microgrid\Lib\site-packages\hopp\simulation\resource_files\wind'
    os.makedirs(solar_dir, exist_ok=True)
    os.makedirs(wind_dir, exist_ok=True)

    # Download Solar Data
    solar_base_url = "https://developer.nrel.gov/api/nsrdb/v2/solar/himawari7-download.csv"
    solar_params = {
        "wkt": f"POINT({longitude} {latitude})",
        "names": solar_year,
        "leap_day": "false",
        "interval": "60",
        "utc": "false",
        "full_name": "Hanrong Huang",
        "email": email,
        "affiliation": "UNSW",
        "mailing_list": "true",
        "reason": "research",
        "api_key": api_key,
        "attributes": "dni,dhi,ghi,dew_point,air_temperature,surface_pressure,wind_direction,wind_speed,surface_albedo"
    }
    solar_response = requests.get(solar_base_url, params=solar_params)
    solar_filename = f"{latitude}_{longitude}_psmv3_60_{solar_year}.csv"
    solar_path = os.path.join(solar_dir, solar_filename)

    if solar_response.status_code == 200:
        with open(solar_path, 'wb') as file:
            file.write(solar_response.content)
        print(f"Solar data downloaded and saved to {solar_path}.")
    else:
        print(f"Failed to download solar data: {solar_response.status_code}")
        print(solar_response.text)

    # Download Wind Data
    wind_url = "https://power.larc.nasa.gov/api/temporal/hourly/point"
    wind_params = {
        "start": wind_start,
        "end": wind_end,
        "latitude": latitude,
        "longitude": longitude,
        "community": "ag",
        "parameters": "WS50M,WD50M",
        "format": "srw",
        "user": "Hanrong",
        "header": "true",
        "time-standard": "lst"
    }
    wind_response = requests.get(wind_url, params=wind_params)
    wind_filename = f"{latitude}_{longitude}_NASA_{wind_start[:4]}_60min_50m.srw"
    wind_path = os.path.join(wind_dir, wind_filename)

    if wind_response.status_code == 200:
        with open(wind_path, 'wb') as file:
            file.write(wind_response.content)
        print(f"Wind data downloaded successfully and saved to {wind_path}.")
    else:
        print(f"Failed to download wind data: {wind_response.status_code}")
        print(wind_response.text)

    # Update YAML configuration file
    if os.path.exists(yaml_file_path):
        with open(yaml_file_path, 'r') as file:
            config = yaml.safe_load(file)

        # Updating site information
        config['site']['data']['latitude'] = latitude
        config['site']['data']['longitude'] = longitude
        config['site']['solar_resource_file'] = solar_path.replace('\\', '/')
        config['site']['wind_resource_file'] = wind_path.replace('\\', '/')

        with open(yaml_file_path, 'w') as file:
            yaml.safe_dump(config, file, default_flow_style=False, sort_keys=False)
        print(f"YAML configuration updated successfully at {yaml_file_path}.")

# users and location info
api_key = "3F5fBErsd9gKIPEdQpkWHNIhNj7gZG3j0y3lkzew"
email = "z5142067@ad.unsw.edu.au"
latitude = -33.5265
longitude = 149.1588
yaml_file_path = "./inputs/test file 2-api alternative.yaml"
download_data_and_update_config(latitude, longitude, "2015", "20180101", "20181231", api_key, email, yaml_file_path)
# Out:
# Solar data downloaded and saved to C:\Users\Public\miniconda\envs\microgrid\Lib\site-packages\hopp\simulation\resource_files\solar\-33.5265_149.1588_psmv3_60_2015.csv.
# Wind data downloaded successfully and saved to C:\Users\Public\miniconda\envs\microgrid\Lib\site-packages\hopp\simulation\resource_files\wind\-33.5265_149.1588_NASA_2018_60min_50m.srw.
# YAML configuration updated successfully at ./inputs/test file 2-api alternative.yaml.

# %%
import yaml
import numpy as np
from hopp.simulation import HoppInterface


def present_value(future_value, discount_rate, project_lifetime):
    """
    Calculate the present value of a future amount using the discount rate.
    """
    return future_value / ((1 + discount_rate) ** project_lifetime)

def calculate_lcoe(total_cost, total_generation, discount_rate, project_lifetime):
    """
    Calculate the Levelized Cost of Electricity (LCOE).
    """
    present_value_costs = present_value(total_cost, discount_rate, project_lifetime)
    present_value_generation = present_value(total_generation, discount_rate, project_lifetime)
    return present_value_costs / present_value_generation

# Initialization for the simulation setup
yaml_file_path = "./inputs/test file 2-api alternative.yaml"

# Parameters initialization from the hybrid plant model
project_lifetime = 25  # years
discount_rate = 0.08  # 8%

# Initialize lists to store results
sufficient_results = []
insufficient_results = []

# Define ranges for PV sizes, number of turbines, and battery capacities
pv_size_range = range(20000, 31500, 5000)  # From 20,000 kW to 30,000 kW, in 5,000 kW increments
num_turbines_range = range(5, 21, 5)  # From 5 to 20, in steps of 5, represent 5,000 kw to 20,000 kw
battery_capacity_range = range(40000, 61000, 5000)  # From 40000 kWh to 60000 kWh, in 5000 kWh increments


for pv_size in pv_size_range:
    for num_turbines in num_turbines_range:
        for battery_capacity_kwh in battery_capacity_range:
            # Load the current configuration
            with open(yaml_file_path, 'r') as file:
                config = yaml.safe_load(file)

            # Update the configuration for PV, wind, and battery
            config['technologies']['pv']['system_capacity_kw'] = pv_size
            config['technologies']['wind']['num_turbines'] = num_turbines
            config['technologies']['battery']['system_capacity_kwh'] = battery_capacity_kwh

            # Write the modified configuration back to the file
            with open(yaml_file_path, 'w') as file:
                yaml.safe_dump(config, file)

            # Create a new HoppInterface instance and run the simulation
            hopp = HoppInterface(yaml_file_path)
            hopp.simulate(project_life=25)
            
            # Assign hopp.system to hybrid_plant for easy reference
            hybrid_plant = hopp.system

            # collect wind capacity in kW
            wind_capacity_kw = hybrid_plant.system_capacity_kw.wind
            
            # Genset Specific Calculations
            genset_capacity_kw = hybrid_plant.grid.interconnect_kw
            genset_install_cost_per_kw = 500
            replacement_cost_genset_per_kw = 500
            om_cost_per_kw_per_op_hour = 0.03 # o&m cost in $/kw/op.hour
            fuel_cost_per_l = 1.16
            specific_fuel_consumption_l_per_kwh = 0.261
            genset_operational_hours_per_year = np.sum(np.array(hybrid_plant.grid.generation_profile) > 0)/25 # Calculate the number of hours where generation is not zero per year
            generator_operational_life_hours = 15000 # genset operational lifetime in hours
            generator_operational_life_years = generator_operational_life_hours/genset_operational_hours_per_year # calculate genset operational life in years
            num_genset_replacements = np.ceil(project_lifetime / generator_operational_life_years) - 1
            
            # Genset Costs
            genset_installed_cost = genset_capacity_kw * genset_install_cost_per_kw
            replacement_cost_genset = num_genset_replacements * genset_capacity_kw * replacement_cost_genset_per_kw
            total_om_cost_genset = om_cost_per_kw_per_op_hour * genset_capacity_kw * genset_operational_hours_per_year * project_lifetime
            annual_fuel_consumption = genset_total_generation / project_lifetime * specific_fuel_consumption_l_per_kwh
            total_fuel_cost = annual_fuel_consumption * fuel_cost_per_l * project_lifetime
            total_genset_cost = genset_installed_cost + replacement_cost_genset + total_om_cost_genset + total_fuel_cost

            # Battery Costs
            battery_capacity_kwh = config['technologies']['battery']['system_capacity_kwh']
            battery_installed_cost = hybrid_plant.battery.total_installed_cost
            om_cost_battery_per_kwh = 10  # Annual O&M cost in $/kWh
            operational_life_battery = 15  # Battery operational life in years
            num_battery_replacements = np.ceil(project_lifetime/ operational_life_battery) - 1 
            replacement_cost_battery_per_kWh = 700  # Replacement cost per kWh
            replacement_cost_battery = num_battery_replacements * battery_capacity_kwh * replacement_cost_battery_per_kWh
            total_om_cost_battery = om_cost_battery_per_kwh * battery_capacity_kwh * project_lifetime
            total_battery_cost = battery_installed_cost + replacement_cost_battery + total_om_cost_battery
            
            # PV Costs
            pv_installed_cost = hybrid_plant.pv.total_installed_cost
            om_cost_pv_per_kw = 10  # Annual O&M cost $/kW
            total_om_cost_pv = om_cost_pv_per_kw * hybrid_plant.system_capacity_kw['pv'] * project_lifetime
            total_pv_cost = pv_installed_cost + total_om_cost_pv
            
            # Wind Costs
            wind_installed_cost = hybrid_plant.wind.total_installed_cost
            om_cost_wind_per_kw = 10  # Annual O&M cost $/kW
            total_om_cost_wind = om_cost_wind_per_kw * hybrid_plant.system_capacity_kw['wind'] * project_lifetime
            total_wind_cost = wind_installed_cost + total_om_cost_wind
            
            # Total System Costs over project lifetime
            total_system_cost = total_pv_cost + total_wind_cost + total_battery_cost + total_genset_cost
            
            # Total system generation over project lifetime
            pv_total_generation = np.sum(hybrid_plant.generation_profile.pv)
            wind_total_generation = np.sum(hybrid_plant.generation_profile.wind)
            battery_total_generation = np.sum(hybrid_plant.generation_profile.battery)
            genset_total_generation = np.sum(hybrid_plant.generation_profile.grid)  # Genset modeled as grid
            total_system_generation_over_lifetime = pv_total_generation + wind_total_generation + battery_total_generation + genset_total_generation
            
            # LCOE Calculation
            LCOE = calculate_lcoe(total_system_cost, total_system_generation_over_lifetime, discount_rate, project_lifetime)

            # Collect NPV for the current configuration
            npv = hybrid_plant.net_present_values.hybrid
            hybrid_installed_cost = hybrid_plant.grid.total_installed_cost
            
            # Calculate the annual system generation: total_system_generation_over_lifetime/project lifetime
            annual_system_generation = total_system_generation_over_lifetime/project_lifetime
            # Calculate the total annual load from the load profile
            total_annual_load = np.sum(hybrid_plant.site.desired_schedule * 1000)  # Convert MW to kW, then sum for kWh
            # Check if generation meets or exceeds the load
            if annual_system_generation >= total_annual_load:
                sufficient_results.append((pv_size, wind_capacity_kw, battery_capacity_kwh, genset_capacity_kw, annual_system_generation, npv, LCOE))
            else:
                insufficient_results.append((pv_size, wind_capacity_kw, battery_capacity_kwh, genset_capacity_kw, annual_system_generation, total_annual_load, LCOE))
                print(f"System capacity is insufficient at PV size {pv_size} kW, Wind size {wind_capacity_kw} kW, Battery size {battery_capacity_kwh} kWh, and Genset size {genset_capacity_kw} kW")
                print(f"Total Annual Generation: {annual_system_generation:.3f} kWh, Total Annual Load: {total_annual_load:.3f} kWh")
                print(f"System LCOE: {LCOE:.3f} $/kWh")
                print("--------------------------------------------------------------------------------")

# Output the collected results
print("Below are the systems with sufficient capacity:")
for result in sufficient_results:
    print(f"PV Capacity: {result[0]} kW, Wind Turbine Capacity: {result[1]} kW, Battery Capacity: {result[2]} kWh, Genset Capacity: {result[3]} kW), Annual System Generation: {result[4]:.3f} kWh, System NPV: {result[5]:.3f}, System LCOE: {result[6]:.3f}")
    print("--------------------------------------------------------------------------------")

# Find the configuration with the lowest hybrid installed cost
lowest_cost_config = min(sufficient_results, key=lambda x: x[6])

print("Configuration with the lowest system LCOE:")
print(f"PV Capacity: {lowest_cost_config[0]} kW")
print(f"Wind Turbine Capacity: {lowest_cost_config[1]} kW")
print(f"Battery Capacity: {lowest_cost_config[2]} kWh")
print(f"Genset Capacity: {lowest_cost_config[3]} kWh")
print(f"Total Annual Generation: {lowest_cost_config[4]:.3f} kWh")
print(f"NPV: {lowest_cost_config[5]:.3f}")
print(f"System LCOE: {lowest_cost_config[6]:.3f} $/kWh")
# Out:
# System capacity is insufficient at PV size 20000 kW, Wind size 5000.0 kW, Battery size 40000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 67835176.83434673 kWh, Total Annual Load: 78631950.11250001 kWh
# System LCOE: 0.326 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 5000.0 kW, Battery size 45000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 67837365.04666935 kWh, Total Annual Load: 78631950.11250001 kWh
# System LCOE: 0.330 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 5000.0 kW, Battery size 50000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 67840730.77212864 kWh, Total Annual Load: 78631950.11250001 kWh
# System LCOE: 0.334 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 5000.0 kW, Battery size 55000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 67842427.91370073 kWh, Total Annual Load: 78631950.11250001 kWh
# System LCOE: 0.337 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 5000.0 kW, Battery size 60000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 67842700.16042152 kWh, Total Annual Load: 78631950.11250001 kWh
# System LCOE: 0.341 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 10000.0 kW, Battery size 40000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 71080727.22642142 kWh, Total Annual Load: 78631950.11250001 kWh
# System LCOE: 0.316 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 10000.0 kW, Battery size 45000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 71082917.83578295 kWh, Total Annual Load: 78631950.11250001 kWh
# System LCOE: 0.326 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 10000.0 kW, Battery size 50000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 71086279.17703508 kWh, Total Annual Load: 78631950.11250001 kWh
# System LCOE: 0.329 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 10000.0 kW, Battery size 55000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 71087976.33998537 kWh, Total Annual Load: 78631950.11250001 kWh
# System LCOE: 0.333 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 10000.0 kW, Battery size 60000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 71088251.60937284 kWh, Total Annual Load: 78631950.11250001 kWh
# System LCOE: 0.336 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 15000.0 kW, Battery size 40000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 74032461.64540523 kWh, Total Annual Load: 78631950.11250001 kWh
# System LCOE: 0.314 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 15000.0 kW, Battery size 45000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 74034646.57490212 kWh, Total Annual Load: 78631950.11250001 kWh
# System LCOE: 0.322 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 15000.0 kW, Battery size 50000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 74038014.35557126 kWh, Total Annual Load: 78631950.11250001 kWh
# System LCOE: 0.326 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 15000.0 kW, Battery size 55000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 74039705.23091541 kWh, Total Annual Load: 78631950.11250001 kWh
# System LCOE: 0.329 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 15000.0 kW, Battery size 60000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 74039971.12902997 kWh, Total Annual Load: 78631950.11250001 kWh
# System LCOE: 0.333 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 20000.0 kW, Battery size 40000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 76769499.96322912 kWh, Total Annual Load: 78631950.11250001 kWh
# System LCOE: 0.312 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 20000.0 kW, Battery size 45000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 76771677.86941394 kWh, Total Annual Load: 78631950.11250001 kWh
# System LCOE: 0.320 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 20000.0 kW, Battery size 50000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 76775042.89256977 kWh, Total Annual Load: 78631950.11250001 kWh
# System LCOE: 0.323 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 20000.0 kW, Battery size 55000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 76776738.20787573 kWh, Total Annual Load: 78631950.11250001 kWh
# System LCOE: 0.327 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 20000.0 kW, Battery size 60000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 76777007.9848102 kWh, Total Annual Load: 78631950.11250001 kWh
# System LCOE: 0.330 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 25000 kW, Wind size 5000.0 kW, Battery size 40000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 78574282.84636672 kWh, Total Annual Load: 78631950.11250001 kWh
# System LCOE: 0.300 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 25000 kW, Wind size 5000.0 kW, Battery size 45000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 78576419.95338714 kWh, Total Annual Load: 78631950.11250001 kWh
# System LCOE: 0.295 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 25000 kW, Wind size 5000.0 kW, Battery size 50000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 78578725.37300803 kWh, Total Annual Load: 78631950.11250001 kWh
# System LCOE: 0.298 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 25000 kW, Wind size 5000.0 kW, Battery size 55000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 78579015.42972706 kWh, Total Annual Load: 78631950.11250001 kWh
# System LCOE: 0.301 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 25000 kW, Wind size 5000.0 kW, Battery size 60000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 78580647.59974301 kWh, Total Annual Load: 78631950.11250001 kWh
# System LCOE: 0.305 $/kWh
# --------------------------------------------------------------------------------
# Below are the systems with sufficient capacity:
# PV Capacity: 25000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 40000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 81768361.32294144 kWh, System NPV: 202366581.69645533, System LCOE: 0.28444334233206436
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 45000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 81770502.12389004 kWh, System NPV: 201405813.2237058, System LCOE: 0.29258334395200636
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 50000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 81772810.61253756 kWh, System NPV: 200444462.73994818, System LCOE: 0.29572531617053105
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 55000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 81773103.82106939 kWh, System NPV: 199469142.46662804, System LCOE: 0.29887510379083665
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 60000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 81774739.61607087 kWh, System NPV: 198502900.18287125, System LCOE: 0.30201942511148744
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 40000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 84684615.03520261 kWh, System NPV: 204097692.83035177, System LCOE: 0.2835927361500752
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 45000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 84686752.02523775 kWh, System NPV: 203136851.416226, System LCOE: 0.29092570759889697
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 50000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 84689061.94325492 kWh, System NPV: 202175350.68434778, System LCOE: 0.2939662434297151
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 55000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 84689361.29490308 kWh, System NPV: 201199959.2960399, System LCOE: 0.29700082790367827
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 60000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 84691006.74018076 kWh, System NPV: 200233746.10271293, System LCOE: 0.30003690113633774
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 40000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 87391083.02661064 kWh, System NPV: 204790060.5443598, System LCOE: 0.2829606986145228
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 45000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 87393223.43840136 kWh, System NPV: 203829188.21482772, System LCOE: 0.2895831861384894
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 50000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 87395530.59565201 kWh, System NPV: 202867476.4857217, System LCOE: 0.29253614120764765
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 55000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 87395815.92220089 kWh, System NPV: 201892002.9879104, System LCOE: 0.29547679347058425
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 60000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 87397443.9349227 kWh, System NPV: 200925649.5149905, System LCOE: 0.2984123655484579
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 5000.0 kW, Battery Capacity: 40000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 88756782.5215982 kWh, System NPV: 204350358.1239735, System LCOE: 0.2736714511873505
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 5000.0 kW, Battery Capacity: 45000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 88758406.44558877 kWh, System NPV: 203384253.9977693, System LCOE: 0.2678215039852763
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 5000.0 kW, Battery Capacity: 50000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 88758718.95239817 kWh, System NPV: 202408919.77278554, System LCOE: 0.2707210849315792
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 5000.0 kW, Battery Capacity: 55000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 88760049.9023204 kWh, System NPV: 201440874.94265816, System LCOE: 0.27363230481138834
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 5000.0 kW, Battery Capacity: 60000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 88762070.22899173 kWh, System NPV: 200476889.0918836, System LCOE: 0.2765319250153864
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 40000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 91926811.53477083 kWh, System NPV: 206984893.4446185, System LCOE: 0.2596169065345245
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 45000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 91928427.31014463 kWh, System NPV: 206018728.71477056, System LCOE: 0.26677768040839944
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 50000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 91928726.9986536 kWh, System NPV: 205043241.2282578, System LCOE: 0.2695772885859873
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 55000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 91930050.38538966 kWh, System NPV: 204075197.858554, System LCOE: 0.2723819172475134
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 60000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 91932076.37441261 kWh, System NPV: 203111258.50537843, System LCOE: 0.27517533901507585
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 40000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 94823013.11515714 kWh, System NPV: 208333723.48428863, System LCOE: 0.25955671953286574
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 45000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 94824641.1136834 kWh, System NPV: 207367615.53992742, System LCOE: 0.266041185298142
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 50000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 94824928.5242181 kWh, System NPV: 206392063.9706111, System LCOE: 0.2687553620080166
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 55000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 94826260.34583181 kWh, System NPV: 205424042.81536376, System LCOE: 0.27147427926187684
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 60000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 94828293.36005162 kWh, System NPV: 204460190.96088552, System LCOE: 0.27418842165149054
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 40000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 97507065.14305753 kWh, System NPV: 208877896.09514642, System LCOE: 0.2596373102551786
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 45000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 97508684.43861763 kWh, System NPV: 207911743.95675898, System LCOE: 0.26550270901483225
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 50000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 97508991.09987736 kWh, System NPV: 206936302.97053987, System LCOE: 0.2681479409327948
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 55000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 97510313.72187571 kWh, System NPV: 205968197.8384922, System LCOE: 0.2707862648197548
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 60000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 97512341.94824675 kWh, System NPV: 205004292.73838347, System LCOE: 0.273431543816188
# --------------------------------------------------------------------------------
# Configuration with the lowest system LCOE:
# PV Capacity: 30000 kW
# Wind Turbine Capacity: 15000.0 kW
# Battery Capacity: 40000 kWh
# Genset Capacity: 19000.0 kWh
# Total Annual Generation: 94823013.11515714 kWh
# NPV: 208333723.48428863
# System LCOE: 0.260 $/kWh

# %%
# merge two blocks above into one
# Read the lat and lon data of an ore deposit from auCopper.csv, then download the corresponding solar and wind data, rewrite the yaml file with the updated data.
# Simulate and optimise the hybrid system capacity at current deposit location, find the system config with the lowest LCOE
# Move on to the next ore deposit location until hybrid system simulations at all deposits are finished

import requests
import os
import yaml
import pandas as pd
from hopp.simulation import HoppInterface

def present_value(future_value, discount_rate, project_lifetime):
    """
    Calculate the present value of a future amount using the discount rate.
    """
    return future_value / ((1 + discount_rate) ** project_lifetime)

def calculate_lcoe(total_cost, total_generation, discount_rate, project_lifetime):
    """
    Calculate the Levelized Cost of Electricity (LCOE).
    """
    present_value_costs = present_value(total_cost, discount_rate, project_lifetime)
    present_value_generation = present_value(total_generation, discount_rate, project_lifetime)
    return present_value_costs / present_value_generation

def download_data_and_update_config(latitude, longitude, solar_year, wind_start, wind_end, api_key, email, yaml_file_path):
    # Define directories for saving files
    solar_dir = r'C:\Users\Public\miniconda\envs\microgrid\Lib\site-packages\hopp\simulation\resource_files\solar'
    wind_dir = r'C:\Users\Public\miniconda\envs\microgrid\Lib\site-packages\hopp\simulation\resource_files\wind'
    os.makedirs(solar_dir, exist_ok=True)
    os.makedirs(wind_dir, exist_ok=True)

    # Download Solar Data
    solar_base_url = "https://developer.nrel.gov/api/nsrdb/v2/solar/himawari7-download.csv"
    solar_params = {
        "wkt": f"POINT({longitude} {latitude})",
        "names": solar_year,
        "leap_day": "false",
        "interval": "60",
        "utc": "false",
        "full_name": "Hanrong Huang",
        "email": email,
        "affiliation": "UNSW",
        "mailing_list": "true",
        "reason": "research",
        "api_key": api_key,
        "attributes": "dni,dhi,ghi,dew_point,air_temperature,surface_pressure,wind_direction,wind_speed,surface_albedo"
    }
    solar_response = requests.get(solar_base_url, params=solar_params)
    solar_filename = f"{latitude}_{longitude}_psmv3_60_{solar_year}.csv"
    solar_path = os.path.join(solar_dir, solar_filename)

    if solar_response.status_code == 200:
        with open(solar_path, 'wb') as file:
            file.write(solar_response.content)
        print(f"Solar data downloaded and saved to {solar_path}.")
    else:
        print(f"Failed to download solar data: {solar_response.status_code}")
        print(solar_response.text)

    # Download Wind Data
    wind_url = "https://power.larc.nasa.gov/api/temporal/hourly/point"
    wind_params = {

        "start": wind_start,
        "end": wind_end,
        "latitude": latitude,
        "longitude": longitude,
        "community": "ag",
        "parameters": "WS50M,WD50M",
        "format": "srw",
        "user": "Hanrong",
        "header": "true",
        "time-standard": "lst"
    }
    wind_response = requests.get(wind_url, params=wind_params)
    wind_filename = f"{latitude}_{longitude}_NASA_{wind_start[:4]}_60min_50m.srw"
    wind_path = os.path.join(wind_dir, wind_filename)

    if wind_response.status_code == 200:
        with open(wind_path, 'wb') as file:
            file.write(wind_response.content)
        print(f"Wind data downloaded successfully and saved to {wind_path}.")
    else:
        print(f"Failed to download wind data: {wind_response.status_code}")
        print(wind_response.text)

    # Update YAML configuration file
    if os.path.exists(yaml_file_path):
        with open(yaml_file_path, 'r') as file:
            config = yaml.safe_load(file)

        # Updating site information
        config['site']['data']['lat'] = latitude
        config['site']['data']['lon'] = longitude
        config['site']['solar_resource_file'] = solar_path.replace('\\', '/')
        config['site']['wind_resource_file'] = wind_path.replace('\\', '/')

        with open(yaml_file_path, 'w') as file:
            yaml.safe_dump(config, file, default_flow_style=False, sort_keys=False)
        print(f"YAML configuration updated successfully at {yaml_file_path}.")
        print("-------------------------------------------------------------------------------------")
# Path to CSV
csv_path = "./Deposit data/auCopper - Copy.csv"
location_data = pd.read_csv(csv_path)

# API and user info
api_key = "3F5fBErsd9gKIPEdQpkWHNIhNj7gZG3j0y3lkzew"
email = "z5142067@ad.unsw.edu.au"
yaml_file_path = "./inputs/test file 2-api alternative.yaml"

for index, row in location_data.iterrows():
    latitude = row['DEPOSIT_LATITUDE']
    longitude = row['DEPOSIT_LONGITUDE']
    print("-------------------------------------------------------------------------------------------------------------------")
    print(f"Hybrid microgrid simulation and optimisation at ore deposit (Lat: {latitude}, Lon: {longitude}) starts from below:")
    print("-------------------------------------------------------------------------------------------------------------------")
    download_data_and_update_config(latitude, longitude, "2015", "20180101", "20181231", api_key, email, yaml_file_path)

    # Insert simulation and results processing code here 
    # Initialization for the simulation setup
    yaml_file_path = "./inputs/test file 2-api alternative.yaml"
    
    # Parameters initialization from the hybrid plant model
    project_lifetime = 25  # years
    discount_rate = 0.08  # 8%
    
    # Initialize lists to store results
    sufficient_results = []
    insufficient_results = []
    
    # Define ranges for PV sizes, number of turbines, and battery capacities
    pv_size_range = range(20000, 31500, 5000)  # From 20,000 kW to 30,000 kW, in 5,000 kW increments
    num_turbines_range = range(5, 21, 5)  # From 5 to 20, in steps of 5, represent 5,000 kw to 20,000 kw
    battery_capacity_range = range(40000, 61000, 5000)  # From 40000 kWh to 60000 kWh, in 5000 kWh increments
    
    
    for pv_size in pv_size_range:
        for num_turbines in num_turbines_range:
            for battery_capacity_kwh in battery_capacity_range:
                # Load the current configuration
                with open(yaml_file_path, 'r') as file:
                    config = yaml.safe_load(file)
    
                # Update the configuration for PV, wind, and battery
                config['technologies']['pv']['system_capacity_kw'] = pv_size
                config['technologies']['wind']['num_turbines'] = num_turbines
                config['technologies']['battery']['system_capacity_kwh'] = battery_capacity_kwh
    
                # Write the modified configuration back to the file
                with open(yaml_file_path, 'w') as file:
                    yaml.safe_dump(config, file)
    
                # Create a new HoppInterface instance and run the simulation
                hopp = HoppInterface(yaml_file_path)
                hopp.simulate(project_life=25)
                
                # Assign hopp.system to hybrid_plant for easy reference
                hybrid_plant = hopp.system
    
                # collect wind capacity in kW
                wind_capacity_kw = hybrid_plant.system_capacity_kw.wind
                
                # Genset Specific Calculations
                genset_capacity_kw = hybrid_plant.grid.interconnect_kw
                genset_install_cost_per_kw = 500
                replacement_cost_genset_per_kw = 500
                om_cost_per_kw_per_op_hour = 0.03 # o&m cost in $/kw/op.hour
                fuel_cost_per_l = 1.16
                specific_fuel_consumption_l_per_kwh = 0.261
                genset_operational_hours_per_year = np.sum(np.array(hybrid_plant.grid.generation_profile) > 0)/25 # Calculate the number of hours where generation is not zero per year
                generator_operational_life_hours = 15000 # genset operational lifetime in hours
                generator_operational_life_years = generator_operational_life_hours/genset_operational_hours_per_year # calculate genset operational life in years
                num_genset_replacements = np.ceil(project_lifetime / generator_operational_life_years) - 1
                
                # Genset Costs
                genset_installed_cost = genset_capacity_kw * genset_install_cost_per_kw
                replacement_cost_genset = num_genset_replacements * genset_capacity_kw * replacement_cost_genset_per_kw
                total_om_cost_genset = om_cost_per_kw_per_op_hour * genset_capacity_kw * genset_operational_hours_per_year * project_lifetime
                annual_fuel_consumption = genset_total_generation / project_lifetime * specific_fuel_consumption_l_per_kwh
                total_fuel_cost = annual_fuel_consumption * fuel_cost_per_l * project_lifetime
                total_genset_cost = genset_installed_cost + replacement_cost_genset + total_om_cost_genset + total_fuel_cost
    
                # Battery Costs
                battery_capacity_kwh = config['technologies']['battery']['system_capacity_kwh']
                battery_installed_cost = hybrid_plant.battery.total_installed_cost
                om_cost_battery_per_kwh = 10  # Annual O&M cost in $/kWh
                operational_life_battery = 15  # Battery operational life in years
                num_battery_replacements = np.ceil(project_lifetime/ operational_life_battery) - 1 
                replacement_cost_battery_per_kWh = 700  # Replacement cost per kWh
                replacement_cost_battery = num_battery_replacements * battery_capacity_kwh * replacement_cost_battery_per_kWh
                total_om_cost_battery = om_cost_battery_per_kwh * battery_capacity_kwh * project_lifetime
                total_battery_cost = battery_installed_cost + replacement_cost_battery + total_om_cost_battery
                
                # PV Costs
                pv_installed_cost = hybrid_plant.pv.total_installed_cost
                om_cost_pv_per_kw = 10  # Annual O&M cost $/kW
                total_om_cost_pv = om_cost_pv_per_kw * hybrid_plant.system_capacity_kw['pv'] * project_lifetime
                total_pv_cost = pv_installed_cost + total_om_cost_pv
                
                # Wind Costs
                wind_installed_cost = hybrid_plant.wind.total_installed_cost
                om_cost_wind_per_kw = 10  # Annual O&M cost $/kW
                total_om_cost_wind = om_cost_wind_per_kw * hybrid_plant.system_capacity_kw['wind'] * project_lifetime
                total_wind_cost = wind_installed_cost + total_om_cost_wind
                
                # Total System Costs over project lifetime
                total_system_cost = total_pv_cost + total_wind_cost + total_battery_cost + total_genset_cost
                
                # Total system generation over project lifetime
                pv_total_generation = np.sum(hybrid_plant.generation_profile.pv)
                wind_total_generation = np.sum(hybrid_plant.generation_profile.wind)
                battery_total_generation = np.sum(hybrid_plant.generation_profile.battery)
                genset_total_generation = np.sum(hybrid_plant.generation_profile.grid)  # Genset modeled as grid
                total_system_generation_over_lifetime = pv_total_generation + wind_total_generation + battery_total_generation + genset_total_generation
                
                # LCOE Calculation
                LCOE = calculate_lcoe(total_system_cost, total_system_generation_over_lifetime, discount_rate, project_lifetime)
    
                # Collect NPV for the current configuration
                npv = hybrid_plant.net_present_values.hybrid
                hybrid_installed_cost = hybrid_plant.grid.total_installed_cost
                
                # Calculate the annual system generation: total_system_generation_over_lifetime/project lifetime
                annual_system_generation = total_system_generation_over_lifetime/project_lifetime
                # Calculate the total annual load from the load profile
                total_annual_load = np.sum(hybrid_plant.site.desired_schedule * 1000)  # Convert MW to kW, then sum for kWh
                # Check if generation meets or exceeds the load
                if annual_system_generation >= total_annual_load:
                    sufficient_results.append((pv_size, wind_capacity_kw, battery_capacity_kwh, genset_capacity_kw, annual_system_generation, npv, LCOE))
                else:
                    insufficient_results.append((pv_size, wind_capacity_kw, battery_capacity_kwh, genset_capacity_kw, annual_system_generation, total_annual_load, LCOE))
                    print(f"System capacity is insufficient at PV size {pv_size} kW, Wind size {wind_capacity_kw} kW, Battery size {battery_capacity_kwh} kWh, and Genset size {genset_capacity_kw} kW")
                    print(f"Total Annual Generation: {annual_system_generation:.3f} kWh, Total Annual Load: {total_annual_load:.3f} kWh")
                    print(f"System LCOE: {LCOE:.3f} $/kWh")
                    print("--------------------------------------------------------------------------------")
    
    # Output the collected results
    print("Below are the systems with sufficient capacity:")
    for result in sufficient_results:
        print(f"PV Capacity: {result[0]} kW, Wind Turbine Capacity: {result[1]} kW, Battery Capacity: {result[2]} kWh, Genset Capacity: {result[3]} kW, Annual System Generation: {result[4]:.3f} kWh, System NPV: {result[5]:.3f}, System LCOE: {result[6]:.3f}")
        print("--------------------------------------------------------------------------------")
    
    # Find the configuration with the lowest hybrid installed cost
    lowest_cost_config = min(sufficient_results, key=lambda x: x[6])
    
    print("Configuration with the lowest system LCOE:")
    print(f"PV Capacity: {lowest_cost_config[0]} kW")
    print(f"Wind Turbine Capacity: {lowest_cost_config[1]} kW")
    print(f"Battery Capacity: {lowest_cost_config[2]} kWh")
    print(f"Genset Capacity: {lowest_cost_config[3]} kWh")
    print(f"Total Annual Generation: {lowest_cost_config[4]:.3f} kWh")
    print(f"NPV: {lowest_cost_config[5]:.3f}")
    print(f"System LCOE: {lowest_cost_config[6]:.3f} $/kWh")
    print("--------------------------------------------------------------------------------")
    
print("------------------------------------------------------------------------------")
print("Simulation completed.")                    
print("------------------------------------------------------------------------------")
# Out:
# Hybrid microgrid simulation and optimisation at ore deposit (Lat: -33.5265, Lon: 149.1588) starts from below:
# Solar data downloaded and saved to C:\Users\Public\miniconda\envs\microgrid\Lib\site-packages\hopp\simulation\resource_files\solar\-33.5265_149.1588_psmv3_60_2015.csv.
# Wind data downloaded successfully and saved to C:\Users\Public\miniconda\envs\microgrid\Lib\site-packages\hopp\simulation\resource_files\wind\-33.5265_149.1588_NASA_2018_60min_50m.srw.
# YAML configuration updated successfully at ./inputs/test file 2-api alternative.yaml.
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 5000.0 kW, Battery size 40000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 67835176.834 kWh, Total Annual Load: 78631950.113 kWh
# System LCOE: 0.326 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 5000.0 kW, Battery size 45000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 67837365.047 kWh, Total Annual Load: 78631950.113 kWh
# System LCOE: 0.330 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 5000.0 kW, Battery size 50000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 67840730.772 kWh, Total Annual Load: 78631950.113 kWh
# System LCOE: 0.334 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 5000.0 kW, Battery size 55000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 67842427.914 kWh, Total Annual Load: 78631950.113 kWh
# System LCOE: 0.337 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 5000.0 kW, Battery size 60000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 67842700.160 kWh, Total Annual Load: 78631950.113 kWh
# System LCOE: 0.341 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 10000.0 kW, Battery size 40000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 71080727.226 kWh, Total Annual Load: 78631950.113 kWh
# System LCOE: 0.316 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 10000.0 kW, Battery size 45000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 71082917.836 kWh, Total Annual Load: 78631950.113 kWh
# System LCOE: 0.326 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 10000.0 kW, Battery size 50000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 71086279.177 kWh, Total Annual Load: 78631950.113 kWh
# System LCOE: 0.329 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 10000.0 kW, Battery size 55000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 71087976.340 kWh, Total Annual Load: 78631950.113 kWh
# System LCOE: 0.333 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 10000.0 kW, Battery size 60000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 71088251.609 kWh, Total Annual Load: 78631950.113 kWh
# System LCOE: 0.336 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 15000.0 kW, Battery size 40000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 74032461.645 kWh, Total Annual Load: 78631950.113 kWh
# System LCOE: 0.314 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 15000.0 kW, Battery size 45000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 74034646.575 kWh, Total Annual Load: 78631950.113 kWh
# System LCOE: 0.322 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 15000.0 kW, Battery size 50000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 74038014.356 kWh, Total Annual Load: 78631950.113 kWh
# System LCOE: 0.326 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 15000.0 kW, Battery size 55000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 74039705.231 kWh, Total Annual Load: 78631950.113 kWh
# System LCOE: 0.329 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 15000.0 kW, Battery size 60000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 74039971.129 kWh, Total Annual Load: 78631950.113 kWh
# System LCOE: 0.333 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 20000.0 kW, Battery size 40000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 76769499.963 kWh, Total Annual Load: 78631950.113 kWh
# System LCOE: 0.312 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 20000.0 kW, Battery size 45000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 76771677.869 kWh, Total Annual Load: 78631950.113 kWh
# System LCOE: 0.320 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 20000.0 kW, Battery size 50000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 76775042.893 kWh, Total Annual Load: 78631950.113 kWh
# System LCOE: 0.323 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 20000.0 kW, Battery size 55000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 76776738.208 kWh, Total Annual Load: 78631950.113 kWh
# System LCOE: 0.327 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 20000 kW, Wind size 20000.0 kW, Battery size 60000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 76777007.985 kWh, Total Annual Load: 78631950.113 kWh
# System LCOE: 0.330 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 25000 kW, Wind size 5000.0 kW, Battery size 40000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 78574282.846 kWh, Total Annual Load: 78631950.113 kWh
# System LCOE: 0.300 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 25000 kW, Wind size 5000.0 kW, Battery size 45000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 78576419.953 kWh, Total Annual Load: 78631950.113 kWh
# System LCOE: 0.295 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 25000 kW, Wind size 5000.0 kW, Battery size 50000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 78578725.373 kWh, Total Annual Load: 78631950.113 kWh
# System LCOE: 0.298 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 25000 kW, Wind size 5000.0 kW, Battery size 55000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 78579015.430 kWh, Total Annual Load: 78631950.113 kWh
# System LCOE: 0.301 $/kWh
# --------------------------------------------------------------------------------
# System capacity is insufficient at PV size 25000 kW, Wind size 5000.0 kW, Battery size 60000 kWh, and Genset size 19000.0 kW
# Total Annual Generation: 78580647.600 kWh, Total Annual Load: 78631950.113 kWh
# System LCOE: 0.305 $/kWh
# --------------------------------------------------------------------------------
# Below are the systems with sufficient capacity:
# PV Capacity: 25000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 40000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 81768361.323 kWh, System NPV: 202366581.696, System LCOE: 0.284
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 45000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 81770502.124 kWh, System NPV: 201405813.224, System LCOE: 0.293
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 50000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 81772810.613 kWh, System NPV: 200444462.740, System LCOE: 0.296
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 55000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 81773103.821 kWh, System NPV: 199469142.467, System LCOE: 0.299
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 60000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 81774739.616 kWh, System NPV: 198502900.183, System LCOE: 0.302
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 40000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 84684615.035 kWh, System NPV: 204097692.830, System LCOE: 0.284
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 45000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 84686752.025 kWh, System NPV: 203136851.416, System LCOE: 0.291
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 50000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 84689061.943 kWh, System NPV: 202175350.684, System LCOE: 0.294
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 55000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 84689361.295 kWh, System NPV: 201199959.296, System LCOE: 0.297
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 60000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 84691006.740 kWh, System NPV: 200233746.103, System LCOE: 0.300
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 40000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 87391083.027 kWh, System NPV: 204790060.544, System LCOE: 0.283
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 45000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 87393223.438 kWh, System NPV: 203829188.215, System LCOE: 0.290
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 50000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 87395530.596 kWh, System NPV: 202867476.486, System LCOE: 0.293
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 55000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 87395815.922 kWh, System NPV: 201892002.988, System LCOE: 0.295
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 60000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 87397443.935 kWh, System NPV: 200925649.515, System LCOE: 0.298
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 5000.0 kW, Battery Capacity: 40000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 88756782.522 kWh, System NPV: 204350358.124, System LCOE: 0.274
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 5000.0 kW, Battery Capacity: 45000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 88758406.446 kWh, System NPV: 203384253.998, System LCOE: 0.268
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 5000.0 kW, Battery Capacity: 50000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 88758718.952 kWh, System NPV: 202408919.773, System LCOE: 0.271
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 5000.0 kW, Battery Capacity: 55000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 88760049.902 kWh, System NPV: 201440874.943, System LCOE: 0.274
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 5000.0 kW, Battery Capacity: 60000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 88762070.229 kWh, System NPV: 200476889.092, System LCOE: 0.277
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 40000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 91926811.535 kWh, System NPV: 206984893.445, System LCOE: 0.260
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 45000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 91928427.310 kWh, System NPV: 206018728.715, System LCOE: 0.267
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 50000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 91928726.999 kWh, System NPV: 205043241.228, System LCOE: 0.270
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 55000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 91930050.385 kWh, System NPV: 204075197.859, System LCOE: 0.272
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 60000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 91932076.374 kWh, System NPV: 203111258.505, System LCOE: 0.275
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 40000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 94823013.115 kWh, System NPV: 208333723.484, System LCOE: 0.260
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 45000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 94824641.114 kWh, System NPV: 207367615.540, System LCOE: 0.266
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 50000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 94824928.524 kWh, System NPV: 206392063.971, System LCOE: 0.269
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 55000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 94826260.346 kWh, System NPV: 205424042.815, System LCOE: 0.271
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 60000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 94828293.360 kWh, System NPV: 204460190.961, System LCOE: 0.274
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 40000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 97507065.143 kWh, System NPV: 208877896.095, System LCOE: 0.260
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 45000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 97508684.439 kWh, System NPV: 207911743.957, System LCOE: 0.266
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 50000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 97508991.100 kWh, System NPV: 206936302.971, System LCOE: 0.268
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 55000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 97510313.722 kWh, System NPV: 205968197.838, System LCOE: 0.271
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 60000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 97512341.948 kWh, System NPV: 205004292.738, System LCOE: 0.273
# --------------------------------------------------------------------------------
# Configuration with the lowest system LCOE:
# PV Capacity: 30000 kW
# Wind Turbine Capacity: 15000.0 kW
# Battery Capacity: 40000 kWh
# Genset Capacity: 19000.0 kWh
# Total Annual Generation: 94823013.115 kWh
# NPV: 208333723.484
# System LCOE: 0.260 $/kWh
# Hybrid microgrid simulation and optimisation at ore deposit (Lat: -31.1629, Lon: 145.6538) starts from below:
# Solar data downloaded and saved to C:\Users\Public\miniconda\envs\microgrid\Lib\site-packages\hopp\simulation\resource_files\solar\-31.1629_145.6538_psmv3_60_2015.csv.
# Wind data downloaded successfully and saved to C:\Users\Public\miniconda\envs\microgrid\Lib\site-packages\hopp\simulation\resource_files\wind\-31.1629_145.6538_NASA_2018_60min_50m.srw.
# YAML configuration updated successfully at ./inputs/test file 2-api alternative.yaml.
# --------------------------------------------------------------------------------
# Below are the systems with sufficient capacity:
# PV Capacity: 20000 kW, Wind Turbine Capacity: 5000.0 kW, Battery Capacity: 40000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 90001204.833 kWh, System NPV: 259449129.172, System LCOE: 0.275
# --------------------------------------------------------------------------------
# PV Capacity: 20000 kW, Wind Turbine Capacity: 5000.0 kW, Battery Capacity: 45000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 90003325.481 kWh, System NPV: 258487468.140, System LCOE: 0.284
# --------------------------------------------------------------------------------
# PV Capacity: 20000 kW, Wind Turbine Capacity: 5000.0 kW, Battery Capacity: 50000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 90005128.716 kWh, System NPV: 257523054.333, System LCOE: 0.287
# --------------------------------------------------------------------------------
# PV Capacity: 20000 kW, Wind Turbine Capacity: 5000.0 kW, Battery Capacity: 55000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 90005811.264 kWh, System NPV: 256550312.029, System LCOE: 0.290
# --------------------------------------------------------------------------------
# PV Capacity: 20000 kW, Wind Turbine Capacity: 5000.0 kW, Battery Capacity: 60000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 90006631.049 kWh, System NPV: 255578833.322, System LCOE: 0.293
# --------------------------------------------------------------------------------
# PV Capacity: 20000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 40000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 107685434.311 kWh, System NPV: 305311372.576, System LCOE: 0.239
# --------------------------------------------------------------------------------
# PV Capacity: 20000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 45000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 107687515.488 kWh, System NPV: 304348583.144, System LCOE: 0.259
# --------------------------------------------------------------------------------
# PV Capacity: 20000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 50000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 107688759.941 kWh, System NPV: 303379743.137, System LCOE: 0.262
# --------------------------------------------------------------------------------
# PV Capacity: 20000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 55000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 107689493.227 kWh, System NPV: 302407135.255, System LCOE: 0.264
# --------------------------------------------------------------------------------
# PV Capacity: 20000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 60000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 107690296.724 kWh, System NPV: 301434894.468, System LCOE: 0.266
# --------------------------------------------------------------------------------
# PV Capacity: 20000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 40000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 123212900.895 kWh, System NPV: 338407186.431, System LCOE: 0.227
# --------------------------------------------------------------------------------
# PV Capacity: 20000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 45000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 123213559.621 kWh, System NPV: 337434167.132, System LCOE: 0.241
# --------------------------------------------------------------------------------
# PV Capacity: 20000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 50000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 123214798.793 kWh, System NPV: 336464644.861, System LCOE: 0.243
# --------------------------------------------------------------------------------
# PV Capacity: 20000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 55000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 123215811.199 kWh, System NPV: 335494148.921, System LCOE: 0.246
# --------------------------------------------------------------------------------
# PV Capacity: 20000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 60000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 123216081.608 kWh, System NPV: 334518528.147, System LCOE: 0.248
# --------------------------------------------------------------------------------
# PV Capacity: 20000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 40000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 136696270.322 kWh, System NPV: 359027541.512, System LCOE: 0.218
# --------------------------------------------------------------------------------
# PV Capacity: 20000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 45000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 136698006.264 kWh, System NPV: 358062125.641, System LCOE: 0.227
# --------------------------------------------------------------------------------
# PV Capacity: 20000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 50000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 136699046.729 kWh, System NPV: 357091821.263, System LCOE: 0.229
# --------------------------------------------------------------------------------
# PV Capacity: 20000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 55000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 136699786.757 kWh, System NPV: 356119212.355, System LCOE: 0.231
# --------------------------------------------------------------------------------
# PV Capacity: 20000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 60000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 136700045.687 kWh, System NPV: 355143520.347, System LCOE: 0.233
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 5000.0 kW, Battery Capacity: 40000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 101213035.156 kWh, System NPV: 263856122.485, System LCOE: 0.297
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 5000.0 kW, Battery Capacity: 45000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 101215141.877 kWh, System NPV: 262893393.995, System LCOE: 0.259
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 5000.0 kW, Battery Capacity: 50000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 101216299.678 kWh, System NPV: 261924011.700, System LCOE: 0.261
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 5000.0 kW, Battery Capacity: 55000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 101216591.855 kWh, System NPV: 260948536.047, System LCOE: 0.264
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 5000.0 kW, Battery Capacity: 60000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 101218504.815 kWh, System NPV: 259984066.279, System LCOE: 0.266
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 40000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 118639185.748 kWh, System NPV: 307525221.496, System LCOE: 0.221
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 45000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 118641036.673 kWh, System NPV: 306560571.818, System LCOE: 0.239
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 50000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 118641390.005 kWh, System NPV: 305585418.626, System LCOE: 0.242
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 55000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 118641666.610 kWh, System NPV: 304609919.098, System LCOE: 0.244
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 60000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 118643546.526 kWh, System NPV: 303644897.693, System LCOE: 0.246
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 40000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 133989426.124 kWh, System NPV: 339130688.620, System LCOE: 0.213
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 45000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 133990654.065 kWh, System NPV: 338161087.096, System LCOE: 0.225
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 50000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 133991424.600 kWh, System NPV: 337188909.661, System LCOE: 0.227
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 55000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 133991644.041 kWh, System NPV: 336212956.705, System LCOE: 0.229
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 60000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 133992558.549 kWh, System NPV: 335241553.434, System LCOE: 0.231
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 40000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 147387195.006 kWh, System NPV: 359060606.229, System LCOE: 0.205
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 45000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 147388221.051 kWh, System NPV: 358090107.070, System LCOE: 0.214
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 50000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 147388758.805 kWh, System NPV: 357116175.260, System LCOE: 0.216
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 55000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 147388990.923 kWh, System NPV: 356140304.789, System LCOE: 0.217
# --------------------------------------------------------------------------------
# PV Capacity: 25000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 60000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 147389518.921 kWh, System NPV: 355166352.515, System LCOE: 0.219
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 5000.0 kW, Battery Capacity: 40000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 112062777.193 kWh, System NPV: 265448892.658, System LCOE: 0.272
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 5000.0 kW, Battery Capacity: 45000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 112064648.518 kWh, System NPV: 264484334.108, System LCOE: 0.238
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 5000.0 kW, Battery Capacity: 50000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 112065039.155 kWh, System NPV: 263509484.246, System LCOE: 0.240
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 5000.0 kW, Battery Capacity: 55000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 112065318.419 kWh, System NPV: 262534003.771, System LCOE: 0.242
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 5000.0 kW, Battery Capacity: 60000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 112067233.421 kWh, System NPV: 261569272.411, System LCOE: 0.245
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 40000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 129332686.774 kWh, System NPV: 307823448.896, System LCOE: 0.207
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 45000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 129334529.708 kWh, System NPV: 306858695.676, System LCOE: 0.223
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 50000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 129334865.398 kWh, System NPV: 305883483.045, System LCOE: 0.225
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 55000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 129335122.964 kWh, System NPV: 304907845.477, System LCOE: 0.227
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 10000.0 kW, Battery Capacity: 60000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 129336996.761 kWh, System NPV: 303942822.962, System LCOE: 0.229
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 40000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 144578874.941 kWh, System NPV: 338571734.113, System LCOE: 0.200
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 45000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 144579852.758 kWh, System NPV: 337600601.750, System LCOE: 0.211
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 50000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 144580871.022 kWh, System NPV: 336629933.017, System LCOE: 0.213
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 55000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 144581079.787 kWh, System NPV: 335653917.653, System LCOE: 0.215
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 15000.0 kW, Battery Capacity: 60000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 144582021.690 kWh, System NPV: 334682692.053, System LCOE: 0.217
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 40000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 157912495.202 kWh, System NPV: 357941966.068, System LCOE: 0.194
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 45000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 157913198.419 kWh, System NPV: 356969274.718, System LCOE: 0.202
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 50000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 157913965.884 kWh, System NPV: 355996817.327, System LCOE: 0.203
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 55000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 157914226.774 kWh, System NPV: 355021169.294, System LCOE: 0.205
# --------------------------------------------------------------------------------
# PV Capacity: 30000 kW, Wind Turbine Capacity: 20000.0 kW, Battery Capacity: 60000 kWh, Genset Capacity: 19000.0 kW), Annual System Generation: 157914481.309 kWh, System NPV: 354045444.389, System LCOE: 0.207
# --------------------------------------------------------------------------------
# Configuration with the lowest system LCOE:
# PV Capacity: 30000 kW
# Wind Turbine Capacity: 20000.0 kW
# Battery Capacity: 40000 kWh
# Genset Capacity: 19000.0 kWh
# Total Annual Generation: 157912495.202 kWh
# NPV: 357941966.068
# System LCOE: 0.194 $/kWh

# %%
# Read the lat and lon data of an ore deposit from auCopper.csv, then download the corresponding solar and wind data using api, rewrite the yaml file.
# Simulate and optimise the hybrid system capacity at current deposit location, find and show the system config with the lowest LCOE 
# Store the sufficient,insufficient, and lowest LCOE results into different dataframes and save them as csv files
# Move on to the next ore deposit location and continue simulation until all the deposits are read

import requests
import os
import yaml
import pandas as pd
import numpy as np
from hopp.simulation import HoppInterface

def present_value(future_value, discount_rate, project_lifetime):
    """
    Calculate the present value of a future amount using the discount rate.
    """
    return future_value / ((1 + discount_rate) ** project_lifetime)

def calculate_lcoe(total_cost, total_generation, discount_rate, project_lifetime):
    """
    Calculate the Levelized Cost of Electricity (LCOE).
    """
    present_value_costs = present_value(total_cost, discount_rate, project_lifetime)
    present_value_generation = present_value(total_generation, discount_rate, project_lifetime)
    return present_value_costs / present_value_generation

def download_data_and_update_config(latitude, longitude, solar_year, wind_start, wind_end, api_key, email, yaml_file_path):
    # Define directories for saving files
    solar_dir = r'C:\Users\Public\miniconda\envs\microgrid\Lib\site-packages\hopp\simulation\resource_files\solar'
    wind_dir = r'C:\Users\Public\miniconda\envs\microgrid\Lib\site-packages\hopp\simulation\resource_files\wind'
    os.makedirs(solar_dir, exist_ok=True)
    os.makedirs(wind_dir, exist_ok=True)

    # Download Solar Data
    solar_base_url = "https://developer.nrel.gov/api/nsrdb/v2/solar/himawari7-download.csv"
    solar_params = {
        "wkt": f"POINT({longitude} {latitude})",
        "names": solar_year,
        "leap_day": "false",
        "interval": "60",
        "utc": "false",
        "full_name": "Hanrong Huang",
        "email": email,
        "affiliation": "UNSW",
        "mailing_list": "true",
        "reason": "research",
        "api_key": api_key,
        "attributes": "dni,dhi,ghi,dew_point,air_temperature,surface_pressure,wind_direction,wind_speed,surface_albedo"
    }
    solar_response = requests.get(solar_base_url, params=solar_params)
    solar_filename = f"{latitude}_{longitude}_psmv3_60_{solar_year}.csv"
    solar_path = os.path.join(solar_dir, solar_filename)

    if solar_response.status_code == 200:
        with open(solar_path, 'wb') as file:
            file.write(solar_response.content)
        print(f"Solar data downloaded and saved to {solar_path}.")
    else:
        print(f"Failed to download solar data: {solar_response.status_code}")
        print(solar_response.text)

    # Download Wind Data
    wind_url = "https://power.larc.nasa.gov/api/temporal/hourly/point"
    wind_params = {

        "start": wind_start,
        "end": wind_end,
        "latitude": latitude,
        "longitude": longitude,
        "community": "ag",
        "parameters": "WS50M,WD50M",
        "format": "srw",
        "user": "Hanrong",
        "header": "true",
        "time-standard": "lst"
    }
    wind_response = requests.get(wind_url, params=wind_params)
    wind_filename = f"{latitude}_{longitude}_NASA_{wind_start[:4]}_60min_50m.srw"
    wind_path = os.path.join(wind_dir, wind_filename)

    if wind_response.status_code == 200:
        with open(wind_path, 'wb') as file:
            file.write(wind_response.content)
        print(f"Wind data downloaded successfully and saved to {wind_path}.")
    else:
        print(f"Failed to download wind data: {wind_response.status_code}")
        print(wind_response.text)

    # Update YAML configuration file
    if os.path.exists(yaml_file_path):
        with open(yaml_file_path, 'r') as file:
            config = yaml.safe_load(file)

        # Updating site information
        config['site']['data']['lat'] = latitude
        config['site']['data']['lon'] = longitude
        config['site']['solar_resource_file'] = solar_path.replace('\\', '/')
        config['site']['wind_resource_file'] = wind_path.replace('\\', '/')

        with open(yaml_file_path, 'w') as file:
            yaml.safe_dump(config, file, default_flow_style=False, sort_keys=False)
        print(f"YAML configuration updated successfully at {yaml_file_path}.")
        print("-------------------------------------------------------------------------------------")
# Path to CSV
csv_path = "./Deposit data/auCopper - Copy.csv"
location_data = pd.read_csv(csv_path)

# API and user info
api_key = "3F5fBErsd9gKIPEdQpkWHNIhNj7gZG3j0y3lkzew"
email = "z5142067@ad.unsw.edu.au"
yaml_file_path = "./inputs/test file 2-api alternative.yaml"

# create frames for storing results
sufficient_frames = []
insufficient_frames = []
lowest_cost_frames = []

for index, row in location_data.iterrows():
    latitude = row['DEPOSIT_LATITUDE']
    longitude = row['DEPOSIT_LONGITUDE']
    deposit_uid = row['DEPOSIT_UID']
    print("------------------------------------------------------------------------------------------------------------")
    print(f"Hybrid microgrid simulation and optimisation at ore deposit (Lat: {latitude}, Lon: {longitude}) starts:")
    print("------------------------------------------------------------------------------------------------------------")
    download_data_and_update_config(latitude, longitude, "2015", "20180101", "20181231", api_key, email, yaml_file_path)

    # Insert simulation and results processing code here 
    # Initialization for the simulation setup
    yaml_file_path = "./inputs/test file 2-api alternative.yaml"
    
    # Parameters initialization from the hybrid plant model
    project_lifetime = 25  # years
    discount_rate = 0.08  # 8%
    
    # Initialize lists to store results
    sufficient_results = []
    insufficient_results = []
    
    # Define ranges for PV sizes, number of turbines, and battery capacities
    pv_size_range = range(20000, 31500, 5000)  # From 20,000 kW to 30,000 kW, in 5,000 kW increments
    num_turbines_range = range(5, 21, 5)  # From 5 to 20, in steps of 5, represent 5,000 kw to 20,000 kw
    battery_capacity_range = range(40000, 61000, 5000)  # From 40000 kWh to 60000 kWh, in 5000 kWh increments

    # Iteration starts
    for pv_size in pv_size_range:
        for num_turbines in num_turbines_range:
            for battery_capacity_kwh in battery_capacity_range:
                # Load the current configuration
                with open(yaml_file_path, 'r') as file:
                    config = yaml.safe_load(file)
    
                # Update the configuration for PV, wind, and battery
                config['technologies']['pv']['system_capacity_kw'] = pv_size
                config['technologies']['wind']['num_turbines'] = num_turbines
                config['technologies']['battery']['system_capacity_kwh'] = battery_capacity_kwh
    
                # Write the modified configuration back to the file
                with open(yaml_file_path, 'w') as file:
                    yaml.safe_dump(config, file)
    
                # Create a new HoppInterface instance and run the simulation
                hopp = HoppInterface(yaml_file_path)
                hopp.simulate(project_life=25)
                
                # Assign hopp.system to hybrid_plant for easy reference
                hybrid_plant = hopp.system

                # Total system generation over project lifetime
                pv_total_generation = np.sum(hybrid_plant.generation_profile.pv)
                wind_total_generation = np.sum(hybrid_plant.generation_profile.wind)
                battery_total_generation = np.sum(hybrid_plant.generation_profile.battery)
                genset_total_generation = np.sum(hybrid_plant.generation_profile.grid)  # Genset modeled as grid
                total_system_generation_over_lifetime = pv_total_generation + wind_total_generation + battery_total_generation + genset_total_generation
                
                # Genset Specific Calculations
                genset_capacity_kw = hybrid_plant.grid.interconnect_kw
                genset_install_cost_per_kw = 500
                replacement_cost_genset_per_kw = 500
                om_cost_per_kw_per_op_hour = 0.03 # o&m cost in $/kw/op.hour
                fuel_cost_per_l = 1.16
                specific_fuel_consumption_l_per_kwh = 0.261
                genset_operational_hours_per_year = np.sum(np.array(hybrid_plant.grid.generation_profile) > 0)/25 # Calculate the number of hours where generation is not zero per year
                generator_operational_life_hours = 15000 # genset operational lifetime in hours
                generator_operational_life_years = generator_operational_life_hours/genset_operational_hours_per_year # calculate genset operational life in years
                num_genset_replacements = np.ceil(project_lifetime / generator_operational_life_years) - 1
                
                # Genset Costs
                genset_installed_cost = genset_capacity_kw * genset_install_cost_per_kw
                replacement_cost_genset = num_genset_replacements * genset_capacity_kw * replacement_cost_genset_per_kw
                total_om_cost_genset = om_cost_per_kw_per_op_hour * genset_capacity_kw * genset_operational_hours_per_year * project_lifetime
                annual_fuel_consumption = genset_total_generation / project_lifetime * specific_fuel_consumption_l_per_kwh
                total_fuel_cost = annual_fuel_consumption * fuel_cost_per_l * project_lifetime
                total_genset_cost = genset_installed_cost + replacement_cost_genset + total_om_cost_genset + total_fuel_cost
    
                # Battery Costs
                battery_capacity_kwh = config['technologies']['battery']['system_capacity_kwh']
                battery_installed_cost = hybrid_plant.battery.total_installed_cost
                om_cost_battery_per_kwh = 10  # Annual O&M cost in $/kWh
                operational_life_battery = 15  # Battery operational life in years
                num_battery_replacements = np.ceil(project_lifetime/ operational_life_battery) - 1 
                replacement_cost_battery_per_kWh = 700  # Replacement cost per kWh
                replacement_cost_battery = num_battery_replacements * battery_capacity_kwh * replacement_cost_battery_per_kWh
                total_om_cost_battery = om_cost_battery_per_kwh * battery_capacity_kwh * project_lifetime
                total_battery_cost = battery_installed_cost + replacement_cost_battery + total_om_cost_battery
                
                # PV Costs
                pv_installed_cost = hybrid_plant.pv.total_installed_cost
                om_cost_pv_per_kw = 10  # Annual O&M cost $/kW
                total_om_cost_pv = om_cost_pv_per_kw * hybrid_plant.system_capacity_kw.pv * project_lifetime
                total_pv_cost = pv_installed_cost + total_om_cost_pv
                
                # Wind Costs
                wind_installed_cost = hybrid_plant.wind.total_installed_cost
                om_cost_wind_per_kw = 10  # Annual O&M cost $/kW
                total_om_cost_wind = om_cost_wind_per_kw * hybrid_plant.system_capacity_kw.wind * project_lifetime
                total_wind_cost = wind_installed_cost + total_om_cost_wind
                
                # Total System Costs over project lifetime
                total_system_cost = total_pv_cost + total_wind_cost + total_battery_cost + total_genset_cost
                
                # LCOE Calculation
                LCOE = calculate_lcoe(total_system_cost, total_system_generation_over_lifetime, discount_rate, project_lifetime)
    
                # Collect NPV for the current configuration
                npv = hybrid_plant.net_present_values.hybrid
                hybrid_installed_cost = hybrid_plant.grid.total_installed_cost
                
                # Calculate the annual system generation: PV + wind + battery + DGs (grid)
                annual_system_generation = hybrid_plant.annual_energies.pv + hybrid_plant.annual_energies.wind + hybrid_plant.annual_energies.battery + hybrid_plant.annual_energies.hybrid
                # Calculate the total annual load from the load profile
                total_annual_load = np.sum(hybrid_plant.site.desired_schedule * 1000)  # Convert MW to kW, then sum for kWh
                # Check if generation meets or exceeds the load
                if annual_system_generation >= total_annual_load:
                    sufficient_results.append({
                        "PV Capacity kW": pv_size,
                        "Wind Turbine Capacity kW": wind_capacity_kw,
                        "Battery Capacity kWh": battery_capacity_kwh,
                        "Genset Capacity kW": genset_capacity_kw,
                        "Annual System Generation kWh": annual_system_generation,
                        "System NPV": npv,
                        "System LCOE $/kWh": LCOE
                    })
                else:
                    insufficient_results.append({
                        "PV Capacity kW": pv_size,
                        "Wind Turbine Capacity kW": wind_capacity_kw,
                        "Battery Capacity kWh": battery_capacity_kwh,
                        "Genset Capacity kW": genset_capacity_kw,
                        "Annual System Generation kWh": annual_system_generation,
                        "Total Annual Load kWh": total_annual_load,
                        "System LCOE $/kWh": LCOE
                    })
    if sufficient_results:
        sufficient_df = pd.DataFrame(sufficient_results, columns=['PV Capacity kW', 'Wind Turbine Capacity kW', 'Battery Capacity kWh', 'Genset Capacity kW', 'Annual System Generation kWh', 'System NPV', 'System LCOE $/kWh'])
        sufficient_df['Deposit UID'] = deposit_uid
        sufficient_frames.append(sufficient_df)

        # Finding the configuration with the lowest LCOE among sufficient results
        lowest_cost_config = min(sufficient_results, key=lambda x: x['System LCOE $/kWh'])
        lowest_cost_df = pd.DataFrame([lowest_cost_config])
        lowest_cost_df.columns = ['PV Capacity kW', 'Wind Turbine Capacity kW', 'Battery Capacity kWh', 'Genset Capacity kW', 'Annual System Generation kWh', 'System NPV', 'System LCOE $/kWh']
        lowest_cost_df['Deposit UID'] = deposit_uid
        lowest_cost_frames.append(lowest_cost_df)

        print("Configuration with the lowest system LCOE:")
        print(f"PV Capacity: {lowest_cost_config['PV Capacity kW']} kW")
        print(f"Wind Turbine Capacity: {lowest_cost_config['Wind Turbine Capacity kW']} kW")
        print(f"Battery Capacity: {lowest_cost_config['Battery Capacity kWh']} kWh")
        print(f"Genset Capacity: {lowest_cost_config['Genset Capacity kW']} kW")
        print(f"Total Annual Generation: {lowest_cost_config['Annual System Generation kWh']:.3f} kWh")
        print(f"NPV: {lowest_cost_config['System NPV']:.3f}")
        print(f"System LCOE: {lowest_cost_config['System LCOE $/kWh']:.3f} $/kWh")
        print("-------------------------------------------------------------------------------------")

    if insufficient_results:
        insufficient_df = pd.DataFrame(insufficient_results, columns=['PV Capacity kW', 'Wind Turbine Capacity kW', 'Battery Capacity kWh', 'Genset Capacity kW', 'Annual System Generation kWh', 'Total Annual Load kWh', 'System LCOE $/kWh'])
        insufficient_df['Deposit UID'] = deposit_uid
        insufficient_frames.append(insufficient_df)

# Concatenate all results into single DataFrames
all_sufficient_df = pd.concat(sufficient_frames, ignore_index=True)
all_insufficient_df = pd.concat(insufficient_frames, ignore_index=True)
all_lowest_cost_df = pd.concat(lowest_cost_frames, ignore_index=True)

# Save results to CSV in the specified directory
output_dir = "./Simulation results"
os.makedirs(output_dir, exist_ok=True)
all_sufficient_df.to_csv(os.path.join(output_dir, "sufficient_systems.csv"), index=False)
all_insufficient_df.to_csv(os.path.join(output_dir, "insufficient_systems.csv"), index=False)
all_lowest_cost_df.to_csv(os.path.join(output_dir, "lowest_cost_configs.csv"), index=False)

print("------------------------------------------------------------------------------")
print("Simulation completed. Results are saved in the 'Simulation results' directory.")                    
print("------------------------------------------------------------------------------")
# Out:
# ------------------------------------------------------------------------------------------------------------
# Hybrid microgrid simulation and optimisation at ore deposit (Lat: -33.5265, Lon: 149.1588) starts:
# ------------------------------------------------------------------------------------------------------------
# Solar data downloaded and saved to C:\Users\Public\miniconda\envs\microgrid\Lib\site-packages\hopp\simulation\resource_files\solar\-33.5265_149.1588_psmv3_60_2015.csv.
# Wind data downloaded successfully and saved to C:\Users\Public\miniconda\envs\microgrid\Lib\site-packages\hopp\simulation\resource_files\wind\-33.5265_149.1588_NASA_2018_60min_50m.srw.
# YAML configuration updated successfully at ./inputs/test file 2-api alternative.yaml.
# -------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 187
#     185 replacement_cost_genset = num_genset_replacements * genset_capacity_kw * replacement_cost_genset_per_kw
#     186 total_om_cost_genset = om_cost_per_kw_per_op_hour * genset_capacity_kw * genset_operational_hours_per_year * project_lifetime
# --> 187 annual_fuel_consumption = genset_total_generation / project_lifetime * specific_fuel_consumption_l_per_kwh
#     188 total_fuel_cost = annual_fuel_consumption * fuel_cost_per_l * project_lifetime
#     189 total_genset_cost = genset_installed_cost + replacement_cost_genset + total_om_cost_genset + total_fuel_cost
#
# NameError: name 'genset_total_generation' is not defined

# %%
## Below are testing cells

## for dispatch options, refer to 'hybrid_dispatch_options.py'
""Args:
     dispatch_options (dict): Contains attribute key-value pairs to change default options.

         - **solver** (str, default='cbc'): MILP solver used for dispatch optimization problem. Options are `('glpk', 'cbc', 'xpress', 'xpress_persistent', 'gurobi_ampl', 'gurobi')`.

         - **solver_options** (dict): Dispatch solver options.

         - **battery_dispatch** (str, default='simple'): Sets the battery dispatch model to use for dispatch. Options are `('simple', 'one_cycle_heuristic', 'heuristic', 'non_convex_LV', 'convex', 'load_following_heuristic'
            ""

# %%
## find LCOE for different components and find the largest discrepency compared to HOMER
## testing yaml file
hopp = HoppInterface("./inputs/test file 2-api alternative.yaml")
print(hopp.system.system_capacity_kw) # hybrid = grid
# Out:
# {"pv": 28053.0, "wind": 108.0, "battery": 500, "hybrid": 100000.0}

# %%
# find the max grid capacity, treat it as diesel generators
# calculate its cost and add to the hybrid installed cost, the find the min lcoe among the sufficient systems.
# plot some figures like opennem for the hybrid system


hopp.simulate(project_life=25)
hybrid_plant = hopp.system

# %%
# calculate system NPC based on system NPV and revenue, NPC = NPV - Present Value of Revenues


def present_value(future_value, discount_rate, project_lifetime):
    """
    Calculate the present value of a future amount using the discount rate.
    """
    return future_value / ((1 + discount_rate) ** project_lifetime)

# Calculation of the present value of total revenues
total_revenue = np.sum(hybrid_plant.total_revenues.pv) + np.sum(hybrid_plant.total_revenues.wind) + np.sum(hybrid_plant.total_revenues.battery) + np.sum(hybrid_plant.total_revenues.hybrid)
project_lifetime = 25  # years
discount_rate = 0.08  # 8%

pv_of_total_revenue = present_value(total_revenue, discount_rate, project_lifetime)
print("Present Value of the total revenue:", pv_of_total_revenue)

# system total npvs
total_npvs = hybrid_plant.net_present_values.pv + hybrid_plant.net_present_values.wind + hybrid_plant.net_present_values.battery + hybrid_plant.net_present_values.hybrid

# Calculate NPC, NPC = NPV - Present Value of Total Revenues 
NPC = total_npvs - pv_of_total_revenue

## HOMER NPC = 396,386,300
# Out:
# Present Value of the total revenue: 431827730.8242289
# System NPC: 268545336.6123816
# 2957361503.589408

# %%
# Calculate NPC of each component.

project_lifetime = 25  # years
discount_rate = 0.08  # 8%

def present_value(future_value, discount_rate, project_lifetime):
    """
    Calculate the present value of a future amount using the discount rate.
    """
    return future_value / ((1 + discount_rate) ** project_lifetime)

# calculate NPC of pv
PV_revenue = np.sum(hybrid_plant.total_revenues.pv)
pv_of_PV_revenue = present_value(PV_revenue, discount_rate, project_lifetime)
print("Present Value of the PV revenue:", pv_of_PV_revenue)

PV_npv = hybrid_plant.net_present_values.pv
PV_NPC = PV_npv - pv_of_PV_revenue
print("PV NPC:", PV_NPC)

# calculate NPC of wind
wind_revenue = np.sum(hybrid_plant.total_revenues.wind)
pv_of_wind_revenue = present_value(wind_revenue, discount_rate, project_lifetime)
print("Present Value of the wind revenue:", pv_of_wind_revenue)

wind_npv = hybrid_plant.net_present_values.wind
wind_NPC = wind_npv - pv_of_wind_revenue
print("wind NPC:", wind_NPC)

# calculate NPC of battery
# Out:
# Present Value of the PV revenue: 249654319.83980584
# PV NPC: 200457630.38623708
# Present Value of the wind revenue: 21318340.704649273
# wind NPC: -3301781.1627296545

# %%
# generation of each component over project lifetime
pv_total_generation = np.sum(hybrid_plant.generation_profile.pv)
wind_total_generation = np.sum(hybrid_plant.generation_profile.wind)
battery_total_generation = np.sum(hybrid_plant.generation_profile.battery)
grid_total_generation = np.sum(hybrid_plant.grid.generation_profile)
# total generation over project lifetime
total_system_generation_over_lifetime = pv_total_generation + wind_total_generation + battery_total_generation + grid_total_generation
#####
print(pv_total_generation)
print(wind_total_generation)
print(battery_total_generation)
print(grid_total_generation)
print("Total generation over project lifetime: {}".format(total_system_generation_over_lifetime))
# Out:
# 1366856831.5038807
# 135838911.763034
# -8223.834462709827
# 865829919.7658572
# Total generation over project lifetime: 2368517439.1983094

# %%
## LCOE = discounted total system cost/discounted total system generation
## original version, where installed cost of each component is coming from HOPP, e.g. hybrid_plant.pv.total_installed_cost
import numpy as np
import yaml
import requests

def present_value(future_value, discount_rate, project_lifetime):
    """
    Calculate the present value of a future amount using the discount rate.
    """
    return future_value / ((1 + discount_rate) ** project_lifetime)

def calculate_lcoe(total_cost, total_generation, discount_rate, project_lifetime):
    """
    Calculate the Levelized Cost of Electricity (LCOE).
    """
    present_value_costs = present_value(total_cost, discount_rate, project_lifetime)
    present_value_generation = present_value(total_generation, discount_rate, project_lifetime)
    return present_value_costs / present_value_generation

# Load the configuration from a YAML file
yaml_file_path = "./inputs/test file 2-api alternative.yaml"
with open(yaml_file_path, 'r') as file:
    config = yaml.safe_load(file)

# Parameters initialization from the hybrid plant model
project_lifetime = 25  # years
discount_rate = 0.08  # 8%

# generation of each component over project lifetime
pv_total_generation = np.sum(hybrid_plant.generation_profile.pv)
wind_total_generation = np.sum(hybrid_plant.generation_profile.wind)
battery_total_generation = np.sum(hybrid_plant.generation_profile.battery)
genset_total_generation = np.sum(hybrid_plant.generation_profile.grid)  # Genset modeled as grid

# Genset Specific Calculations
genset_capacity_kw = hybrid_plant.grid.interconnect_kw
genset_install_cost_per_kw = 500
replacement_cost_genset_per_kw = 500
om_cost_per_kw_per_op_hour = 0.03 # o&m cost in $/kw/op.hour
fuel_cost_per_l = 1.16
specific_fuel_consumption_l_per_kwh = 0.261
genset_operational_hours_per_year = np.sum(np.array(hybrid_plant.grid.generation_profile) > 0)/25 # Calculate the number of hours where generation is not zero per year
generator_operational_life_hours = 15000 # genset operational lifetime in hours
generator_operational_life_years = generator_operational_life_hours/genset_operational_hours_per_year # calculate genset operational life in years
num_genset_replacements = np.ceil(project_lifetime / generator_operational_life_years) - 1
# Genset Costs
genset_installed_cost = genset_capacity_kw * genset_install_cost_per_kw
replacement_cost_genset = num_genset_replacements * genset_capacity_kw * replacement_cost_genset_per_kw
total_om_cost_genset = om_cost_per_kw_per_op_hour * genset_capacity_kw * genset_operational_hours_per_year * project_lifetime
annual_fuel_consumption = genset_total_generation / project_lifetime * specific_fuel_consumption_l_per_kwh
total_fuel_cost = annual_fuel_consumption * fuel_cost_per_l * project_lifetime
total_genset_cost = genset_installed_cost + replacement_cost_genset + total_om_cost_genset + total_fuel_cost

# Battery Costs
battery_capacity_kwh = config['technologies']['battery']['system_capacity_kwh']
battery_installed_cost = hybrid_plant.battery.total_installed_cost
om_cost_battery_per_kwh = 10  # Annual O&M cost in $/kWh
operational_life_battery = 15  # Battery operational life in years
num_battery_replacements = np.ceil(project_lifetime/ operational_life_battery) - 1 
replacement_cost_battery_per_kWh = 700  # Replacement cost per kWh
replacement_cost_battery = num_battery_replacements * battery_capacity_kwh * replacement_cost_battery_per_kWh
total_om_cost_battery = om_cost_battery_per_kwh * battery_capacity_kwh * project_lifetime
total_battery_cost = battery_installed_cost + replacement_cost_battery + total_om_cost_battery

# PV Costs
pv_installed_cost = hybrid_plant.pv.total_installed_cost
om_cost_pv_per_kw = 10  # Annual O&M cost $/kW
total_om_cost_pv = om_cost_pv_per_kw * hybrid_plant.system_capacity_kw['pv'] * project_lifetime
total_pv_cost = pv_installed_cost + total_om_cost_pv

# Wind Costs
wind_installed_cost = hybrid_plant.wind.total_installed_cost
om_cost_wind_per_kw = 10  # Annual O&M cost $/kW
total_om_cost_wind = om_cost_wind_per_kw * hybrid_plant.system_capacity_kw['wind'] * project_lifetime
total_wind_cost = wind_installed_cost + total_om_cost_wind

# Total System Costs 
total_system_cost = total_pv_cost + total_wind_cost + total_battery_cost + total_genset_cost

# Total system generation over project lifetime
pv_total_generation = np.sum(hybrid_plant.generation_profile.pv)
wind_total_generation = np.sum(hybrid_plant.generation_profile.wind)
battery_total_generation = np.sum(hybrid_plant.generation_profile.battery)
genset_total_generation = np.sum(hybrid_plant.generation_profile.grid)  # Genset modeled as grid
total_system_generation_over_lifetime = pv_total_generation + wind_total_generation + battery_total_generation + genset_total_generation

# LCOE Calculation
lcoe = calculate_lcoe(total_system_cost, total_system_generation_over_lifetime, discount_rate, project_lifetime)
print(f"The calculated Levelized Cost of Electricity (LCOE) is: ${lcoe:.4f} per kWh")
# Out:
# The calculated Levelized Cost of Electricity (LCOE) is: $0.2712 per kWh

# %%
## LCOE = discounted total system cost/discounted total system generation
## updated version, the installed cost of each component now aligns with HOMER
import numpy as np
import yaml
import requests

def present_value(future_value, discount_rate, project_lifetime):
    """
    Calculate the present value of a future amount using the discount rate.
    """
    return future_value / ((1 + discount_rate) ** project_lifetime)

def calculate_lcoe(total_cost, total_generation, discount_rate, project_lifetime):
    """
    Calculate the Levelized Cost of Electricity (LCOE).
    """
    present_value_costs = present_value(total_cost, discount_rate, project_lifetime)
    present_value_generation = present_value(total_generation, discount_rate, project_lifetime)
    return present_value_costs / present_value_generation

# Load the configuration from a YAML file
yaml_file_path = "./inputs/test file 2-api alternative.yaml"
with open(yaml_file_path, 'r') as file:
    config = yaml.safe_load(file)

# Parameters initialization from the hybrid plant model
project_lifetime = 25  # years
discount_rate = 0.08  # 8%

# generation of each component over project lifetime
pv_total_generation = np.sum(hybrid_plant.generation_profile.pv)
wind_total_generation = np.sum(hybrid_plant.generation_profile.wind)
battery_total_generation = np.sum(hybrid_plant.generation_profile.battery)
genset_total_generation = np.sum(hybrid_plant.generation_profile.grid)  # Genset modeled as grid

# Genset Specific Calculations
genset_capacity_kw = hybrid_plant.grid.interconnect_kw
genset_install_cost_per_kw = 500
replacement_cost_genset_per_kw = 500
om_cost_per_kw_per_op_hour = 0.03 # o&m cost in $/kw/op.hour
fuel_cost_per_l = 1.16
specific_fuel_consumption_l_per_kwh = 0.261 # L/kwh
genset_operational_hours_per_year = np.sum(np.array(hybrid_plant.grid.generation_profile) > 0)/25 # Calculate the number of hours where generation is not zero per year
generator_operational_life_hours = 15000 # genset operational lifetime in hours
generator_operational_life_years = generator_operational_life_hours/genset_operational_hours_per_year # calculate genset operational life in years
num_genset_replacements = np.ceil(project_lifetime / generator_operational_life_years) - 1
# Genset Costs
genset_installed_cost = genset_capacity_kw * genset_install_cost_per_kw
replacement_cost_genset = num_genset_replacements * genset_capacity_kw * replacement_cost_genset_per_kw
total_om_cost_genset = om_cost_per_kw_per_op_hour * genset_capacity_kw * genset_operational_hours_per_year * project_lifetime
total_fuel_consumption = genset_total_generation * specific_fuel_consumption_l_per_kwh
total_fuel_cost = total_fuel_consumption * fuel_cost_per_l 
total_genset_cost = genset_installed_cost + replacement_cost_genset + total_om_cost_genset + total_fuel_cost

# Battery Costs
battery_capacity_kwh = config['technologies']['battery']['system_capacity_kwh']
battery_installed_cost_per_kwh = 700 # battery installed cost per kwh, match with HOMER
battery_installed_cost = battery_capacity_kwh * battery_installed_cost_per_kwh
om_cost_battery_per_kwh = 10  # Annual O&M cost in $/kWh
operational_life_battery = 15  # Battery operational life in years
num_battery_replacements = np.ceil(project_lifetime/ operational_life_battery) - 1 
replacement_cost_battery_per_kWh = 700  # Replacement cost per kWh
replacement_cost_battery = num_battery_replacements * battery_capacity_kwh * replacement_cost_battery_per_kWh
total_om_cost_battery = om_cost_battery_per_kwh * battery_capacity_kwh * project_lifetime
total_battery_cost = battery_installed_cost + replacement_cost_battery + total_om_cost_battery

# PV Costs
pv_capacity_kw = hybrid_plant.system_capacity_kw.pv
pv_installed_cost_per_kw = 2000 # PV installed cost per kw, match wit HOMER
pv_installed_cost = pv_capacity_kw * pv_installed_cost_per_kw
om_cost_pv_per_kw = 10  # Annual O&M cost $/kW
total_om_cost_pv = om_cost_pv_per_kw * hybrid_plant.system_capacity_kw['pv'] * project_lifetime
total_pv_cost = pv_installed_cost + total_om_cost_pv

# Wind Costs
wind_capacity_kw = hybrid_plant.system_capacity_kw.wind
wind_installed_cost_per_kw = 5320 # wind installed cost per kw, match with HOMER
wind_installed_cost = wind_capacity_kw * wind_installed_cost_per_kw
om_cost_wind_per_kw = 10  # Annual O&M cost $/kW
total_om_cost_wind = om_cost_wind_per_kw * wind_capacity_kw * project_lifetime
total_wind_cost = wind_installed_cost + total_om_cost_wind

# Total System Costs 
total_system_cost = total_pv_cost + total_wind_cost + total_battery_cost + total_genset_cost

# Total system generation over project lifetime
pv_total_generation = np.sum(hybrid_plant.generation_profile.pv)
wind_total_generation = np.sum(hybrid_plant.generation_profile.wind)
battery_total_generation = np.sum(hybrid_plant.generation_profile.battery)
genset_total_generation = np.sum(hybrid_plant.generation_profile.grid)  # Genset modeled as grid
total_system_generation_over_lifetime = pv_total_generation + wind_total_generation + battery_total_generation + genset_total_generation

# LCOE Calculation
lcoe = calculate_lcoe(total_system_cost, total_system_generation_over_lifetime, discount_rate, project_lifetime)
print(f"The calculated Levelized Cost of Electricity (LCOE) is: ${lcoe:.4f} per kWh")
# Out:
# The calculated Levelized Cost of Electricity (LCOE) is: $0.2933 per kWh
