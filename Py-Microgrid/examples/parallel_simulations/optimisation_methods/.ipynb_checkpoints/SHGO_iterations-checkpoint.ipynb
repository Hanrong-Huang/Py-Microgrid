# %%
import requests
import os
import yaml
import pandas as pd
import numpy as np
import time
from scipy.optimize import minimize, differential_evolution, shgo
import csv
from hopp.simulation import HoppInterface
from hopp.tools.dispatch.plot_tools import (
    plot_battery_output, plot_battery_dispatch_error, plot_generation_profile, plot_battery_generation
)
from hopp.utilities import load_yaml
from hopp.simulation.technologies.grid import Grid
from hopp.simulation.technologies.grid import GridConfig
from hopp.utilities.keys import set_nrel_key_dot_env
from hopp.utilities.keys import set_developer_nrel_gov_key

# Set API for solar and wind resources
set_developer_nrel_gov_key('3F5fBErsd9gKIPEdQpkWHNIhNj7gZG3j0y3lkzew')

# Global variables
yaml_file_path = "./input_file_chunk_0_test_optimisation_methods.yaml"
project_lifetime = 25  # years
discount_rate = 0.0588  # real discount rate = 5.88%, discount rate 8%, inflation rate 2%


# Functions for Present Value and LCOE calculations
def present_value(future_value, discount_rate, project_lifetime):
    return future_value / ((1 + discount_rate) ** project_lifetime)

def calculate_lcoe(total_system_cost, total_system_generation_over_lifetime, discount_rate, project_lifetime):
    present_value_total_system_costs = present_value(total_system_cost, discount_rate, project_lifetime)
    present_value_total_system_generation = present_value(total_system_generation_over_lifetime, discount_rate, project_lifetime)
    return present_value_total_system_costs / present_value_total_system_generation

# Battery and load adjustment
def apply_flexible_load_and_adjust_battery(row):
    pv, wind, genset = row['PV Generation (kW)'], row['Wind Generation (kW)'], row['Genset Generation (kW)']
    battery, original_load = row['Original Battery Generation (kW)'], row['Original Load (kW)']
    
    total_generation_without_battery = pv + wind + genset
    
    if battery < 0 and total_generation_without_battery + battery < original_load:
        battery = 0
    
    adjusted_generation = total_generation_without_battery + battery
    
    if adjusted_generation < original_load:
        max_reduction = 0.20 * original_load
        load_reduction = min(original_load - adjusted_generation, max_reduction)
        adjusted_load = original_load - load_reduction
    else:
        adjusted_load = original_load
    
    new_deficit = adjusted_generation - adjusted_load
    
    return pd.Series({
        'Adjusted Battery Generation (kW)': battery,
        'Adjusted Load (kW)': adjusted_load,
        'Adjusted Deficit (kW)': new_deficit
    })

# Penalty calculation
def calculate_penalty(demand_met_percentage):
    unmet_percentage = 100 - demand_met_percentage
    if unmet_percentage <= 1:
        return 0.1 * unmet_percentage
    else:
        return 0.2 * unmet_percentage

# Load YAML configuration file safely
def load_yaml_safely(file_path):
    with open(file_path, 'r') as file:
        config = yaml.safe_load(file)
    if config is None:
        raise ValueError(f"The YAML configuration file at {file_path} is empty or invalid.")
    return config

# Save YAML configuration file safely
def save_yaml_safely(config, file_path):
    backup_path = file_path + '.bak'
    if os.path.exists(file_path):
        os.rename(file_path, backup_path)
    
    try:
        with open(file_path, 'w') as file:
            yaml.safe_dump(config, file, default_flow_style=False, sort_keys=False)
        
        if os.path.getsize(file_path) == 0:
            raise IOError("Failed to write data to YAML file")
        
        if os.path.exists(backup_path):
            os.remove(backup_path)
    except Exception as e:
        if os.path.exists(backup_path):
            os.rename(backup_path, file_path)
        raise IOError(f"Error saving YAML file: {str(e)}")

# Update YAML configuration
def update_yaml_config(yaml_file_path, solar_path, wind_path, latitude, longitude):
    if os.path.exists(yaml_file_path):
        config = load_yaml_safely(yaml_file_path)
        if 'site' not in config or 'data' not in config['site']:
            raise KeyError("The YAML configuration is missing required 'site.data' key.")

        config['site']['data']['lat'] = latitude
        config['site']['data']['lon'] = longitude
        config['site']['solar_resource_file'] = solar_path.replace('\\', '/')
        config['site']['wind_resource_file'] = wind_path.replace('\\', '/')

        save_yaml_safely(config, yaml_file_path)
        print(f"YAML configuration updated successfully at {yaml_file_path}.")
    else:
        raise FileNotFoundError(f"The YAML file at {yaml_file_path} does not exist.")

# Download solar and wind resource data
def download_data_and_update_config(latitude, longitude, solar_year, wind_start, wind_end, api_key, email, yaml_file_path):
    # Define directories for saving files
    solar_dir = r'/home/z5142067/miniconda3/envs/microgrid/lib/python3.8/site-packages/hopp/simulation/resource_files/solar'
    wind_dir = r'/home/z5142067/miniconda3/envs/microgrid/lib/python3.8/site-packages/hopp/simulation/resource_files/wind'
    os.makedirs(solar_dir, exist_ok=True)
    os.makedirs(wind_dir, exist_ok=True)

    # Download Solar Data
    solar_base_url = "https://developer.nrel.gov/api/nsrdb/v2/solar/himawari-download.csv"
    solar_params = {
        "wkt": f"POINT({longitude} {latitude})",
        "names": solar_year,
        "leap_day": "false",
        "interval": "60",
        "utc": "false",
        "full_name": "Hanrong Huang",
        "email": email,
        "affiliation": "UNSW",
        "mailing_list": "true",
        "reason": "research",
        "api_key": api_key,
        "attributes": "dni,dhi,ghi,dew_point,air_temperature,surface_pressure,wind_direction,wind_speed,surface_albedo"
    }
    solar_response = requests.get(solar_base_url, params=solar_params)
    solar_filename = f"{latitude}_{longitude}_psmv3_60_{solar_year}.csv"
    solar_path = os.path.join(solar_dir, solar_filename)

    if solar_response.status_code == 200:
        with open(solar_path, 'wb') as file:
            file.write(solar_response.content)
        print(f"Solar data downloaded and saved to {solar_path}.")
    else:
        print(f"Failed to download solar data: {solar_response.status_code}")
        print(solar_response.text)

    # Download Wind Data
    wind_url = "https://power.larc.nasa.gov/api/temporal/hourly/point"
    wind_params = {
        "start": wind_start,
        "end": wind_end,
        "latitude": latitude,
        "longitude": longitude,
        "community": "ag",
        "parameters": "WS50M,WD50M",
        "format": "srw",
        "user": "Hanrong",
        "header": "true",
        "time-standard": "lst"
    }
    wind_response = requests.get(wind_url, params=wind_params)
    wind_filename = f"{latitude}_{longitude}_NASA_{wind_start[:4]}_60min_50m.srw"
    wind_path = os.path.join(wind_dir, wind_filename)

    if wind_response.status_code == 200:
        with open(wind_path, 'wb') as file:
            file.write(wind_response.content)
        print(f"Wind data downloaded successfully and saved to {wind_path}.")
    else:
        print(f"Failed to download wind data: {wind_response.status_code}")
        print(wind_response.text)

    # Update YAML configuration file
    try:
        update_yaml_config(yaml_file_path, solar_path, wind_path, latitude, longitude)
    except Exception as e:
        raise RuntimeError(f"Error updating YAML configuration: {e}")
        
# Objective function for optimization
def objective_function(x):
    # Ensure integer values for specific variables
    pv_size = float(np.clip(round(x[0]), bounds[0][0], bounds[0][1]))
    num_turbines = int(np.clip(round(x[1]), bounds[1][0], bounds[1][1]))
    battery_capacity_kwh = float(np.clip(round(x[2]), bounds[2][0], bounds[2][1]))
    battery_capacity_kw = float(np.clip(round(x[3]), bounds[3][0], bounds[3][1]))
    grid_interconnect_kw = float(np.clip(round(x[4]), bounds[4][0], bounds[4][1]))

    # Update the YAML configuration with rounded integer variable
    config = load_yaml_safely(yaml_file_path)
    config['technologies']['pv']['system_capacity_kw'] = pv_size
    config['technologies']['wind']['num_turbines'] = num_turbines
    config['technologies']['battery']['system_capacity_kwh'] = battery_capacity_kwh
    config['technologies']['battery']['system_capacity_kw'] = battery_capacity_kw
    config['technologies']['grid']['interconnect_kw'] = grid_interconnect_kw
    save_yaml_safely(config, yaml_file_path)

    # Create a new HoppInterface instance and run the simulation
    try:
        hopp = HoppInterface(yaml_file_path)
        hopp.simulate(project_life=25)
    except Exception as e:
        print(f"Simulation failed: {e}")
        return 1e6, {}  # Return a high LCOE and empty result for infeasible solutions

    # Calculate system components generation over project lifetime
    hybrid_plant = hopp.system

    pv_total_generation = np.sum(hybrid_plant.generation_profile.pv)
    wind_total_generation = np.sum(hybrid_plant.generation_profile.wind)
    battery_total_generation = np.sum(hybrid_plant.generation_profile.battery)
    genset_total_generation = np.sum(hybrid_plant.generation_profile.grid)

    # Total system generation = PV + wind + genset, excluding battery
    total_system_generation_over_lifetime = pv_total_generation + wind_total_generation + genset_total_generation 

    # Genset Specific Calculations
    genset_capacity_kw = hybrid_plant.grid.interconnect_kw
    genset_install_cost_per_kw = 500
    replacement_cost_genset_per_kw = 500
    om_cost_per_kw_per_op_hour = 0.03  # Genset O&M cost per kW per operating hour
    fuel_cost_per_l = 1.20
    specific_fuel_consumption_l_per_kwh = 0.250
    genset_operational_hours_per_year = np.sum(np.array(hybrid_plant.grid.generation_profile) > 0) / project_lifetime
    generator_operational_life_hours = 15000
    generator_operational_life_years = generator_operational_life_hours / genset_operational_hours_per_year
    num_genset_replacements = float(project_lifetime / generator_operational_life_years) - 1

    genset_installed_cost = genset_capacity_kw * genset_install_cost_per_kw
    replacement_cost_genset = num_genset_replacements * genset_capacity_kw * replacement_cost_genset_per_kw
    total_om_cost_genset = om_cost_per_kw_per_op_hour * genset_capacity_kw * genset_operational_hours_per_year * project_lifetime
    total_fuel_consumption = genset_total_generation * specific_fuel_consumption_l_per_kwh
    total_fuel_cost = total_fuel_consumption * fuel_cost_per_l
    total_genset_cost = genset_installed_cost + replacement_cost_genset + total_om_cost_genset + total_fuel_cost

    # Battery Costs
    battery_capacity_kwh = config['technologies']['battery']['system_capacity_kwh']
    battery_installed_cost = hybrid_plant.battery.total_installed_cost  # can be modified in hopp/tools/analysis/bos/cost_calculator.py
    om_cost_battery_per_kwh_per_year = 10  # Battery O&M cost per kW per year
    operational_life_battery = 15
    num_battery_replacements = float(project_lifetime / operational_life_battery) - 1
    replacement_cost_battery_per_kWh = battery_installed_cost / battery_capacity_kwh  # Battery replacement cost per kWh, 700 $/kWh
    replacement_cost_battery = num_battery_replacements * battery_capacity_kwh * replacement_cost_battery_per_kWh
    total_om_cost_battery = om_cost_battery_per_kwh_per_year * battery_capacity_kwh * project_lifetime
    total_battery_cost = battery_installed_cost + replacement_cost_battery + total_om_cost_battery

    # PV Costs
    pv_capacity_kw = hybrid_plant.system_capacity_kw.pv
    pv_installed_cost = hybrid_plant.pv.total_installed_cost  # can be modified in hopp/tools/analysis/bos/cost_calculator.py
    om_cost_pv_per_kw_per_year = 10  # PV O&M cost per kW per year
    total_om_cost_pv = om_cost_pv_per_kw_per_year * pv_capacity_kw * project_lifetime
    total_pv_cost = pv_installed_cost + total_om_cost_pv

    # Wind Costs
    wind_capacity_kw = hybrid_plant.system_capacity_kw.wind
    wind_installed_cost = hybrid_plant.wind.total_installed_cost  # can be modified in hopp/tools/analysis/bos/cost_calculator.py
    om_cost_wind_per_kw_per_year = 40  # Wind O&M cost per kW per year
    total_om_cost_wind = om_cost_wind_per_kw_per_year * wind_capacity_kw * project_lifetime
    total_wind_cost = wind_installed_cost + total_om_cost_wind

    # Total System Costs over project lifetime
    total_system_cost = total_pv_cost + total_wind_cost + total_battery_cost + total_genset_cost

    # Calculate NPC 
    npc = present_value(total_system_cost, discount_rate, project_lifetime)
    
    # Create a DataFrame for flexible load and battery adjustment calculation
    df = pd.DataFrame({
        'PV Generation (kW)': np.array(hybrid_plant.generation_profile.pv[:8760]), 
        'Wind Generation (kW)': np.array(hybrid_plant.generation_profile.wind[:8760]),  
        'Genset Generation (kW)': np.array(hybrid_plant.generation_profile.grid[:8760]), 
        'Original Battery Generation (kW)': np.array(hybrid_plant.generation_profile.battery[:8760]), 
        'Original Load (kW)': np.array(hybrid_plant.site.desired_schedule[:8760]) * 1000   # Convert MW to kW
    })

    # Apply flexible load and battery charging adjustment
    adjusted_results = df.apply(apply_flexible_load_and_adjust_battery, axis=1)
    df['Adjusted Deficit (kW)'] = adjusted_results['Adjusted Deficit (kW)']
    df['Adjusted Load (kW)'] = adjusted_results['Adjusted Load (kW)']
    df['Adjusted Battery Generation (kW)'] = adjusted_results['Adjusted Battery Generation (kW)']

    # Calculate the number of deficit hours that have been fixed by the adjustments (for one year)
    original_deficits = df[df['Original Load (kW)'] > (df['PV Generation (kW)'] + df['Wind Generation (kW)'] + df['Genset Generation (kW)'] + df['Original Battery Generation (kW)'])]
    remaining_deficits = df[df['Adjusted Deficit (kW)'] < 0]
    deficit_hours_fixed_one_year = len(original_deficits) - len(remaining_deficits)

    # Calculate metrics for one year
    total_load_served_one_year = np.sum(df['Adjusted Load (kW)'])
    total_load_reduction_one_year = np.sum(df['Original Load (kW)'] - df['Adjusted Load (kW)'])
    total_charging_prevented_one_year = np.sum(np.maximum(0, -df['Original Battery Generation (kW)'] + df['Adjusted Battery Generation (kW)']))
    total_load_not_served_one_year = np.sum(np.maximum(0, -df['Adjusted Deficit (kW)']))

    # Calculate values for the entire project lifetime
    deficit_hours_fixed = deficit_hours_fixed_one_year * project_lifetime
    total_load_served = total_load_served_one_year * project_lifetime
    total_load_reduction = total_load_reduction_one_year * project_lifetime
    total_charging_prevented = total_charging_prevented_one_year * project_lifetime
    total_load_not_served = total_load_not_served_one_year * project_lifetime

    # Calculate percentages
    total_load_reduction_percentage = (total_load_reduction / (np.sum(df['Original Load (kW)']) * project_lifetime)) * 100
    demand_met_percentage = ((total_load_served - total_load_not_served) / total_load_served) * 100

    # Calculate LCOE
    lcoe = calculate_lcoe(total_system_cost, total_load_served, discount_rate, project_lifetime)

    # Check if the system meets the demand for all hours
    all_hours_sufficient = np.all(df['Adjusted Deficit (kW)'] >= 0)

    # Prepare result dictionary with lifetime values
    result = {
        "PV Capacity (kW)": pv_size,
        "Wind Turbine Capacity (kW)": num_turbines * 1000,  # 1000 kW per turbine
        "Genset Capacity (kW)": grid_interconnect_kw,
        "Battery Energy Capacity (kWh)": battery_capacity_kwh,
        "Battery Power Capacity (kW)": battery_capacity_kw,
        "Total System Generation (kWh)": total_system_generation_over_lifetime,
        "Total PV Generation (kWh)": pv_total_generation,
        "Total Wind Generation (kWh)": wind_total_generation,
        "Total Genset Generation (kWh)": genset_total_generation,
        "Total Battery Generation (kWh)": battery_total_generation,
        "System NPC ($)": npc,
        "System LCOE ($/kWh)": lcoe,
        "Deficit Hours Fixed": deficit_hours_fixed,
        "Total Load Reduction (kWh)": total_load_reduction,
        "Total Load Served (kWh)": total_load_served,
        "Load Reduction Percentage": total_load_reduction_percentage,
        "Total Charging Prevented (kWh)": total_charging_prevented,
        "Demand Not Served (kWh)": total_load_not_served,
        "Demand Met Percentage": demand_met_percentage,
        "Project Lifetime (years)": project_lifetime
    }

    # Check if all hours were sufficient and apply the penalty if there are deficit hours
    if all_hours_sufficient:
        return lcoe, result
    else:
        penalty = calculate_penalty(demand_met_percentage)
        penalized_lcoe = lcoe + penalty
        result["Penalized LCOE ($/kWh)"] = penalized_lcoe
        return penalized_lcoe, result

# OptimizationTracker class
class OptimizationTracker:
    def __init__(self, csv_file):
        self.csv_file = csv_file
        self.iteration_count = 0
        self.fieldnames = ['Iteration', 'Objective Value', 'Parameters', 'Time (seconds)']
        self.data = []
        self.start_time = time.time()

    def track(self, x, f=None):
        self.iteration_count += 1
        current_time = time.time()
        elapsed_time = current_time - self.start_time
        
        x_int = [int(round(xi)) for xi in x]
        lcoe = f if f is not None else objective_function(x_int)[0]
        self.data.append({
            'Iteration': self.iteration_count,
            'Objective Value': lcoe,
            'Parameters': x_int,
            'Time (seconds)': elapsed_time
        })
        print(f"Iteration {self.iteration_count}: Objective Value (LCOE) = {lcoe}, Parameters = {x_int}, Time = {elapsed_time:.2f} seconds")

    def save_to_csv(self):
        with open(self.csv_file, 'w', newline='') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=self.fieldnames)
            writer.writeheader()
            for row in self.data:
                row_copy = row.copy()
                row_copy['Parameters'] = str(row['Parameters'])
                writer.writerow(row_copy)

# Class to hold optimization result
class OptimizationResult:
    def __init__(self, x, success):
        self.x = x
        self.success = success
        
# Global variable for the tracker
global_tracker = None

# Base objective function
def base_objective_function(x):
    x_int = [int(round(xi)) for xi in x]
    return objective_function(x_int)[0]

# Tracking wrapper
def track_evaluation(func):
    def wrapper(x):
        result = func(x)
        if global_tracker is not None:
            global_tracker.track(x, result)
        return result
    return wrapper

# Integer constraint objective (used for Nelder-Mead, Powell and COBYlA)
integer_constraint_objective = base_objective_function

# Tracked integer constraint objective (used for differential evo and shgo)
tracked_integer_constraint_objective = track_evaluation(base_objective_function)

# Custom callback for Nelder-Mead
def custom_callback(xk):
    global best_score, iterations, global_tracker
    iterations += 1
    score = base_objective_function(xk)
    if global_tracker is not None:
        global_tracker.track(xk, score)
    if best_score is None or score < best_score:
        best_score = score
    else:
        if iterations > 50 and abs(score - best_score) < 1e-3:
            return True
    return False

# Run optimization function
def run_optimization(method, bounds, deposit_uid, iteration_output_dir, latitude, longitude):
    global global_tracker, best_score, iterations
    
    start_time = time.time()
    
    tracker = OptimizationTracker(os.path.join(iteration_output_dir, f'{method}_iterations_{deposit_uid}.csv'))
    global_tracker = tracker
    
    best_score = None
    iterations = 0

    # Choose the appropriate objective function based on the method
    obj_func = integer_constraint_objective if method == 'Nelder-Mead' else tracked_integer_constraint_objective

    try:
        if method == 'Nelder-Mead':
            x0 = [int(bound[0] + 0.5 * (bound[1] - bound[0])) for bound in bounds]
            result = minimize(
                obj_func,
                x0,
                method=method,
                options={
                    'maxiter': 200,
                    'xatol': 1,
                    'fatol': 1e-3,
                    'disp': True
                },
                callback=custom_callback
            )
        elif method == 'COBYLA':
            x0 = [int(bound[0] + 0.5 * (bound[1] - bound[0])) for bound in bounds]
            result = minimize(
                obj_func,
                x0,
                method=method,
                bounds=bounds,
                options={
                    'maxiter': 200,
                    'rhobeg': 1.0,
                    'tol': 1e-5,
                    'disp': True
                }
            )
        elif method == 'Powell':
            x0 = [int(bound[0] + 0.5 * (bound[1] - bound[0])) for bound in bounds]
            result = minimize(
                obj_func,
                x0,
                method=method,
                bounds=bounds,
                options={
                    'maxiter': 200,
                    'xtol': 1e-5,
                    'ftol': 1e-5,
                    'disp': True
                }
            )
        elif method == 'Differential Evolution':
            result = differential_evolution(
                obj_func,
                bounds,
                strategy='best1bin',
                maxiter=200,
                popsize=15,
                tol=1e-5,
                mutation=(0.5, 1),
                recombination=0.7,
                updating='immediate',
                workers=1,
                disp=True
            )
        elif method == 'SHGO':
            result = shgo(
                obj_func,
                bounds,
                n=125,
                iters=4,
                sampling_method='sobol',
                options={'disp': True}
            )
        else:
            raise ValueError(f"Unknown method: {method}")
        
        success = result.success
    except Exception as e:
        print(f"Optimization failed for method {method}: {e}")
        result = OptimizationResult(None, False)
        
    end_time = time.time()
    total_time = end_time - start_time

    tracker.save_to_csv()
    global_tracker = None

    if result and getattr(result, 'x', None) is not None:
        optimal_x = [int(round(x)) for x in result.x]
        lcoe, optimal_results = objective_function(optimal_x)

        optimization_results.append({
            'Method': method,
            'Deposit UID': deposit_uid,
            'Latitude': latitude,
            'Longitude': longitude,
            'Iterations': iterations,
            'Duration (seconds)': total_time,
            'LCOE': lcoe,
            **optimal_results
        })
        print(f"{method} optimization successful. LCOE: {lcoe:.6f}, Iterations: {iterations}, Total Time: {total_time:.2f} seconds")
    else:
        print(f"{method} optimization failed or was stopped early. Total Time: {total_time:.2f} seconds")

    return result, iterations, total_time

# Main execution logic
if __name__ == "__main__":
    csv_path = "../deposit_data/auCopper_chunk_0_test_optimisation_methods.csv"
    location_data = pd.read_csv(csv_path)
    api_key = "3F5fBErsd9gKIPEdQpkWHNIhNj7gZG3j0y3lkzew"
    email = "z5142067@ad.unsw.edu.au"
    optimization_results = []
    iteration_output_dir = "./optimisation_results"
    os.makedirs(iteration_output_dir, exist_ok=True)

    methods_to_test = ['SHGO']

    # Bounds for the variables: PV, wind, battery_capacity_kwh, battery_capacity_kw, genset
    bounds = [(10000, 45000), (10, 45), (15000, 30000), (5000, 10000), (17000, 30000)]

    for index, row in location_data.iterrows():
        latitude = row['DEPOSIT_LATITUDE']
        longitude = row['DEPOSIT_LONGITUDE']
        deposit_uid = row['DEPOSIT_UID']
        print(f"\nHybrid microgrid simulation and optimization at ore deposit (Lat: {latitude}, Lon: {longitude}) starts:")

        try:
            # Assume you have a function to download data and update config
            download_data_and_update_config(latitude, longitude, "2020", "20200101", "20201231", api_key, email, yaml_file_path)
        except Exception as e:
            print(f"Failed to download data or update configuration: {e}")
            continue
            
        for method in methods_to_test:
            print(f"\nTesting optimization method: {method}")
            result, iterations, duration = run_optimization(method, bounds, deposit_uid, iteration_output_dir, latitude, longitude)

            if result and getattr(result, 'x', None) is not None:
                optimal_x = result.x

                # Round integer variables if needed
                if method != 'Nelder-Mead':  # Nelder-Mead already handled internally
                    optimal_x[1] = int(round(optimal_x[1]))  # Number of turbines

                # Get LCOE and results
                lcoe, optimal_results = objective_function(optimal_x)

                optimization_results.append({
                    'Method': method,
                    'Deposit UID': deposit_uid,
                    'Latitude': latitude,
                    'Longitude': longitude,
                    'Iterations': iterations,
                    'Duration (seconds)': duration,
                    'LCOE ($/kWh)': lcoe,
                    **optimal_results
                })
                print(f"{method} optimization successful. LCOE: {lcoe:.6f}, Iterations: {iterations}, Time: {duration:.2f} seconds")
            else:
                print(f"{method} optimization failed to converge or was stopped early.")

    # Saving and summarizing results
    if optimization_results:
        optimization_df = pd.DataFrame(optimization_results)
        output_dir = "./optimisation_results"
        os.makedirs(output_dir, exist_ok=True)
        optimization_df.to_csv(os.path.join(output_dir, "optimisation_results_SHGO.csv"), index=False)
        print("\nOptimization comparison results are saved in the 'optimisation_results' directory.")

        # Best results per deposit
        best_results = optimization_df.loc[optimization_df.groupby('Deposit UID')['LCOE'].idxmin()]
        print("\nBest results for each deposit:")
        print(best_results[['Method', 'Iterations', 'Duration (seconds)', 'LCOE']])

        # Method performance summary
        method_performance = optimization_df.groupby('Method').agg({
            'Iterations': ['median', 'min', 'max'],
            'Duration (seconds)': ['median', 'min', 'max'],
            'LCOE': ['median', 'min', 'max', 'std']
        }).sort_values(('LCOE', 'median'))
        print("\nMethod performance summary:")
        print(method_performance)

        # Number of times each method found the best solution
        best_method_counts = optimization_df.loc[optimization_df.groupby('Deposit UID')['LCOE'].idxmin()]['Method'].value_counts()
        print("\nNumber of times each method found the best solution:")
        print(best_method_counts)

        # Success rate of each method (%)
        unique_deposits = optimization_df['Deposit UID'].nunique()
        success_rate = (optimization_df.groupby('Method')['LCOE'].count() / unique_deposits) * 100
        print("\nSuccess rate of each method (%):")
        print(success_rate)
    else:
        print("No successful optimization results to save.")
# Out:
# /home/z5142067/miniconda3/envs/microgrid/lib/python3.8/site-packages/hopp/examples/parallel_simulations/optimisation_methods/log/hybrid_systems_2024-11-08T16.32.46.259103.log
#
# Hybrid microgrid simulation and optimization at ore deposit (Lat: -31.1629, Lon: 145.6538) starts:
# Solar data downloaded and saved to /home/z5142067/miniconda3/envs/microgrid/lib/python3.8/site-packages/hopp/simulation/resource_files/solar/-31.1629_145.6538_psmv3_60_2020.csv.
# Wind data downloaded successfully and saved to /home/z5142067/miniconda3/envs/microgrid/lib/python3.8/site-packages/hopp/simulation/resource_files/wind/-31.1629_145.6538_NASA_2020_60min_50m.srw.
# YAML configuration updated successfully at ../input_file_chunk_0_test_optimisation_methods.yaml.
#
# Testing optimization method: SHGO
# Splitting first generation
# Generating sampling points
# Iteration 1: Objective Value (LCOE) = 0.2890503966658966, Parameters = [10000, 10, 15000, 5000, 17000], Time = 11.66 seconds
# Iteration 2: Objective Value (LCOE) = 0.26290325656999936, Parameters = [27500, 28, 22500, 7500, 23500], Time = 23.52 seconds
# Iteration 3: Objective Value (LCOE) = 0.28707059825109166, Parameters = [36250, 19, 18750, 6250, 26750], Time = 35.02 seconds
# Iteration 4: Objective Value (LCOE) = 0.24956829232711644, Parameters = [18750, 36, 26250, 8750, 20250], Time = 47.06 seconds
# Iteration 5: Objective Value (LCOE) = 0.26065729412723043, Parameters = [23125, 23, 24375, 9375, 21875], Time = 59.04 seconds
# Iteration 6: Objective Value (LCOE) = 0.28265100412475247, Parameters = [40625, 41, 16875, 6875, 28375], Time = 71.30 seconds
# Iteration 7: Objective Value (LCOE) = 0.29584097152545163, Parameters = [31875, 14, 28125, 8125, 25125], Time = 83.04 seconds
# Iteration 8: Objective Value (LCOE) = 0.24124178821215064, Parameters = [14375, 32, 20625, 5625, 18625], Time = 95.08 seconds
# Iteration 9: Objective Value (LCOE) = 0.27603006038149536, Parameters = [16562, 21, 29062, 7188, 24312], Time = 106.91 seconds
# Iteration 10: Objective Value (LCOE) = 0.25013981661000717, Parameters = [34062, 38, 21562, 9688, 17812], Time = 118.95 seconds
# Iteration 11: Objective Value (LCOE) = 0.29198348508957894, Parameters = [42812, 12, 25312, 5938, 21062], Time = 130.60 seconds
# Iteration 12: Objective Value (LCOE) = 0.2696197957374679, Parameters = [25312, 30, 17812, 8438, 27562], Time = 142.49 seconds
# Iteration 13: Objective Value (LCOE) = 0.2940623623820192, Parameters = [20938, 17, 19688, 7812, 29188], Time = 154.30 seconds
# Iteration 14: Objective Value (LCOE) = 0.2707945189641765, Parameters = [38438, 34, 27188, 5312, 22688], Time = 166.26 seconds
# Iteration 15: Objective Value (LCOE) = 0.24897751686097597, Parameters = [29688, 25, 15938, 9062, 19438], Time = 178.13 seconds
# Iteration 16: Objective Value (LCOE) = 0.2687412401775801, Parameters = [12188, 43, 23438, 6562, 25938], Time = 190.27 seconds
# Iteration 17: Objective Value (LCOE) = 0.2540143098838417, Parameters = [13281, 26, 22031, 8281, 20656], Time = 202.10 seconds
# Iteration 18: Objective Value (LCOE) = 0.28084995872508817, Parameters = [30781, 44, 29531, 5781, 27156], Time = 214.27 seconds
# Iteration 19: Objective Value (LCOE) = 0.2810309780228524, Parameters = [39531, 18, 18281, 9531, 23906], Time = 225.98 seconds
# Iteration 20: Objective Value (LCOE) = 0.2413464167147721, Parameters = [22031, 35, 25781, 7031, 17406], Time = 238.10 seconds
# Iteration 21: Objective Value (LCOE) = 0.2712814752765607, Parameters = [26406, 13, 27656, 6406, 19031], Time = 249.61 seconds
# Iteration 22: Objective Value (LCOE) = 0.27964006963976873, Parameters = [43906, 31, 20156, 8906, 25531], Time = 261.45 seconds
# Iteration 23: Objective Value (LCOE) = 0.2932606357824337, Parameters = [35156, 22, 23906, 5156, 28781], Time = 273.26 seconds
# Iteration 24: Objective Value (LCOE) = 0.24916580685708126, Parameters = [17656, 40, 16406, 7656, 22281], Time = 285.39 seconds
# Iteration 25: Objective Value (LCOE) = 0.3028626642703827, Parameters = [15469, 15, 22969, 9219, 27969], Time = 297.15 seconds
# Iteration 26: Objective Value (LCOE) = 0.25403018609908734, Parameters = [32969, 33, 15469, 6719, 21469], Time = 309.26 seconds
# Iteration 27: Objective Value (LCOE) = 0.26299495341913204, Parameters = [41719, 24, 26719, 7969, 18219], Time = 321.10 seconds
# Iteration 28: Objective Value (LCOE) = 0.26088661593760487, Parameters = [24219, 42, 19219, 5469, 24719], Time = 333.29 seconds
# Iteration 29: Objective Value (LCOE) = 0.2755172525180454, Parameters = [19844, 20, 17344, 6094, 26344], Time = 344.98 seconds
# Iteration 30: Objective Value (LCOE) = 0.26083863626168763, Parameters = [37344, 37, 24844, 8594, 19844], Time = 357.16 seconds
# Iteration 31: Objective Value (LCOE) = 0.290262454310918, Parameters = [28594, 11, 21094, 7344, 23094], Time = 369.31 seconds
# Iteration 32: Objective Value (LCOE) = 0.2925668489612267, Parameters = [11094, 29, 28594, 9844, 29594], Time = 381.25 seconds
# Iteration 33: Objective Value (LCOE) = 0.26355339361183583, Parameters = [11641, 19, 25547, 7734, 18828], Time = 393.26 seconds
# Iteration 34: Objective Value (LCOE) = 0.2646772189669283, Parameters = [29141, 37, 18047, 5234, 25328], Time = 405.38 seconds
# Iteration 35: Objective Value (LCOE) = 0.3234706115107193, Parameters = [37891, 11, 29297, 8984, 28578], Time = 417.16 seconds
# Iteration 36: Objective Value (LCOE) = 0.2538673549903271, Parameters = [20391, 28, 21797, 6484, 22078], Time = 428.93 seconds
# Iteration 37: Objective Value (LCOE) = 0.26284095913755545, Parameters = [24766, 15, 16172, 7109, 20453], Time = 440.26 seconds
# Iteration 38: Objective Value (LCOE) = 0.2847736139289985, Parameters = [42266, 32, 23672, 9609, 26953], Time = 451.95 seconds
# Iteration 39: Objective Value (LCOE) = 0.26907651295409807, Parameters = [33516, 24, 19922, 5859, 23703], Time = 463.48 seconds
# Iteration 40: Objective Value (LCOE) = 0.2424865681404558, Parameters = [16016, 41, 27422, 8359, 17203], Time = 475.54 seconds
# Iteration 41: Objective Value (LCOE) = 0.2959865066100665, Parameters = [18203, 13, 18984, 9922, 26141], Time = 487.33 seconds
# Iteration 42: Objective Value (LCOE) = 0.25931542264232504, Parameters = [35703, 30, 26484, 7422, 19641], Time = 499.41 seconds
# Iteration 43: Objective Value (LCOE) = 0.2755465368163128, Parameters = [44453, 21, 15234, 8672, 22891], Time = 511.28 seconds
# Iteration 44: Objective Value (LCOE) = 0.277931998967288, Parameters = [26953, 39, 22734, 6172, 29391], Time = 523.35 seconds
# Iteration 45: Objective Value (LCOE) = 0.2801866949195863, Parameters = [22578, 26, 28359, 5547, 27766], Time = 535.20 seconds
# Iteration 46: Objective Value (LCOE) = 0.26700145919562995, Parameters = [40078, 43, 20859, 8047, 21266], Time = 547.66 seconds
# Iteration 47: Objective Value (LCOE) = 0.2598440045961283, Parameters = [31328, 17, 24609, 6797, 18016], Time = 559.41 seconds
# Iteration 48: Objective Value (LCOE) = 0.25799316678682793, Parameters = [13828, 35, 17109, 9297, 24516], Time = 571.37 seconds
# Iteration 49: Objective Value (LCOE) = 0.27968268298242566, Parameters = [12734, 18, 26953, 5703, 22484], Time = 583.01 seconds
# Iteration 50: Objective Value (LCOE) = 0.2771794860801102, Parameters = [30234, 36, 19453, 8203, 28984], Time = 594.85 seconds
# Iteration 51: Objective Value (LCOE) = 0.2804497689463961, Parameters = [38984, 27, 23203, 6953, 25734], Time = 606.67 seconds
# Iteration 52: Objective Value (LCOE) = 0.24256947408142043, Parameters = [21484, 44, 15703, 9453, 19234], Time = 618.58 seconds
# Iteration 53: Objective Value (LCOE) = 0.24500756329534903, Parameters = [25859, 23, 21328, 8828, 17609], Time = 630.20 seconds
# Iteration 54: Objective Value (LCOE) = 0.2821089070790523, Parameters = [43359, 40, 28828, 6328, 24109], Time = 642.18 seconds
# Iteration 55: Objective Value (LCOE) = 0.2985622235504906, Parameters = [34609, 14, 17578, 7578, 27359], Time = 653.77 seconds
# Iteration 56: Objective Value (LCOE) = 0.25090792998517436, Parameters = [17109, 31, 25078, 5078, 20859], Time = 665.78 seconds
# Iteration 57: Objective Value (LCOE) = 0.28495199289524414, Parameters = [14922, 25, 18516, 6641, 29797], Time = 677.48 seconds
# Iteration 58: Objective Value (LCOE) = 0.26860264804543155, Parameters = [32422, 42, 26016, 9141, 23297], Time = 689.53 seconds
# Iteration 59: Objective Value (LCOE) = 0.2746376629126833, Parameters = [41172, 16, 22266, 5391, 20047], Time = 701.25 seconds
# Iteration 60: Objective Value (LCOE) = 0.27264188251148114, Parameters = [23672, 34, 29766, 7891, 26547], Time = 713.20 seconds
# Iteration 61: Objective Value (LCOE) = 0.2974047803863096, Parameters = [19297, 12, 24141, 8516, 24922], Time = 725.04 seconds
# Iteration 62: Objective Value (LCOE) = 0.24985303961932645, Parameters = [36797, 29, 16641, 6016, 18422], Time = 736.80 seconds
# Iteration 63: Objective Value (LCOE) = 0.2687565875018023, Parameters = [28047, 20, 27891, 9766, 21672], Time = 748.17 seconds
# Iteration 64: Objective Value (LCOE) = 0.2769496354192938, Parameters = [10547, 38, 20391, 7266, 28172], Time = 759.85 seconds
# Iteration 65: Objective Value (LCOE) = 0.2846464244154854, Parameters = [10820, 24, 27305, 9180, 25430], Time = 771.16 seconds
# Iteration 66: Objective Value (LCOE) = 0.24835998823487024, Parameters = [28320, 41, 19805, 6680, 18930], Time = 782.76 seconds
# Iteration 67: Objective Value (LCOE) = 0.28224243124871007, Parameters = [37070, 15, 23555, 7930, 22180], Time = 794.15 seconds
# Iteration 68: Objective Value (LCOE) = 0.26815551111915537, Parameters = [19570, 33, 16055, 5430, 28680], Time = 805.66 seconds
# Iteration 69: Objective Value (LCOE) = 0.3060843700083879, Parameters = [23945, 11, 21680, 6055, 27055], Time = 816.80 seconds
# Iteration 70: Objective Value (LCOE) = 0.2699523484716995, Parameters = [41445, 28, 29180, 8555, 20555], Time = 828.28 seconds
# Iteration 71: Objective Value (LCOE) = 0.2493337414174785, Parameters = [32695, 20, 17930, 7305, 17305], Time = 839.81 seconds
# Iteration 72: Objective Value (LCOE) = 0.2607354958529112, Parameters = [15195, 37, 25430, 9805, 23805], Time = 851.37 seconds
# Iteration 73: Objective Value (LCOE) = 0.25682693732258477, Parameters = [17383, 17, 16992, 8242, 19742], Time = 862.74 seconds
# Iteration 74: Objective Value (LCOE) = 0.2760002071216312, Parameters = [34883, 35, 24492, 5742, 26242], Time = 874.40 seconds
# Iteration 75: Objective Value (LCOE) = 0.29546557051913885, Parameters = [43633, 26, 20742, 9492, 29492], Time = 885.93 seconds
# Iteration 76: Objective Value (LCOE) = 0.26492706281437617, Parameters = [26133, 44, 28242, 6992, 22992], Time = 897.55 seconds
# Iteration 77: Objective Value (LCOE) = 0.25834314091430194, Parameters = [21758, 22, 22617, 6367, 21367], Time = 908.86 seconds
# Iteration 78: Objective Value (LCOE) = 0.27842804925920767, Parameters = [39258, 39, 15117, 8867, 27867], Time = 920.40 seconds
# Iteration 79: Objective Value (LCOE) = 0.29499881159050817, Parameters = [30508, 13, 26367, 5117, 24617], Time = 931.52 seconds
# Iteration 80: Objective Value (LCOE) = 0.23915897748932505, Parameters = [13008, 31, 18867, 7617, 18117], Time = 942.77 seconds
# Iteration 81: Objective Value (LCOE) = 0.3169367058381816, Parameters = [14102, 14, 24961, 7461, 29086], Time = 953.97 seconds
# Iteration 82: Objective Value (LCOE) = 0.25820361989193563, Parameters = [31602, 32, 17461, 9961, 22586], Time = 965.89 seconds
# Iteration 83: Objective Value (LCOE) = 0.26796759720826735, Parameters = [40352, 23, 28711, 6211, 19336], Time = 977.19 seconds
# Iteration 84: Objective Value (LCOE) = 0.2642794599383259, Parameters = [22852, 40, 21211, 8711, 25836], Time = 988.80 seconds
# Iteration 85: Objective Value (LCOE) = 0.2606411173508449, Parameters = [27227, 27, 15586, 8086, 24211], Time = 1000.07 seconds
# Iteration 86: Objective Value (LCOE) = 0.26520419452094907, Parameters = [44727, 45, 23086, 5586, 17711], Time = 1011.92 seconds
# Iteration 87: Objective Value (LCOE) = 0.2681825044305641, Parameters = [35977, 18, 19336, 9336, 20961], Time = 1023.11 seconds
# Iteration 88: Objective Value (LCOE) = 0.2720499744170273, Parameters = [18477, 36, 26836, 6836, 27461], Time = 1034.60 seconds
# Iteration 89: Objective Value (LCOE) = 0.2663813980869996, Parameters = [16289, 21, 20273, 5273, 23398], Time = 1045.86 seconds
# Iteration 90: Objective Value (LCOE) = 0.288073238576188, Parameters = [33789, 38, 27773, 7773, 29898], Time = 1057.60 seconds
# Iteration 91: Objective Value (LCOE) = 0.3071829604565514, Parameters = [42539, 12, 16523, 6523, 26648], Time = 1068.98 seconds
# Iteration 92: Objective Value (LCOE) = 0.2510720270513868, Parameters = [25039, 29, 24023, 9023, 20148], Time = 1080.35 seconds
# Iteration 93: Objective Value (LCOE) = 0.26152333394036925, Parameters = [20664, 16, 29648, 9648, 18523], Time = 1091.46 seconds
# Iteration 94: Objective Value (LCOE) = 0.2736503025078751, Parameters = [38164, 34, 22148, 7148, 25023], Time = 1102.96 seconds
# Iteration 95: Objective Value (LCOE) = 0.28545473583061287, Parameters = [29414, 25, 25898, 8398, 28273], Time = 1113.88 seconds
# Iteration 96: Objective Value (LCOE) = 0.2526323276445592, Parameters = [11914, 43, 18398, 5898, 21773], Time = 1125.42 seconds
# Iteration 97: Objective Value (LCOE) = 0.29558497590630634, Parameters = [11367, 15, 20977, 6758, 23602], Time = 1136.45 seconds
# Iteration 98: Objective Value (LCOE) = 0.2472989529391247, Parameters = [28867, 32, 28477, 9258, 17102], Time = 1147.80 seconds
# Iteration 99: Objective Value (LCOE) = 0.260544105996253, Parameters = [37617, 23, 17227, 5508, 20352], Time = 1159.28 seconds
# Iteration 100: Objective Value (LCOE) = 0.26867818486246764, Parameters = [20117, 41, 24727, 8008, 26852], Time = 1170.93 seconds
# Iteration 101: Objective Value (LCOE) = 0.2920833831204718, Parameters = [24492, 19, 26602, 8633, 28477], Time = 1182.34 seconds
# Iteration 102: Objective Value (LCOE) = 0.26720462734979433, Parameters = [41992, 37, 19102, 6133, 21977], Time = 1193.73 seconds
# Iteration 103: Objective Value (LCOE) = 0.27925687490245, Parameters = [33242, 10, 22852, 9883, 18727], Time = 1204.85 seconds
# Iteration 104: Objective Value (LCOE) = 0.2612249231507647, Parameters = [15742, 28, 15352, 7383, 25227], Time = 1216.11 seconds
# Iteration 105: Objective Value (LCOE) = 0.24267100231992578, Parameters = [17930, 26, 23789, 5820, 17914], Time = 1227.34 seconds
# Iteration 106: Objective Value (LCOE) = 0.2675565509441779, Parameters = [35430, 43, 16289, 8320, 24414], Time = 1239.02 seconds
# Iteration 107: Objective Value (LCOE) = 0.30692557184347985, Parameters = [44180, 17, 27539, 7070, 27664], Time = 1250.48 seconds
# Iteration 108: Objective Value (LCOE) = 0.2515119901064372, Parameters = [26680, 34, 20039, 9570, 21164], Time = 1262.09 seconds
# Iteration 109: Objective Value (LCOE) = 0.28251924199461553, Parameters = [22305, 12, 18164, 8945, 22789], Time = 1273.36 seconds
# Iteration 110: Objective Value (LCOE) = 0.291720693872673, Parameters = [39805, 30, 25664, 6445, 29289], Time = 1284.80 seconds
# Iteration 111: Objective Value (LCOE) = 0.28033006712205644, Parameters = [31055, 21, 21914, 7695, 26039], Time = 1296.20 seconds
# Iteration 112: Objective Value (LCOE) = 0.2513739156266507, Parameters = [13555, 39, 29414, 5195, 19539], Time = 1308.00 seconds
# Iteration 113: Objective Value (LCOE) = 0.2844566871177739, Parameters = [12461, 22, 16758, 9727, 27258], Time = 1319.44 seconds
# Iteration 114: Objective Value (LCOE) = 0.25748095030548096, Parameters = [29961, 40, 24258, 7227, 20758], Time = 1331.10 seconds
# Iteration 115: Objective Value (LCOE) = 0.26583898949898327, Parameters = [38711, 14, 20508, 8477, 17508], Time = 1342.21 seconds
# Iteration 116: Objective Value (LCOE) = 0.263181369353191, Parameters = [21211, 31, 28008, 5977, 24008], Time = 1353.69 seconds
# Iteration 117: Objective Value (LCOE) = 0.2837599617610124, Parameters = [25586, 18, 26133, 5352, 25633], Time = 1364.85 seconds
# Iteration 118: Objective Value (LCOE) = 0.25908672845508113, Parameters = [43086, 35, 18633, 7852, 19133], Time = 1376.39 seconds
# Iteration 119: Objective Value (LCOE) = 0.2705823043201304, Parameters = [34336, 27, 29883, 6602, 22383], Time = 1388.06 seconds
# Iteration 120: Objective Value (LCOE) = 0.2735414724180169, Parameters = [16836, 44, 22383, 9102, 28883], Time = 1399.81 seconds
# Iteration 121: Objective Value (LCOE) = 0.29678440164887326, Parameters = [14648, 11, 28945, 7539, 21570], Time = 1411.10 seconds
# Iteration 122: Objective Value (LCOE) = 0.2796270524343632, Parameters = [32148, 29, 21445, 5039, 28070], Time = 1422.63 seconds
# Iteration 123: Objective Value (LCOE) = 0.28754352298065544, Parameters = [40898, 20, 25195, 8789, 24820], Time = 1434.02 seconds
# Iteration 124: Objective Value (LCOE) = 0.24028187194181488, Parameters = [23398, 38, 17695, 6289, 18320], Time = 1445.72 seconds
# Iteration 125: Objective Value (LCOE) = 0.24812717351291008, Parameters = [19023, 24, 19570, 6914, 19945], Time = 1457.25 seconds
# Iteration 126: Objective Value (LCOE) = 0.28136542657650015, Parameters = [36523, 42, 27070, 9414, 26445], Time = 1469.16 seconds
# Iteration 127: Objective Value (LCOE) = 0.29688562566915117, Parameters = [27773, 16, 15820, 5664, 29695], Time = 1480.56 seconds
# Iteration 128: Objective Value (LCOE) = 0.26391690637813703, Parameters = [10273, 33, 23320, 8164, 23195], Time = 1492.41 seconds
# Generating sampling points
# Iteration 129: Objective Value (LCOE) = 0.2865474851996348, Parameters = [10205, 27, 25166, 6475, 27131], Time = 1503.76 seconds
# Iteration 130: Objective Value (LCOE) = 0.25280364084571694, Parameters = [27705, 45, 17666, 8975, 20631], Time = 1515.51 seconds
# Iteration 131: Objective Value (LCOE) = 0.26141379050589686, Parameters = [36455, 19, 28916, 5225, 17381], Time = 1526.82 seconds
# Iteration 132: Objective Value (LCOE) = 0.25720168520553743, Parameters = [18955, 36, 21416, 7725, 23881], Time = 1538.52 seconds
# Iteration 133: Objective Value (LCOE) = 0.2848312392667197, Parameters = [23330, 14, 15791, 8350, 25506], Time = 1549.63 seconds
# Iteration 134: Objective Value (LCOE) = 0.2596799638192436, Parameters = [40830, 32, 23291, 5850, 19006], Time = 1561.14 seconds
# Iteration 135: Objective Value (LCOE) = 0.26418555295687346, Parameters = [32080, 23, 19541, 9600, 22256], Time = 1572.88 seconds
# Iteration 136: Objective Value (LCOE) = 0.27761350981937566, Parameters = [14580, 41, 27041, 7100, 28756], Time = 1584.60 seconds
# Iteration 137: Objective Value (LCOE) = 0.26890323047529296, Parameters = [16768, 16, 20479, 6162, 21443], Time = 1596.04 seconds
# Iteration 138: Objective Value (LCOE) = 0.28303267856021674, Parameters = [34268, 34, 27979, 8662, 27943], Time = 1607.54 seconds
# Iteration 139: Objective Value (LCOE) = 0.2779515488648574, Parameters = [43018, 25, 16729, 7412, 24693], Time = 1618.96 seconds
# Iteration 140: Objective Value (LCOE) = 0.24815201300510306, Parameters = [25518, 43, 24229, 9912, 18193], Time = 1630.69 seconds
# Iteration 141: Objective Value (LCOE) = 0.2585064495057798, Parameters = [21143, 21, 29854, 9287, 19818], Time = 1642.18 seconds
# Iteration 142: Objective Value (LCOE) = 0.2786454797843397, Parameters = [38643, 38, 22354, 6787, 26318], Time = 1653.92 seconds
# Iteration 143: Objective Value (LCOE) = 0.31784566497898437, Parameters = [29893, 12, 26104, 8037, 29568], Time = 1665.06 seconds
# Iteration 144: Objective Value (LCOE) = 0.2579997969221873, Parameters = [12393, 30, 18604, 5537, 23068], Time = 1676.58 seconds
# Iteration 145: Objective Value (LCOE) = 0.31239074993156923, Parameters = [13486, 11, 27510, 9443, 24287], Time = 1687.75 seconds
# Iteration 146: Objective Value (LCOE) = 0.24536670360659554, Parameters = [30986, 29, 20010, 6943, 17787], Time = 1699.24 seconds
# Iteration 147: Objective Value (LCOE) = 0.27243852337688584, Parameters = [39736, 20, 23760, 8193, 21037], Time = 1710.41 seconds
# Iteration 148: Objective Value (LCOE) = 0.26529098761923514, Parameters = [22236, 37, 16260, 5693, 27537], Time = 1722.04 seconds
# Iteration 149: Objective Value (LCOE) = 0.2841876461039314, Parameters = [26611, 24, 21885, 5068, 29162], Time = 1733.62 seconds
# Iteration 150: Objective Value (LCOE) = 0.28028293439450996, Parameters = [44111, 42, 29385, 7568, 22662], Time = 1745.64 seconds
# Iteration 151: Objective Value (LCOE) = 0.26674998557306, Parameters = [35361, 15, 18135, 6318, 19412], Time = 1757.07 seconds
# Iteration 152: Objective Value (LCOE) = 0.2667804514706523, Parameters = [17861, 33, 25635, 8818, 25912], Time = 1768.72 seconds
# Iteration 153: Objective Value (LCOE) = 0.2454644828860733, Parameters = [15674, 22, 17197, 7881, 18600], Time = 1780.07 seconds
# Iteration 154: Objective Value (LCOE) = 0.272230051922694, Parameters = [33174, 39, 24697, 5381, 25100], Time = 1791.52 seconds
# Iteration 155: Objective Value (LCOE) = 0.3128653892008987, Parameters = [41924, 13, 20947, 9131, 28350], Time = 1802.76 seconds
# Iteration 156: Objective Value (LCOE) = 0.2583968259783115, Parameters = [24424, 31, 28447, 6631, 21850], Time = 1814.14 seconds
# Iteration 157: Objective Value (LCOE) = 0.27216853289237786, Parameters = [20049, 18, 22822, 7256, 23475], Time = 1825.53 seconds
# Iteration 158: Objective Value (LCOE) = 0.2822839599910118, Parameters = [37549, 35, 15322, 9756, 29975], Time = 1836.94 seconds
# Iteration 159: Objective Value (LCOE) = 0.2790103014333013, Parameters = [28799, 26, 26572, 6006, 26725], Time = 1848.35 seconds
# Iteration 160: Objective Value (LCOE) = 0.249292980139651, Parameters = [11299, 44, 19072, 8506, 20225], Time = 1860.24 seconds
# Iteration 161: Objective Value (LCOE) = 0.301490160290102, Parameters = [11846, 18, 16494, 8896, 28553], Time = 1871.82 seconds
# Iteration 162: Objective Value (LCOE) = 0.25965768491524366, Parameters = [29346, 36, 23994, 6396, 22053], Time = 1883.58 seconds
# Iteration 163: Objective Value (LCOE) = 0.2554752261335076, Parameters = [38096, 27, 20244, 7646, 18803], Time = 1894.93 seconds
# Iteration 164: Objective Value (LCOE) = 0.26733214095898133, Parameters = [20596, 44, 27744, 5146, 25303], Time = 1906.81 seconds
# Iteration 165: Objective Value (LCOE) = 0.2687782396538294, Parameters = [24971, 23, 25869, 5771, 23678], Time = 1918.18 seconds
# Iteration 166: Objective Value (LCOE) = 0.25510928414107875, Parameters = [42471, 40, 18369, 8271, 17178], Time = 1929.86 seconds
# Iteration 167: Objective Value (LCOE) = 0.2799347954691235, Parameters = [33721, 14, 29619, 7021, 20428], Time = 1941.11 seconds
# Iteration 168: Objective Value (LCOE) = 0.26920871467038054, Parameters = [16221, 31, 22119, 9521, 26928], Time = 1952.65 seconds
# Iteration 169: Objective Value (LCOE) = 0.26483803432943986, Parameters = [18408, 25, 28682, 8584, 22865], Time = 1963.92 seconds
# Iteration 170: Objective Value (LCOE) = 0.28434204321124723, Parameters = [35908, 42, 21182, 6084, 29365], Time = 1975.73 seconds
# Iteration 171: Objective Value (LCOE) = 0.30174509054126825, Parameters = [44658, 16, 24932, 9834, 26115], Time = 1987.33 seconds
# Iteration 172: Objective Value (LCOE) = 0.24527900392456417, Parameters = [27158, 33, 17432, 7334, 19615], Time = 1999.27 seconds
# Iteration 173: Objective Value (LCOE) = 0.2632536687875032, Parameters = [22783, 12, 19307, 6709, 17990], Time = 2010.63 seconds
# Iteration 174: Objective Value (LCOE) = 0.2790304583602185, Parameters = [40283, 29, 26807, 9209, 24490], Time = 2022.12 seconds
# Iteration 175: Objective Value (LCOE) = 0.2838499327188717, Parameters = [31533, 20, 15557, 5459, 27740], Time = 2033.48 seconds
# Iteration 176: Objective Value (LCOE) = 0.25180311438851555, Parameters = [14033, 38, 23057, 7959, 21240], Time = 2045.16 seconds
# Iteration 177: Objective Value (LCOE) = 0.2858346560472453, Parameters = [12939, 19, 20713, 7178, 25709], Time = 2056.43 seconds
# Iteration 178: Objective Value (LCOE) = 0.2554914212153555, Parameters = [30439, 37, 28213, 9678, 19209], Time = 2068.20 seconds
# Iteration 179: Objective Value (LCOE) = 0.29415413594398343, Parameters = [39189, 10, 16963, 5928, 22459], Time = 2079.46 seconds
# Iteration 180: Objective Value (LCOE) = 0.2788424184672759, Parameters = [21689, 28, 24463, 8428, 28959], Time = 2091.02 seconds
# Iteration 181: Objective Value (LCOE) = 0.29744239119314103, Parameters = [26064, 15, 26338, 7803, 27334], Time = 2102.23 seconds
# Iteration 182: Objective Value (LCOE) = 0.26449412279399714, Parameters = [43564, 32, 18838, 5303, 20834], Time = 2113.53 seconds
# Iteration 183: Objective Value (LCOE) = 0.2517584264005837, Parameters = [34814, 24, 22588, 9053, 17584], Time = 2124.75 seconds
# Iteration 184: Objective Value (LCOE) = 0.25377692160584187, Parameters = [17314, 41, 15088, 6553, 24084], Time = 2136.50 seconds
# Iteration 185: Objective Value (LCOE) = 0.2764951781338919, Parameters = [15127, 13, 23525, 5615, 20021], Time = 2147.92 seconds
# Iteration 186: Objective Value (LCOE) = 0.2704493688899761, Parameters = [32627, 30, 16025, 8115, 26521], Time = 2159.49 seconds
# Iteration 187: Objective Value (LCOE) = 0.30487380016834476, Parameters = [41377, 21, 27275, 6865, 29771], Time = 2171.05 seconds
# Iteration 188: Objective Value (LCOE) = 0.2564103026213758, Parameters = [23877, 39, 19775, 9365, 23271], Time = 2182.75 seconds
# Iteration 189: Objective Value (LCOE) = 0.25132132483699193, Parameters = [19502, 26, 17900, 9990, 21646], Time = 2194.32 seconds
# Iteration 190: Objective Value (LCOE) = 0.28534848386516604, Parameters = [37002, 43, 25400, 7490, 28146], Time = 2206.07 seconds
# Iteration 191: Objective Value (LCOE) = 0.28134531550977454, Parameters = [28252, 17, 21650, 8740, 24896], Time = 2217.50 seconds
# Iteration 192: Objective Value (LCOE) = 0.2497930385411969, Parameters = [10752, 35, 29150, 6240, 18396], Time = 2228.95 seconds
# Iteration 193: Objective Value (LCOE) = 0.299409276929981, Parameters = [11025, 13, 22471, 8076, 21951], Time = 2240.30 seconds
# Iteration 194: Objective Value (LCOE) = 0.28296503855138394, Parameters = [28525, 31, 29971, 5576, 28451], Time = 2251.80 seconds
# Iteration 195: Objective Value (LCOE) = 0.27893157881708447, Parameters = [37275, 22, 18721, 9326, 25201], Time = 2263.35 seconds
# Iteration 196: Objective Value (LCOE) = 0.24608520023638442, Parameters = [19775, 40, 26221, 6826, 18701], Time = 2275.03 seconds
# Iteration 197: Objective Value (LCOE) = 0.24412262279091845, Parameters = [24150, 27, 28096, 7451, 17076], Time = 2286.27 seconds
# Iteration 198: Objective Value (LCOE) = 0.2748661420465192, Parameters = [41650, 44, 20596, 9951, 23576], Time = 2297.98 seconds
# Iteration 199: Objective Value (LCOE) = 0.29092418848378226, Parameters = [32900, 18, 24346, 6201, 26826], Time = 2309.35 seconds
# Iteration 200: Objective Value (LCOE) = 0.24320559928602134, Parameters = [15400, 35, 16846, 8701, 20326], Time = 2321.12 seconds
# Iteration 201: Objective Value (LCOE) = 0.29237711652139975, Parameters = [17588, 20, 23408, 9639, 29264], Time = 2332.42 seconds
# Iteration 202: Objective Value (LCOE) = 0.26084000908943533, Parameters = [35088, 38, 15908, 7139, 22764], Time = 2344.14 seconds
# Iteration 203: Objective Value (LCOE) = 0.29047731633320845, Parameters = [43838, 11, 27158, 8389, 19514], Time = 2355.16 seconds
# Iteration 204: Objective Value (LCOE) = 0.2676202436714651, Parameters = [26338, 29, 19658, 5889, 26014], Time = 2366.48 seconds
# Iteration 205: Objective Value (LCOE) = 0.2761273854368975, Parameters = [21963, 16, 17783, 5264, 24389], Time = 2377.85 seconds
# Iteration 206: Objective Value (LCOE) = 0.2563616631193605, Parameters = [39463, 33, 25283, 7764, 17889], Time = 2389.68 seconds
# Iteration 207: Objective Value (LCOE) = 0.25960416601965325, Parameters = [30713, 24, 21533, 6514, 21139], Time = 2401.49 seconds
# Iteration 208: Objective Value (LCOE) = 0.2768856840566201, Parameters = [13213, 42, 29033, 9014, 27639], Time = 2413.33 seconds
# Iteration 209: Objective Value (LCOE) = 0.24581173719220895, Parameters = [14307, 23, 15439, 6045, 19107], Time = 2424.83 seconds
# Iteration 210: Objective Value (LCOE) = 0.27175795782946166, Parameters = [31807, 41, 22939, 8545, 25607], Time = 2436.54 seconds
# Iteration 211: Objective Value (LCOE) = 0.30671498131246855, Parameters = [40557, 15, 19189, 7295, 28857], Time = 2447.58 seconds
# Iteration 212: Objective Value (LCOE) = 0.2580215292587573, Parameters = [23057, 32, 26689, 9795, 22357], Time = 2458.87 seconds
# Iteration 213: Objective Value (LCOE) = 0.28603325256139356, Parameters = [27432, 10, 24814, 9170, 20732], Time = 2469.60 seconds
# Iteration 214: Objective Value (LCOE) = 0.2853634009752996, Parameters = [44932, 28, 17314, 6670, 27232], Time = 2480.61 seconds
# Iteration 215: Objective Value (LCOE) = 0.28427782511249783, Parameters = [36182, 19, 28564, 7920, 23982], Time = 2491.80 seconds
# Iteration 216: Objective Value (LCOE) = 0.237415431617172, Parameters = [18682, 36, 21064, 5420, 17482], Time = 2503.50 seconds
# Iteration 217: Objective Value (LCOE) = 0.29378186804739975, Parameters = [16494, 17, 29502, 6357, 26420], Time = 2514.90 seconds
# Iteration 218: Objective Value (LCOE) = 0.2550987876735188, Parameters = [33994, 34, 22002, 8857, 19920], Time = 2526.47 seconds
# Iteration 219: Objective Value (LCOE) = 0.27814818156325904, Parameters = [42744, 26, 25752, 5107, 23170], Time = 2538.02 seconds
# Iteration 220: Objective Value (LCOE) = 0.2747701832680676, Parameters = [25244, 43, 18252, 7607, 29670], Time = 2549.92 seconds
# Iteration 221: Objective Value (LCOE) = 0.2815060407521382, Parameters = [20869, 21, 20127, 8232, 28045], Time = 2561.70 seconds
# Iteration 222: Objective Value (LCOE) = 0.2693636837497967, Parameters = [38369, 39, 27627, 5732, 21545], Time = 2573.21 seconds
# Iteration 223: Objective Value (LCOE) = 0.2651009686536888, Parameters = [29619, 12, 16377, 9482, 18295], Time = 2584.10 seconds
# Iteration 224: Objective Value (LCOE) = 0.2683826429120864, Parameters = [12119, 30, 23877, 6982, 24795], Time = 2595.29 seconds
# Iteration 225: Objective Value (LCOE) = 0.26446113874100763, Parameters = [11572, 23, 26924, 5342, 20529], Time = 2606.68 seconds
# Iteration 226: Objective Value (LCOE) = 0.2705964814907558, Parameters = [29072, 40, 19424, 7842, 27029], Time = 2618.20 seconds
# Iteration 227: Objective Value (LCOE) = 0.2908619524787265, Parameters = [37822, 14, 23174, 6592, 23779], Time = 2629.53 seconds
# Iteration 228: Objective Value (LCOE) = 0.2326643661181077, Parameters = [20322, 32, 15674, 9092, 17279], Time = 2641.21 seconds
# Iteration 229: Objective Value (LCOE) = 0.25478945159710176, Parameters = [24697, 18, 21299, 9717, 18904], Time = 2652.94 seconds
# Iteration 230: Objective Value (LCOE) = 0.28374327872380756, Parameters = [42197, 36, 28799, 7217, 25404], Time = 2664.67 seconds
# Iteration 231: Objective Value (LCOE) = 0.281078953511191, Parameters = [33447, 27, 17549, 8467, 28654], Time = 2676.25 seconds
# Iteration 232: Objective Value (LCOE) = 0.25665086910525226, Parameters = [15947, 45, 25049, 5967, 22154], Time = 2688.05 seconds
# Iteration 233: Objective Value (LCOE) = 0.3074125487167886, Parameters = [18135, 12, 18486, 6904, 27842], Time = 2699.47 seconds
# Iteration 234: Objective Value (LCOE) = 0.26462379898269434, Parameters = [35635, 29, 25986, 9404, 21342], Time = 2710.85 seconds
# Iteration 235: Objective Value (LCOE) = 0.26423922286530344, Parameters = [44385, 21, 22236, 5654, 18092], Time = 2722.29 seconds
# Iteration 236: Objective Value (LCOE) = 0.26933417093795575, Parameters = [26885, 38, 29736, 8154, 24592], Time = 2733.72 seconds
# Iteration 237: Objective Value (LCOE) = 0.2733634511454685, Parameters = [22510, 25, 24111, 7529, 26217], Time = 2745.17 seconds
# Iteration 238: Objective Value (LCOE) = 0.25929760019273435, Parameters = [40010, 42, 16611, 5029, 19717], Time = 2757.42 seconds
# Iteration 239: Objective Value (LCOE) = 0.2821529568442303, Parameters = [31260, 16, 27861, 8779, 22967], Time = 2768.82 seconds
# Iteration 240: Objective Value (LCOE) = 0.27712493281830647, Parameters = [13760, 34, 20361, 6279, 29467], Time = 2780.50 seconds
# Iteration 241: Objective Value (LCOE) = 0.26627820453786527, Parameters = [12666, 15, 25518, 8623, 17686], Time = 2792.03 seconds
# Iteration 242: Objective Value (LCOE) = 0.2617752867065413, Parameters = [30166, 33, 18018, 6123, 24186], Time = 2803.59 seconds
# Iteration 243: Objective Value (LCOE) = 0.29268603263794796, Parameters = [38916, 24, 29268, 9873, 27436], Time = 2815.23 seconds
# Iteration 244: Objective Value (LCOE) = 0.2503254428934457, Parameters = [21416, 41, 21768, 7373, 20936], Time = 2826.93 seconds
# Iteration 245: Objective Value (LCOE) = 0.262139802464071, Parameters = [25791, 20, 16143, 6748, 22561], Time = 2838.39 seconds
# Iteration 246: Objective Value (LCOE) = 0.2913083126836234, Parameters = [43291, 37, 23643, 9248, 29061], Time = 2849.99 seconds
# Iteration 247: Objective Value (LCOE) = 0.30371532126956885, Parameters = [34541, 11, 19893, 5498, 25811], Time = 2861.40 seconds
# Iteration 248: Objective Value (LCOE) = 0.24880303392235534, Parameters = [17041, 28, 27393, 7998, 19311], Time = 2873.07 seconds
# Iteration 249: Objective Value (LCOE) = 0.26594582628388963, Parameters = [14854, 26, 18955, 8936, 24998], Time = 2884.59 seconds
# Iteration 250: Objective Value (LCOE) = 0.25714600311066893, Parameters = [32354, 44, 26455, 6436, 18498], Time = 2896.61 seconds
# Iteration 251: Objective Value (LCOE) = 0.2741480254643748, Parameters = [41104, 17, 15205, 7686, 21748], Time = 2907.99 seconds
# Iteration 252: Objective Value (LCOE) = 0.2724783956962246, Parameters = [23604, 35, 22705, 5186, 28248], Time = 2919.75 seconds
# Iteration 253: Objective Value (LCOE) = 0.31722687685860956, Parameters = [19229, 13, 28330, 5811, 29873], Time = 2931.01 seconds
# Iteration 254: Objective Value (LCOE) = 0.26757275706426553, Parameters = [36729, 30, 20830, 8311, 23373], Time = 2942.61 seconds
# Iteration 255: Objective Value (LCOE) = 0.25887424770344203, Parameters = [27979, 22, 24580, 7061, 20123], Time = 2954.42 seconds
# Iteration 256: Objective Value (LCOE) = 0.26937001512584957, Parameters = [10479, 39, 17080, 9561, 26623], Time = 2966.06 seconds
# Generating sampling points
# Iteration 257: Objective Value (LCOE) = 0.31754906075836564, Parameters = [10513, 13, 26206, 8999, 24427], Time = 2977.37 seconds
# Iteration 258: Objective Value (LCOE) = 0.242111392762415, Parameters = [28013, 30, 18706, 6499, 17927], Time = 2989.36 seconds
# Iteration 259: Objective Value (LCOE) = 0.2729472382538554, Parameters = [36763, 22, 29956, 7749, 21177], Time = 3000.81 seconds
# Iteration 260: Objective Value (LCOE) = 0.2693274070859083, Parameters = [19263, 39, 22456, 5249, 27677], Time = 3012.64 seconds
# Iteration 261: Objective Value (LCOE) = 0.27753221479696133, Parameters = [23638, 26, 16831, 5874, 29302], Time = 3024.10 seconds
# Iteration 262: Objective Value (LCOE) = 0.2750410243421197, Parameters = [41138, 44, 24331, 8374, 22802], Time = 3035.72 seconds
# Iteration 263: Objective Value (LCOE) = 0.2634359679841616, Parameters = [32388, 17, 20581, 7124, 19552], Time = 3047.05 seconds
# Iteration 264: Objective Value (LCOE) = 0.2699911784633544, Parameters = [14888, 35, 28081, 9624, 26052], Time = 3058.54 seconds
# Iteration 265: Objective Value (LCOE) = 0.2446105763738144, Parameters = [17075, 19, 19644, 8687, 17114], Time = 3069.91 seconds
# Iteration 266: Objective Value (LCOE) = 0.2706247060587722, Parameters = [34575, 37, 27144, 6187, 23614], Time = 3081.44 seconds
# Iteration 267: Objective Value (LCOE) = 0.3109557311049616, Parameters = [43325, 11, 15894, 9937, 26864], Time = 3092.73 seconds
# Iteration 268: Objective Value (LCOE) = 0.25222478156789413, Parameters = [25825, 28, 23394, 7437, 20364], Time = 3104.62 seconds
# Iteration 269: Objective Value (LCOE) = 0.2774235763831307, Parameters = [21450, 15, 29019, 6812, 21989], Time = 3115.87 seconds
# Iteration 270: Objective Value (LCOE) = 0.2841944299430077, Parameters = [38950, 33, 21519, 9312, 28489], Time = 3127.43 seconds
# Iteration 271: Objective Value (LCOE) = 0.2757634447310789, Parameters = [30200, 24, 25269, 5562, 25239], Time = 3139.30 seconds
# Iteration 272: Objective Value (LCOE) = 0.24137276643959638, Parameters = [12700, 41, 17769, 8062, 18739], Time = 3151.08 seconds
# Iteration 273: Objective Value (LCOE) = 0.28596592421340544, Parameters = [13794, 25, 26675, 6968, 28083], Time = 3162.47 seconds
# Iteration 274: Objective Value (LCOE) = 0.2580886502587625, Parameters = [31294, 42, 19175, 9468, 21583], Time = 3174.02 seconds
# Iteration 275: Objective Value (LCOE) = 0.26784900498649855, Parameters = [40044, 16, 22925, 5718, 18333], Time = 3185.11 seconds
# Iteration 276: Objective Value (LCOE) = 0.2565633830962577, Parameters = [22544, 34, 15425, 8218, 24833], Time = 3196.58 seconds
# Iteration 277: Objective Value (LCOE) = 0.3004549196217165, Parameters = [26919, 12, 21050, 7593, 26458], Time = 3208.11 seconds
# Iteration 278: Objective Value (LCOE) = 0.2703081167927573, Parameters = [44419, 29, 28550, 5093, 19958], Time = 3219.67 seconds
# Iteration 279: Objective Value (LCOE) = 0.2703797287582326, Parameters = [35669, 21, 17300, 8843, 23208], Time = 3231.08 seconds
# Iteration 280: Objective Value (LCOE) = 0.27719186353355885, Parameters = [18169, 38, 24800, 6343, 29708], Time = 3242.90 seconds
# Iteration 281: Objective Value (LCOE) = 0.2607615752149444, Parameters = [15981, 18, 18237, 5405, 20771], Time = 3254.55 seconds
# Iteration 282: Objective Value (LCOE) = 0.27903233124555704, Parameters = [33481, 36, 25737, 7905, 27271], Time = 3266.40 seconds
# Iteration 283: Objective Value (LCOE) = 0.27698130473283444, Parameters = [42231, 27, 21987, 6655, 24021], Time = 3278.10 seconds
# Iteration 284: Objective Value (LCOE) = 0.2505861980899629, Parameters = [24731, 45, 29487, 9155, 17521], Time = 3289.75 seconds
# Iteration 285: Objective Value (LCOE) = 0.24955591595980425, Parameters = [20356, 23, 23862, 9780, 19146], Time = 3301.21 seconds
# Iteration 286: Objective Value (LCOE) = 0.2721392942848446, Parameters = [37856, 40, 16362, 7280, 25646], Time = 3313.22 seconds
# Iteration 287: Objective Value (LCOE) = 0.30867191375339287, Parameters = [29106, 14, 27612, 8530, 28896], Time = 3325.26 seconds
# Iteration 288: Objective Value (LCOE) = 0.25725634451358836, Parameters = [11606, 31, 20112, 6030, 22396], Time = 3336.90 seconds
# Iteration 289: Objective Value (LCOE) = 0.2816944740772986, Parameters = [12153, 21, 15659, 6265, 26255], Time = 3348.34 seconds
# Iteration 290: Objective Value (LCOE) = 0.25345429128065394, Parameters = [29653, 39, 23159, 8765, 19755], Time = 3360.23 seconds
# Iteration 291: Objective Value (LCOE) = 0.2918154172510918, Parameters = [38403, 12, 19409, 5015, 23005], Time = 3371.56 seconds
# Iteration 292: Objective Value (LCOE) = 0.2803599647739854, Parameters = [20903, 30, 26909, 7515, 29505], Time = 3383.24 seconds
# Iteration 293: Objective Value (LCOE) = 0.2934323759552819, Parameters = [25278, 17, 25034, 8140, 27880], Time = 3394.75 seconds
# Iteration 294: Objective Value (LCOE) = 0.26418567482940253, Parameters = [42778, 34, 17534, 5640, 21380], Time = 3406.64 seconds
# Iteration 295: Objective Value (LCOE) = 0.25725824894351546, Parameters = [34028, 25, 28784, 9390, 18130], Time = 3418.02 seconds
# Iteration 296: Objective Value (LCOE) = 0.26051331581282394, Parameters = [16528, 43, 21284, 6890, 24630], Time = 3429.89 seconds
# Iteration 297: Objective Value (LCOE) = 0.2823926861031605, Parameters = [18716, 10, 29722, 5952, 18942], Time = 3441.36 seconds
# Iteration 298: Objective Value (LCOE) = 0.27567152665191524, Parameters = [36216, 28, 22222, 8452, 25442], Time = 3453.14 seconds
# Iteration 299: Objective Value (LCOE) = 0.3064312543036787, Parameters = [44966, 19, 25972, 7202, 28692], Time = 3464.61 seconds
# Iteration 300: Objective Value (LCOE) = 0.2545296125364503, Parameters = [27466, 36, 18472, 9702, 22192], Time = 3476.23 seconds
# Iteration 301: Objective Value (LCOE) = 0.2531606730733248, Parameters = [23091, 23, 20347, 9077, 20567], Time = 3487.61 seconds
# Iteration 302: Objective Value (LCOE) = 0.28702094715659443, Parameters = [40591, 41, 27847, 6577, 27067], Time = 3499.20 seconds
# Iteration 303: Objective Value (LCOE) = 0.2801507631401875, Parameters = [31841, 15, 16597, 7827, 23817], Time = 3510.50 seconds
# Iteration 304: Objective Value (LCOE) = 0.23934795768429007, Parameters = [14341, 32, 24097, 5327, 17317], Time = 3521.91 seconds
# Iteration 305: Objective Value (LCOE) = 0.31294698646439545, Parameters = [13247, 16, 21753, 9546, 29911], Time = 3533.31 seconds
# Iteration 306: Objective Value (LCOE) = 0.2679585395509105, Parameters = [30747, 33, 29253, 7046, 23411], Time = 3545.35 seconds
# Iteration 307: Objective Value (LCOE) = 0.26116339369974123, Parameters = [39497, 24, 18003, 8296, 20161], Time = 3556.75 seconds
# Iteration 308: Objective Value (LCOE) = 0.26957657945263247, Parameters = [21997, 42, 25503, 5796, 26661], Time = 3568.64 seconds
# Iteration 309: Objective Value (LCOE) = 0.27947562232946355, Parameters = [26372, 20, 27378, 5171, 25036], Time = 3580.17 seconds
# Iteration 310: Objective Value (LCOE) = 0.2604261343438855, Parameters = [43872, 38, 19878, 7671, 18536], Time = 3591.80 seconds
# Iteration 311: Objective Value (LCOE) = 0.29045490727432843, Parameters = [35122, 11, 23628, 6421, 21786], Time = 3603.36 seconds
# Iteration 312: Objective Value (LCOE) = 0.2704783487642529, Parameters = [17622, 29, 16128, 8921, 28286], Time = 3615.19 seconds
# Iteration 313: Objective Value (LCOE) = 0.2584613725884945, Parameters = [15435, 27, 22690, 7983, 22599], Time = 3626.84 seconds
# Iteration 314: Objective Value (LCOE) = 0.27747205560780996, Parameters = [32935, 44, 15190, 5483, 29099], Time = 3638.53 seconds
# Iteration 315: Objective Value (LCOE) = 0.29573562128012054, Parameters = [41685, 18, 26440, 9233, 25849], Time = 3649.81 seconds
# Iteration 316: Objective Value (LCOE) = 0.24359820223030829, Parameters = [24185, 35, 18940, 6733, 19349], Time = 3661.38 seconds
# Iteration 317: Objective Value (LCOE) = 0.25738778693172243, Parameters = [19810, 13, 17065, 7358, 17724], Time = 3672.51 seconds
# Iteration 318: Objective Value (LCOE) = 0.27284699643201654, Parameters = [37310, 31, 24565, 9858, 24224], Time = 3683.93 seconds
# Iteration 319: Objective Value (LCOE) = 0.28222771998242585, Parameters = [28560, 22, 20815, 6108, 27474], Time = 3695.12 seconds
# Iteration 320: Objective Value (LCOE) = 0.2573632905983477, Parameters = [11060, 40, 28315, 8608, 20974], Time = 3706.89 seconds
# Iteration 321: Objective Value (LCOE) = 0.25445656702607267, Parameters = [10786, 26, 21401, 5522, 19653], Time = 3718.83 seconds
# Iteration 322: Objective Value (LCOE) = 0.27530554781766925, Parameters = [28286, 43, 28901, 8022, 26153], Time = 3730.66 seconds
# Iteration 323: Objective Value (LCOE) = 0.3001883774765386, Parameters = [37036, 17, 17651, 6772, 29403], Time = 3741.94 seconds
# Iteration 324: Objective Value (LCOE) = 0.2564996875647326, Parameters = [19536, 35, 25151, 9272, 22903], Time = 3753.60 seconds
# Iteration 325: Objective Value (LCOE) = 0.27924647293424476, Parameters = [23911, 13, 27026, 9897, 21278], Time = 3764.77 seconds
# Iteration 326: Objective Value (LCOE) = 0.2841187114852712, Parameters = [41411, 30, 19526, 7397, 27778], Time = 3776.28 seconds
# Iteration 327: Objective Value (LCOE) = 0.27700494396048747, Parameters = [32661, 21, 23276, 8647, 24528], Time = 3787.65 seconds
# Iteration 328: Objective Value (LCOE) = 0.23618537753639474, Parameters = [15161, 39, 15776, 6147, 18028], Time = 3799.45 seconds
# Iteration 329: Objective Value (LCOE) = 0.290267349395237, Parameters = [17349, 15, 24214, 7085, 25341], Time = 3810.70 seconds
# Iteration 330: Objective Value (LCOE) = 0.24903733201260614, Parameters = [34849, 32, 16714, 9585, 18841], Time = 3822.23 seconds
# Iteration 331: Objective Value (LCOE) = 0.2783000424394052, Parameters = [43599, 24, 27964, 5835, 22091], Time = 3833.33 seconds
# Iteration 332: Objective Value (LCOE) = 0.2735559746163049, Parameters = [26099, 41, 20464, 8335, 28591], Time = 3844.73 seconds
# Iteration 333: Objective Value (LCOE) = 0.2802788651254878, Parameters = [21724, 19, 18589, 7710, 26966], Time = 3855.75 seconds
# Iteration 334: Objective Value (LCOE) = 0.2653539675573151, Parameters = [39224, 37, 26089, 5210, 20466], Time = 3866.84 seconds
# Iteration 335: Objective Value (LCOE) = 0.2710285162006171, Parameters = [30474, 10, 22339, 8960, 17216], Time = 3877.68 seconds
# Iteration 336: Objective Value (LCOE) = 0.2691767409393621, Parameters = [12974, 28, 29839, 6460, 23716], Time = 3888.63 seconds
# Iteration 337: Objective Value (LCOE) = 0.2939680745566922, Parameters = [14067, 12, 16245, 8491, 23310], Time = 3899.47 seconds
# Iteration 338: Objective Value (LCOE) = 0.28631401583533417, Parameters = [31567, 29, 23745, 5991, 29810], Time = 3910.37 seconds
# Iteration 339: Objective Value (LCOE) = 0.28937271884216476, Parameters = [40317, 20, 19995, 9741, 26560], Time = 3921.28 seconds
# Iteration 340: Objective Value (LCOE) = 0.2519522509765766, Parameters = [22817, 38, 27495, 7241, 20060], Time = 3932.39 seconds
# Iteration 341: Objective Value (LCOE) = 0.25067666592687593, Parameters = [27192, 25, 25620, 6616, 18435], Time = 3943.47 seconds
# Iteration 342: Objective Value (LCOE) = 0.2787124557284245, Parameters = [44692, 42, 18120, 9116, 24935], Time = 3954.72 seconds
# Iteration 343: Objective Value (LCOE) = 0.3053850479687649, Parameters = [35942, 16, 29370, 5366, 28185], Time = 3965.78 seconds
# Iteration 344: Objective Value (LCOE) = 0.2505286670499001, Parameters = [18442, 33, 21870, 7866, 21685], Time = 3977.37 seconds
# Iteration 345: Objective Value (LCOE) = 0.29273732636518257, Parameters = [16255, 22, 28433, 8804, 28997], Time = 3989.34 seconds
# Iteration 346: Objective Value (LCOE) = 0.26308664914672397, Parameters = [33755, 40, 20933, 6304, 22497], Time = 4001.26 seconds
# Iteration 347: Objective Value (LCOE) = 0.2785902730458727, Parameters = [42505, 14, 24683, 7554, 19247], Time = 4012.83 seconds
# Iteration 348: Objective Value (LCOE) = 0.2627758557093456, Parameters = [25005, 31, 17183, 5054, 25747], Time = 4024.32 seconds
# Iteration 349: Objective Value (LCOE) = 0.2717372672291462, Parameters = [20630, 18, 19058, 5679, 24122], Time = 4035.66 seconds
# Iteration 350: Objective Value (LCOE) = 0.2562345895229068, Parameters = [38130, 36, 26558, 8179, 17622], Time = 4047.64 seconds
# Iteration 351: Objective Value (LCOE) = 0.25128096784782783, Parameters = [29380, 27, 15308, 6929, 20872], Time = 4059.20 seconds
# Iteration 352: Objective Value (LCOE) = 0.27316351988555554, Parameters = [11880, 44, 22808, 9429, 27372], Time = 4071.26 seconds
# Iteration 353: Objective Value (LCOE) = 0.2641041037846897, Parameters = [11333, 18, 27729, 7944, 17825], Time = 4083.02 seconds
# Iteration 354: Objective Value (LCOE) = 0.26263637947854707, Parameters = [28833, 35, 20229, 5444, 24325], Time = 4095.29 seconds
# Iteration 355: Objective Value (LCOE) = 0.2864052523902051, Parameters = [37583, 26, 23979, 9194, 27575], Time = 4107.17 seconds
# Iteration 356: Objective Value (LCOE) = 0.24755385981842837, Parameters = [20083, 44, 16479, 6694, 21075], Time = 4119.33 seconds
# Iteration 357: Objective Value (LCOE) = 0.2639166411395996, Parameters = [24458, 22, 22104, 7319, 22700], Time = 4131.22 seconds
# Iteration 358: Objective Value (LCOE) = 0.29506170922819125, Parameters = [41958, 39, 29604, 9819, 29200], Time = 4143.17 seconds
# Iteration 359: Objective Value (LCOE) = 0.2959375963406549, Parameters = [33208, 13, 18354, 6069, 25950], Time = 4154.91 seconds
# Iteration 360: Objective Value (LCOE) = 0.2472083547016707, Parameters = [15708, 31, 25854, 8569, 19450], Time = 4166.67 seconds
# Iteration 361: Objective Value (LCOE) = 0.25968744268683847, Parameters = [17896, 24, 17417, 9507, 23513], Time = 4178.52 seconds
# Iteration 362: Objective Value (LCOE) = 0.25368321674533706, Parameters = [35396, 42, 24917, 7007, 17013], Time = 4190.45 seconds
# Iteration 363: Objective Value (LCOE) = 0.27931942888985806, Parameters = [44146, 15, 21167, 8257, 20263], Time = 4202.06 seconds
# Iteration 364: Objective Value (LCOE) = 0.2745685155397136, Parameters = [26646, 33, 28667, 5757, 26763], Time = 4214.19 seconds
# Iteration 365: Objective Value (LCOE) = 0.3129879087539144, Parameters = [22271, 11, 23042, 5132, 28388], Time = 4226.09 seconds
# ...
# Iteration 458: Objective Value (LCOE) = 0.2540923325420369, Parameters = [35054, 29, 29751, 7817, 17241], Time = 5322.25 seconds
# Iteration 459: Objective Value (LCOE) = 0.2703664060088802, Parameters = [43804, 20, 18501, 6567, 20491], Time = 5333.78 seconds
# Iteration 460: Objective Value (LCOE) = 0.27312221982156115, Parameters = [26304, 38, 26001, 9067, 26991], Time = 5345.84 seconds
# Iteration 461: Objective Value (LCOE) = 0.2847432635954398, Parameters = [21929, 24, 27876, 9692, 28616], Time = 5357.45 seconds
# Iteration 462: Objective Value (LCOE) = 0.2677578238998549, Parameters = [39429, 42, 20376, 7192, 22116], Time = 5369.57 seconds
# Iteration 463: Objective Value (LCOE) = 0.2637558015782189, Parameters = [30679, 16, 24126, 8442, 18866], Time = 5380.96 seconds
# Iteration 464: Objective Value (LCOE) = 0.26140558443566875, Parameters = [13179, 33, 16626, 5942, 25366], Time = 5393.12 seconds
# Iteration 465: Objective Value (LCOE) = 0.2830385576891728, Parameters = [14272, 15, 29282, 8911, 21710], Time = 5404.87 seconds
# Iteration 466: Objective Value (LCOE) = 0.27849789729810465, Parameters = [31772, 32, 21782, 6411, 28210], Time = 5416.66 seconds
# Iteration 467: Objective Value (LCOE) = 0.2845648101696806, Parameters = [40522, 23, 25532, 7661, 24960], Time = 5428.05 seconds
# Iteration 468: Objective Value (LCOE) = 0.24161626850338078, Parameters = [23022, 41, 18032, 5161, 18460], Time = 5439.93 seconds
# Iteration 469: Objective Value (LCOE) = 0.25809855635059653, Parameters = [27397, 19, 19907, 5786, 20085], Time = 5451.78 seconds
# Iteration 470: Objective Value (LCOE) = 0.28857245547046745, Parameters = [44897, 36, 27407, 8286, 26585], Time = 5463.83 seconds
# Iteration 471: Objective Value (LCOE) = 0.32170351768565214, Parameters = [36147, 10, 16157, 7036, 29835], Time = 5475.21 seconds
# Iteration 472: Objective Value (LCOE) = 0.2596097565260755, Parameters = [18647, 28, 23657, 9536, 23335], Time = 5486.77 seconds
# Iteration 473: Objective Value (LCOE) = 0.2706177770968115, Parameters = [16460, 26, 15220, 8599, 27397], Time = 5498.40 seconds
# Iteration 474: Objective Value (LCOE) = 0.2616215169298197, Parameters = [33960, 43, 22720, 6099, 20897], Time = 5510.42 seconds
# Iteration 475: Objective Value (LCOE) = 0.2635546027478131, Parameters = [42710, 17, 18970, 9849, 17647], Time = 5521.75 seconds
# Iteration 476: Objective Value (LCOE) = 0.2640537632690011, Parameters = [25210, 34, 26470, 7349, 24147], Time = 5533.22 seconds
# Iteration 477: Objective Value (LCOE) = 0.300033944673796, Parameters = [20835, 12, 24595, 6724, 25772], Time = 5543.92 seconds
# Iteration 478: Objective Value (LCOE) = 0.25380702687634255, Parameters = [38335, 30, 17095, 9224, 19272], Time = 5555.15 seconds
# Iteration 479: Objective Value (LCOE) = 0.27168241293483003, Parameters = [29585, 21, 28345, 5474, 22522], Time = 5566.28 seconds
# Iteration 480: Objective Value (LCOE) = 0.27671612984212235, Parameters = [12085, 39, 20845, 7974, 29022], Time = 5577.46 seconds
# Iteration 481: Objective Value (LCOE) = 0.277210597430144, Parameters = [11538, 14, 18735, 9614, 19476], Time = 5588.51 seconds
# Iteration 482: Objective Value (LCOE) = 0.2728689534668916, Parameters = [29038, 32, 26235, 7114, 25976], Time = 5599.81 seconds
# Iteration 483: Objective Value (LCOE) = 0.29416771488719884, Parameters = [37788, 23, 22485, 8364, 29226], Time = 5611.81 seconds
# Iteration 484: Objective Value (LCOE) = 0.26054166226273756, Parameters = [20288, 40, 29985, 5864, 22726], Time = 5623.90 seconds
# Iteration 485: Objective Value (LCOE) = 0.2550510449570379, Parameters = [24663, 27, 24360, 5239, 21101], Time = 5635.66 seconds
# Iteration 486: Objective Value (LCOE) = 0.2833307133865655, Parameters = [42163, 45, 16860, 7739, 27601], Time = 5647.36 seconds
# Iteration 487: Objective Value (LCOE) = 0.28491330243257734, Parameters = [33413, 18, 28110, 6489, 24351], Time = 5658.68 seconds
# Iteration 488: Objective Value (LCOE) = 0.23812712599655572, Parameters = [15913, 36, 20610, 8989, 17851], Time = 5670.69 seconds
# Iteration 489: Objective Value (LCOE) = 0.2769449220242098, Parameters = [18101, 21, 27173, 8052, 25163], Time = 5682.54 seconds
# Iteration 490: Objective Value (LCOE) = 0.2525811185125533, Parameters = [35601, 38, 19673, 5552, 18663], Time = 5694.70 seconds
# Iteration 491: Objective Value (LCOE) = 0.2951254625246288, Parameters = [44351, 12, 23423, 9302, 21913], Time = 5706.52 seconds
# Iteration 492: Objective Value (LCOE) = 0.27294628923888015, Parameters = [26851, 29, 15923, 6802, 28413], Time = 5718.58 seconds
# Iteration 493: Objective Value (LCOE) = 0.2883868390148496, Parameters = [22476, 16, 21548, 7427, 26788], Time = 5730.41 seconds
# Iteration 494: Objective Value (LCOE) = 0.2666515753041276, Parameters = [39976, 34, 29048, 9927, 20288], Time = 5742.11 seconds
# Iteration 495: Objective Value (LCOE) = 0.24346837733493135, Parameters = [31226, 25, 17798, 6177, 17038], Time = 5753.96 seconds
# Iteration 496: Objective Value (LCOE) = 0.26145113235417766, Parameters = [13726, 43, 25298, 8677, 23538], Time = 5765.60 seconds
# Iteration 497: Objective Value (LCOE) = 0.264979694256328, Parameters = [12632, 24, 19204, 6333, 23132], Time = 5777.45 seconds
# Iteration 498: Objective Value (LCOE) = 0.2840460416427775, Parameters = [30132, 41, 26704, 8833, 29632], Time = 5789.59 seconds
# Iteration 499: Objective Value (LCOE) = 0.2935268999680346, Parameters = [38882, 15, 15454, 5083, 26382], Time = 5801.31 seconds
# Iteration 500: Objective Value (LCOE) = 0.24614740488786788, Parameters = [21382, 33, 22954, 7583, 19882], Time = 5813.33 seconds
# Iteration 501: Objective Value (LCOE) = 0.27450541792963074, Parameters = [25757, 11, 28579, 8208, 18257], Time = 5825.05 seconds
# Iteration 502: Objective Value (LCOE) = 0.27884322821657526, Parameters = [43257, 28, 21079, 5708, 24757], Time = 5836.87 seconds
# Iteration 503: Objective Value (LCOE) = 0.29317977506289145, Parameters = [34507, 20, 24829, 9458, 28007], Time = 5848.93 seconds
# Iteration 504: Objective Value (LCOE) = 0.24711629946798286, Parameters = [17007, 37, 17329, 6958, 21507], Time = 5860.96 seconds
# Iteration 505: Objective Value (LCOE) = 0.3036717630029216, Parameters = [14819, 17, 25767, 6021, 28819], Time = 5872.76 seconds
# Iteration 506: Objective Value (LCOE) = 0.25815552710432954, Parameters = [32319, 35, 18267, 8521, 22319], Time = 5884.74 seconds
# Iteration 507: Objective Value (LCOE) = 0.2662305503381316, Parameters = [41069, 26, 29517, 7271, 19069], Time = 5896.50 seconds
# Iteration 508: Objective Value (LCOE) = 0.26549119639912344, Parameters = [23569, 44, 22017, 9771, 25569], Time = 5908.27 seconds
# Iteration 509: Objective Value (LCOE) = 0.2633459159887887, Parameters = [19194, 22, 16392, 9146, 23944], Time = 5919.86 seconds
# Iteration 510: Objective Value (LCOE) = 0.25375998616757695, Parameters = [36694, 39, 23892, 6646, 17444], Time = 5931.28 seconds
# Iteration 511: Objective Value (LCOE) = 0.2733426477871915, Parameters = [27944, 13, 20142, 7896, 20694], Time = 5942.97 seconds
# Iteration 512: Objective Value (LCOE) = 0.2837823876625427, Parameters = [10444, 30, 27642, 5396, 27194], Time = 5954.78 seconds
# Constructing Gabrial graph and minimizer pool
# Triangulation completed, building minimizer pool
# Starting minimization at [20219.7265625     32.18261719 19819.3359375   7026.3671875
#  26305.6640625 ]...
# bounds in kwarg:
# [[10000.0, 45000.0], [10.0, 45.0], [15000.0, 30000.0], [5000.0, 10000.0], [17000.0, 30000.0]]
# Iteration 513: Objective Value (LCOE) = 0.2641448974239781, Parameters = [20220, 32, 19819, 7026, 26306], Time = 5967.36 seconds
# Iteration 514: Objective Value (LCOE) = 0.2641448974239781, Parameters = [20220, 32, 19819, 7026, 26306], Time = 5979.25 seconds
# Iteration 515: Objective Value (LCOE) = 0.2641448974239781, Parameters = [20220, 32, 19819, 7026, 26306], Time = 5991.18 seconds
# Iteration 516: Objective Value (LCOE) = 0.2641448974239781, Parameters = [20220, 32, 19819, 7026, 26306], Time = 6002.38 seconds
# Iteration 517: Objective Value (LCOE) = 0.2641448974239781, Parameters = [20220, 32, 19819, 7026, 26306], Time = 6013.86 seconds
# Iteration 518: Objective Value (LCOE) = 0.2641448974239781, Parameters = [20220, 32, 19819, 7026, 26306], Time = 6025.40 seconds
# lres =  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.2641448974239781
#        x: [ 2.022e+04  3.218e+01  1.982e+04  7.026e+03  2.631e+04]
#      nit: 1
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#     nfev: 6
#     njev: 1
# Starting minimization at [3.47119141e+04 2.26123047e+01 2.76708984e+04 7.37792969e+03
#  2.64072266e+04]...
# bounds in kwarg:
# [[10000.0, 45000.0], [10.0, 45.0], [15000.0, 30000.0], [5000.0, 10000.0], [17000.0, 30000.0]]
# Iteration 519: Objective Value (LCOE) = 0.28609206734311626, Parameters = [34712, 23, 27671, 7378, 26407], Time = 6037.17 seconds
# Iteration 520: Objective Value (LCOE) = 0.28609206734311626, Parameters = [34712, 23, 27671, 7378, 26407], Time = 6048.54 seconds
# Iteration 521: Objective Value (LCOE) = 0.28609206734311626, Parameters = [34712, 23, 27671, 7378, 26407], Time = 6060.32 seconds
# Iteration 522: Objective Value (LCOE) = 0.28609206734311626, Parameters = [34712, 23, 27671, 7378, 26407], Time = 6072.29 seconds
# Iteration 523: Objective Value (LCOE) = 0.28609206734311626, Parameters = [34712, 23, 27671, 7378, 26407], Time = 6084.06 seconds
# Iteration 524: Objective Value (LCOE) = 0.28609206734311626, Parameters = [34712, 23, 27671, 7378, 26407], Time = 6095.45 seconds
# lres =  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.28609206734311626
#        x: [ 3.471e+04  2.261e+01  2.767e+04  7.378e+03  2.641e+04]
#      nit: 1
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#     nfev: 6
#     njev: 1
# Starting minimization at [15161.1328125     38.88183594 15776.3671875   6147.4609375
#  18028.3203125 ]...
# bounds in kwarg:
# [[10000.0, 45000.0], [10.0, 45.0], [15000.0, 30000.0], [5000.0, 10000.0], [17000.0, 30000.0]]
# Iteration 525: Objective Value (LCOE) = 0.23618537753639474, Parameters = [15161, 39, 15776, 6147, 18028], Time = 6107.44 seconds
# Iteration 526: Objective Value (LCOE) = 0.23618537753639474, Parameters = [15161, 39, 15776, 6147, 18028], Time = 6118.98 seconds
# Iteration 527: Objective Value (LCOE) = 0.23618537753639474, Parameters = [15161, 39, 15776, 6147, 18028], Time = 6131.09 seconds
# Iteration 528: Objective Value (LCOE) = 0.23618537753639474, Parameters = [15161, 39, 15776, 6147, 18028], Time = 6143.02 seconds
# Iteration 529: Objective Value (LCOE) = 0.23618537753639474, Parameters = [15161, 39, 15776, 6147, 18028], Time = 6155.11 seconds
# Iteration 530: Objective Value (LCOE) = 0.23618537753639474, Parameters = [15161, 39, 15776, 6147, 18028], Time = 6167.26 seconds
# lres =  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.23618537753639474
#        x: [ 1.516e+04  3.888e+01  1.578e+04  6.147e+03  1.803e+04]
#      nit: 1
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#     nfev: 6
#     njev: 1
# Starting minimization at [30883.7890625     35.19042969 15717.7734375   9174.8046875
#  26610.3515625 ]...
# bounds in kwarg:
# [[10000.0, 45000.0], [10.0, 45.0], [15000.0, 30000.0], [5000.0, 10000.0], [17000.0, 30000.0]]
# Iteration 531: Objective Value (LCOE) = 0.2676475386431566, Parameters = [30884, 35, 15718, 9175, 26610], Time = 6179.05 seconds
# Iteration 532: Objective Value (LCOE) = 0.2676475386431566, Parameters = [30884, 35, 15718, 9175, 26610], Time = 6191.27 seconds
# Iteration 533: Objective Value (LCOE) = 0.2676475386431566, Parameters = [30884, 35, 15718, 9175, 26610], Time = 6203.08 seconds
# Iteration 534: Objective Value (LCOE) = 0.2676475386431566, Parameters = [30884, 35, 15718, 9175, 26610], Time = 6214.89 seconds
# Iteration 535: Objective Value (LCOE) = 0.2676475386431566, Parameters = [30884, 35, 15718, 9175, 26610], Time = 6226.77 seconds
# Iteration 536: Objective Value (LCOE) = 0.2676475386431566, Parameters = [30884, 35, 15718, 9175, 26610], Time = 6238.95 seconds
# lres =  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.2676475386431566
#        x: [ 3.088e+04  3.519e+01  1.572e+04  9.175e+03  2.661e+04]
#      nit: 1
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#     nfev: 6
#     njev: 1
# Starting minimization at [1.52978516e+04 2.83544922e+01 1.91162109e+04 5.22949219e+03
#  2.93525391e+04]...
# bounds in kwarg:
# [[10000.0, 45000.0], [10.0, 45.0], [15000.0, 30000.0], [5000.0, 10000.0], [17000.0, 30000.0]]
# Iteration 537: Objective Value (LCOE) = 0.2789860259574532, Parameters = [15298, 28, 19116, 5229, 29353], Time = 6250.75 seconds
# Iteration 538: Objective Value (LCOE) = 0.2789860259574532, Parameters = [15298, 28, 19116, 5229, 29353], Time = 6262.15 seconds
# Iteration 539: Objective Value (LCOE) = 0.2789860259574532, Parameters = [15298, 28, 19116, 5229, 29353], Time = 6273.86 seconds
# Iteration 540: Objective Value (LCOE) = 0.2789860259574532, Parameters = [15298, 28, 19116, 5229, 29353], Time = 6285.09 seconds
# Iteration 541: Objective Value (LCOE) = 0.2789860259574532, Parameters = [15298, 28, 19116, 5229, 29353], Time = 6297.01 seconds
# Iteration 542: Objective Value (LCOE) = 0.2789860259574532, Parameters = [15298, 28, 19116, 5229, 29353], Time = 6308.62 seconds
# lres =  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.2789860259574532
#        x: [ 1.530e+04  2.835e+01  1.912e+04  5.229e+03  2.935e+04]
#      nit: 1
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#     nfev: 6
#     njev: 1
# Starting minimization at [2.40478516e+04 1.96044922e+01 2.28662109e+04 8.97949219e+03
#  2.61025391e+04]...
# bounds in kwarg:
# [[10000.0, 45000.0], [10.0, 45.0], [15000.0, 30000.0], [5000.0, 10000.0], [17000.0, 30000.0]]
# Iteration 543: Objective Value (LCOE) = 0.2790414066287694, Parameters = [24048, 20, 22866, 8979, 26103], Time = 6320.05 seconds
# Iteration 544: Objective Value (LCOE) = 0.2790414066287694, Parameters = [24048, 20, 22866, 8979, 26103], Time = 6331.45 seconds
# Iteration 545: Objective Value (LCOE) = 0.2790414066287694, Parameters = [24048, 20, 22866, 8979, 26103], Time = 6343.14 seconds
# Iteration 546: Objective Value (LCOE) = 0.2790414066287694, Parameters = [24048, 20, 22866, 8979, 26103], Time = 6354.39 seconds
# Iteration 547: Objective Value (LCOE) = 0.2790414066287694, Parameters = [24048, 20, 22866, 8979, 26103], Time = 6366.06 seconds
# Iteration 548: Objective Value (LCOE) = 0.2790414066287694, Parameters = [24048, 20, 22866, 8979, 26103], Time = 6377.48 seconds
# lres =  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.2790414066287694
#        x: [ 2.405e+04  1.960e+01  2.287e+04  8.979e+03  2.610e+04]
#      nit: 1
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#     nfev: 6
#     njev: 1
# Successfully completed construction of complex.
# SHGO optimization successful. LCOE: 0.236185, Iterations: 0, Total Time: 6377.48 seconds
# SHGO optimization successful. LCOE: 0.236185, Iterations: 0, Time: 6377.48 seconds
#
# Optimization comparison results are saved in the 'optimisation_results' directory.
#
# Best results for each deposit:
#   Method  Iterations  Duration (seconds)      LCOE
# 0   SHGO           0         6377.482592  0.236185
#
# Method performance summary:
#        Iterations         Duration (seconds)                            \
#            median min max             median          min          max
# Method
# SHGO          0.0   0   0        6377.482592  6377.482592  6377.482592
#
#             LCOE
#           median       min       max std
# Method
# SHGO    0.236185  0.236185  0.236185 NaN
#
# Number of times each method found the best solution:
# Method
# SHGO    1
# Name: count, dtype: int64
#
# Success rate of each method (%):
# Method
# SHGO    100.0
# Name: LCOE, dtype: float64
